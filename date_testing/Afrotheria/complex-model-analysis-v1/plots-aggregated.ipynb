# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ete3 import Tree

# %%
# middle_calibration files

middle_GTR_G4_dates = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/middle/GTR_G4_middle_out.txt"
middle_MF_Q_dates = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/middle/MF_middle_out.txt"
middle_MF_p_dates = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/middle/MF_p_middle_out.txt"
middle_MIX_MF_dates = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/middle/MIX_MF_midle_out.txt"

# %%
# root_calibration files

root_GTR_G4_dates = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/root/GTR_G4_root_out.txt"
root_MF_Q_dates = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/root/MF_root_out.txt"
root_MF_p_dates = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/root/MF_p_root_out.txt"
root_MIX_MF_dates = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/root/MIX_MF_root_out.txt"

# %%
# young_calibration files

young_GTR_G4_dates = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/young/GTR_G4_young_out.txt"
young_MF_Q_dates = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/young/MF_young_out.txt"
young_MF_p_dates = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/young/MF_p_young_out.txt"
young_MIX_MF_dates = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/young/MIX_MF_young_out.txt"

# %%
# index trees

GTR_G4_index_tree = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/GTR_G4_index.tree"
MIX_MF_index_tree = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/MIX_MF_index.tree"

# %%
def read_mean_dates(file_path):
    data = []
    mu_data = []
    var_data = []
    model_mean_times = {}
    read_flag = False
    with open(file_path,"r") as f:
        lines = f.readlines()
    for line in lines:
        if line.startswith("Posterior"):
            read_flag = True
        if read_flag and line.startswith("t"):
            data.append(line)
        if read_flag and line.startswith("mu"):
            mu_data.append(line)
        if read_flag and line.startswith("sigma"):
            var_data.append(line)
    for line in data:
        line = line.strip().split()
        model_mean_times[int(line[0][3:])] = float(line[1])
    return model_mean_times

# %%
# Function to traverse the tree and populate the dictionary
def traverse_and_collect(node, clade_values):
    if not node.is_leaf():
        clade_name = node.name if node.name else "root"
        # Retrieve the support value (if exists)
        if clade_name == "root":
            clade_name = "root:1"
        support_value = node.support if node.support else None
        clade_values[clade_name] = support_value
        for child in node.get_children():
            # print(child)
            # print(child.get_leaf_names())
            child_names = child.get_leaf_names()
            cleaned_child_names = ["_".join(name.split('_')[1:]) for name in child_names]
            cleaned_child_names.sort()
            final_child_name = ":".join(cleaned_child_names)+":"+str(len(cleaned_child_names))
            support_value = node.support if node.support else None
            # print(support_value)
            clade_values[final_child_name] = support_value
            traverse_and_collect(child, clade_values)

# %%
def compare_trees(x_axis_tree, y_axis_tree, y_axis_data_path, x_axis_data_path):
    y_axis_model1_mean_times = read_mean_dates(y_axis_data_path)
    x_axis_model2_mean_times = read_mean_dates(x_axis_data_path)
    
    tree1 = Tree(x_axis_tree)
    tree2 = Tree(y_axis_tree)
    
    clade_values_tree1 = {}
    clade_values_tree2 = {}
    
    traverse_and_collect(tree1, clade_values_tree1)
    traverse_and_collect(tree2, clade_values_tree2)
    
    diff_indexes = []
    for clade, value in clade_values_tree1.items():
        names = clade.split(":")
        len_of_clade = int(names[-1])
        for clade2, value2 in clade_values_tree2.items():
            names2 = clade2.split(":")
            len_of_clade2 = int(names2[-1])
            if clade == clade2 and value != value2:
               print(f"Clade: {clade}, Support Value LG_G4: {value}, Support Value LG_G4_C60: {value2}")
               diff_indexes.append([int(value), int(value2)])
    unique_data = [list(t) for t in set(tuple(inner) for inner in diff_indexes)]
    
    model2_keys = [i[0] for i in unique_data]
    model1_keys = [i[1] for i in unique_data]
    
    mapped_keys = {}
    for i in range(len(model2_keys)):
        mapped_keys[model2_keys[i]] = model1_keys[i]
    
    model1_revised_times = {}
    for key, value in y_axis_model1_mean_times.items():
        if key in model1_keys:
            model1_revised_times[key] = y_axis_model1_mean_times[mapped_keys[key]]
        else:
            model1_revised_times[key] = value
    model1_mean_posterior_times = np.array(list(model1_revised_times.values()))
    model2_mean_posterior_times = np.array(list(x_axis_model2_mean_times.values()))
    
    return model1_mean_posterior_times, model2_mean_posterior_times

# %%
# middle_C60_data = read_mean_dates(middle_LG_G4_C60_dates)
# middle_LG_G4_data = read_mean_dates(middle_LG_G4_codeml_dates)

# %%
middle_MIX_MF_y, middle_GTR_G4_x = compare_trees(GTR_G4_index_tree, MIX_MF_index_tree, middle_MIX_MF_dates, middle_GTR_G4_dates)
# Out:
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:12, Support Value LG_G4: 65.0, Support Value LG_G4_C60: 96.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:7, Support Value LG_G4: 66.0, Support Value LG_G4_C60: 97.0
# Clade: elephantulus_edwardii:elephantulus_myurus:elephantulus_sp_vb001:3, Support Value LG_G4: 67.0, Support Value LG_G4_C60: 98.0
# Clade: elephantulus_edwardii:1, Support Value LG_G4: 68.0, Support Value LG_G4_C60: 99.0
# Clade: elephantulus_myurus:elephantulus_sp_vb001:2, Support Value LG_G4: 68.0, Support Value LG_G4_C60: 99.0
# Clade: elephantulus_sp_vb001:1, Support Value LG_G4: 69.0, Support Value LG_G4_C60: 100.0
# Clade: elephantulus_myurus:1, Support Value LG_G4: 69.0, Support Value LG_G4_C60: 100.0
# Clade: elephantulus_brachyrhynchus:elephantulus_intufi:elephantulus_rufescens:elephantulus_rupestris:4, Support Value LG_G4: 67.0, Support Value LG_G4_C60: 98.0
# Clade: elephantulus_intufi:elephantulus_rupestris:2, Support Value LG_G4: 70.0, Support Value LG_G4_C60: 101.0
# Clade: elephantulus_intufi:1, Support Value LG_G4: 71.0, Support Value LG_G4_C60: 102.0
# Clade: elephantulus_rupestris:1, Support Value LG_G4: 71.0, Support Value LG_G4_C60: 102.0
# Clade: elephantulus_brachyrhynchus:elephantulus_rufescens:2, Support Value LG_G4: 70.0, Support Value LG_G4_C60: 101.0
# Clade: elephantulus_brachyrhynchus:1, Support Value LG_G4: 72.0, Support Value LG_G4_C60: 103.0
# Clade: elephantulus_rufescens:1, Support Value LG_G4: 72.0, Support Value LG_G4_C60: 103.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:5, Support Value LG_G4: 66.0, Support Value LG_G4_C60: 97.0
# Clade: petrodromus_tetradactylus:petrosaltator_rozeti:2, Support Value LG_G4: 73.0, Support Value LG_G4_C60: 104.0
# Clade: petrosaltator_rozeti:1, Support Value LG_G4: 74.0, Support Value LG_G4_C60: 105.0
# Clade: petrodromus_tetradactylus:1, Support Value LG_G4: 74.0, Support Value LG_G4_C60: 105.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:3, Support Value LG_G4: 73.0, Support Value LG_G4_C60: 104.0
# Clade: macroscelides_flavicaudatus:macroscelides_proboscideus:2, Support Value LG_G4: 75.0, Support Value LG_G4_C60: 106.0
# Clade: macroscelides_flavicaudatus:1, Support Value LG_G4: 76.0, Support Value LG_G4_C60: 107.0
# Clade: macroscelides_proboscideus:1, Support Value LG_G4: 76.0, Support Value LG_G4_C60: 107.0
# Clade: macroscelides_micus:1, Support Value LG_G4: 75.0, Support Value LG_G4_C60: 106.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:3, Support Value LG_G4: 65.0, Support Value LG_G4_C60: 96.0
# Clade: rhynchocyon_udzungwensis:1, Support Value LG_G4: 77.0, Support Value LG_G4_C60: 108.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:2, Support Value LG_G4: 77.0, Support Value LG_G4_C60: 108.0
# Clade: rhynchocyon_cirnei_reichardi:1, Support Value LG_G4: 78.0, Support Value LG_G4_C60: 109.0
# Clade: rhynchocyon_petersi:1, Support Value LG_G4: 78.0, Support Value LG_G4_C60: 109.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:oryzorictes:potamogale_velox:setifer_setosus:tenrec_ecaudatus:15, Support Value LG_G4: 79.0, Support Value LG_G4_C60: 65.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:setifer_setosus:tenrec_ecaudatus:13, Support Value LG_G4: 80.0, Support Value LG_G4_C60: 82.0
# Clade: echinops_telfairi:hemicentetes_semispinosus:setifer_setosus:tenrec_ecaudatus:4, Support Value LG_G4: 81.0, Support Value LG_G4_C60: 83.0
# Clade: echinops_telfairi:setifer_setosus:2, Support Value LG_G4: 82.0, Support Value LG_G4_C60: 84.0
# Clade: echinops_telfairi:1, Support Value LG_G4: 83.0, Support Value LG_G4_C60: 86.0
# Clade: setifer_setosus:1, Support Value LG_G4: 83.0, Support Value LG_G4_C60: 86.0
# Clade: hemicentetes_semispinosus:tenrec_ecaudatus:2, Support Value LG_G4: 82.0, Support Value LG_G4_C60: 84.0
# Clade: tenrec_ecaudatus:1, Support Value LG_G4: 84.0, Support Value LG_G4_C60: 85.0
# Clade: hemicentetes_semispinosus:1, Support Value LG_G4: 84.0, Support Value LG_G4_C60: 85.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:9, Support Value LG_G4: 81.0, Support Value LG_G4_C60: 83.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:8, Support Value LG_G4: 85.0, Support Value LG_G4_C60: 87.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:7, Support Value LG_G4: 86.0, Support Value LG_G4_C60: 88.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:4, Support Value LG_G4: 87.0, Support Value LG_G4_C60: 89.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:3, Support Value LG_G4: 88.0, Support Value LG_G4_C60: 90.0
# Clade: microgale_longicaudata:microgale_majori:2, Support Value LG_G4: 89.0, Support Value LG_G4_C60: 91.0
# Clade: microgale_longicaudata:1, Support Value LG_G4: 90.0, Support Value LG_G4_C60: 92.0
# Clade: microgale_majori:1, Support Value LG_G4: 90.0, Support Value LG_G4_C60: 92.0
# Clade: microgale_principula:1, Support Value LG_G4: 89.0, Support Value LG_G4_C60: 91.0
# Clade: microgale_pusilla:1, Support Value LG_G4: 88.0, Support Value LG_G4_C60: 90.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_talazaci:3, Support Value LG_G4: 87.0, Support Value LG_G4_C60: 89.0
# Clade: limnogale_mergulus:microgale_brevicaudata:2, Support Value LG_G4: 91.0, Support Value LG_G4_C60: 93.0
# Clade: microgale_brevicaudata:1, Support Value LG_G4: 92.0, Support Value LG_G4_C60: 94.0
# Clade: limnogale_mergulus:1, Support Value LG_G4: 92.0, Support Value LG_G4_C60: 94.0
# Clade: microgale_talazaci:1, Support Value LG_G4: 91.0, Support Value LG_G4_C60: 93.0
# Clade: geogale_aurita:1, Support Value LG_G4: 86.0, Support Value LG_G4_C60: 88.0
# Clade: oryzorictes:1, Support Value LG_G4: 85.0, Support Value LG_G4_C60: 87.0
# Clade: micropotamogale_lamottei:potamogale_velox:2, Support Value LG_G4: 80.0, Support Value LG_G4_C60: 82.0
# Clade: micropotamogale_lamottei:1, Support Value LG_G4: 93.0, Support Value LG_G4_C60: 95.0
# Clade: potamogale_velox:1, Support Value LG_G4: 93.0, Support Value LG_G4_C60: 95.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:17, Support Value LG_G4: 79.0, Support Value LG_G4_C60: 65.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:14, Support Value LG_G4: 94.0, Support Value LG_G4_C60: 66.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:neamblysomus_gunningi:neamblysomus_julianae:13, Support Value LG_G4: 95.0, Support Value LG_G4_C60: 67.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:8, Support Value LG_G4: 96.0, Support Value LG_G4_C60: 68.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:5, Support Value LG_G4: 97.0, Support Value LG_G4_C60: 73.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_septentrionalis:4, Support Value LG_G4: 98.0, Support Value LG_G4_C60: 74.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:3, Support Value LG_G4: 99.0, Support Value LG_G4_C60: 75.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:2, Support Value LG_G4: 100.0, Support Value LG_G4_C60: 76.0
# Clade: amblysomus_hottentotus:1, Support Value LG_G4: 101.0, Support Value LG_G4_C60: 77.0
# Clade: amblysomus_corriae:1, Support Value LG_G4: 101.0, Support Value LG_G4_C60: 77.0
# Clade: amblysomus_marleyi:1, Support Value LG_G4: 100.0, Support Value LG_G4_C60: 76.0
# Clade: amblysomus_septentrionalis:1, Support Value LG_G4: 99.0, Support Value LG_G4_C60: 75.0
# Clade: amblysomus_robustus:1, Support Value LG_G4: 98.0, Support Value LG_G4_C60: 74.0
# Clade: carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:3, Support Value LG_G4: 97.0, Support Value LG_G4_C60: 73.0
# Clade: neamblysomus_gunningi:neamblysomus_julianae:2, Support Value LG_G4: 102.0, Support Value LG_G4_C60: 78.0
# Clade: neamblysomus_julianae:1, Support Value LG_G4: 103.0, Support Value LG_G4_C60: 79.0
# Clade: neamblysomus_gunningi:1, Support Value LG_G4: 103.0, Support Value LG_G4_C60: 79.0
# Clade: carpitalpa_arendsi:1, Support Value LG_G4: 102.0, Support Value LG_G4_C60: 78.0
# Clade: calcochloris_obtusirostris:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:5, Support Value LG_G4: 96.0, Support Value LG_G4_C60: 68.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:chrysospalax_villosus:3, Support Value LG_G4: 104.0, Support Value LG_G4_C60: 69.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:2, Support Value LG_G4: 105.0, Support Value LG_G4_C60: 70.0
# Clade: chrysospalax_trevelyani:1, Support Value LG_G4: 106.0, Support Value LG_G4_C60: 71.0
# Clade: calcochloris_obtusirostris:1, Support Value LG_G4: 106.0, Support Value LG_G4_C60: 71.0
# Clade: chrysospalax_villosus:1, Support Value LG_G4: 105.0, Support Value LG_G4_C60: 70.0
# Clade: chlorotalpa_duthieae:chlorotalpa_sclateri:2, Support Value LG_G4: 104.0, Support Value LG_G4_C60: 69.0
# Clade: chlorotalpa_sclateri:1, Support Value LG_G4: 107.0, Support Value LG_G4_C60: 72.0
# Clade: chlorotalpa_duthieae:1, Support Value LG_G4: 107.0, Support Value LG_G4_C60: 72.0
# Clade: eremitalpa_granti:1, Support Value LG_G4: 95.0, Support Value LG_G4_C60: 67.0
# Clade: chrysochloris_asiatica:chrysochloris_stuhlmanni:cryptochloris_wintoni:3, Support Value LG_G4: 94.0, Support Value LG_G4_C60: 66.0
# Clade: chrysochloris_asiatica:cryptochloris_wintoni:2, Support Value LG_G4: 108.0, Support Value LG_G4_C60: 80.0
# Clade: chrysochloris_asiatica:1, Support Value LG_G4: 109.0, Support Value LG_G4_C60: 81.0
# Clade: cryptochloris_wintoni:1, Support Value LG_G4: 109.0, Support Value LG_G4_C60: 81.0
# Clade: chrysochloris_stuhlmanni:1, Support Value LG_G4: 108.0, Support Value LG_G4_C60: 80.0

# %%
fig, ax = plt.subplots(figsize=(9 ,9))
ax.plot([-0.1,3], 
        [-0.1, 3], 
        'k--')
points = ax.plot(middle_GTR_G4_x, middle_MIX_MF_y, 'o')
points[0].set_markerfacecolor('blue')

points_to_mark = [(1, 1), (1.5, 1.5), (2, 2)]
labels = ['Point A', 'Point B', 'Point C']
colors = ['red', 'green', 'blue']
# points[23].set_markerfacecolor('blue')# Set default face color (for other points)

# Now plot the highlighted point with a different color
# ax.scatter(posterior_mean_iqtree[0], posterior_mean_baseml[0], color='red', s=100)
# ax.scatter(posterior_mean_iqtree[-5], posterior_mean_baseml[-5], color='red', s=100)
# # ax.scatter(posterior_mean_iqtree[0], posterior_mean_baseml[0], color='red', label='Root age')
# ax.annotate('root calibration:\n B(33.4700, 45.2000)', 
#         xy=(model1_mean_posterior_times[0], model2_mean_posterior_times[0]), 
#         xytext=(model1_mean_posterior_times[0] -4,  model2_mean_posterior_times[0] + 2),  # Offset position for the label
#         arrowprops=dict(arrowstyle='->', color='red'),  # Arrow style
#         fontsize=12, color='red') 
# ax.annotate('middle calibration:\n B (10.3300, 45.2000)', 
#         xy=(model1_mean_posterior_times[-5], model2_mean_posterior_times[-5]), 
#         xytext=(model1_mean_posterior_times[-5] -6,  model2_mean_posterior_times[-5] + 10),  # Offset position for the label
#         arrowprops=dict(arrowstyle='->', color='red'),  # Arrow style
#         fontsize=12, color='red') 

for (px, py), color in zip(points_to_mark, colors):
        ax.scatter(px, py, color=color, marker='o', s=100, zorder=3)
# Labels and title
# ax.set_xlabel('Posterior mean age LG+G4+C60 [100 Mya]', fontsize=18)
# ax.set_ylabel('Posterior mean age LG+G4 [100 Mya]', fontsize=18)

# Adding a label below the x-axis title for all the subplots with colored dots
fig.text(0.5, 0.01, 'Highlighted Points: ', ha='center', fontsize=14, color='blue')
for label, color in zip(labels, colors):
    plt.scatter([], [], color=color, marker='o', s=100, label=label)
fig.legend(loc='lower center', ncol=3, fontsize=12)
# ax.set_title('Posterior mean age comparison between LG and LG+G4+C60 [t199 ~ B(10.3300,45.2000)]')
# ax.legend()


plt.show()

# %%
x_plot_data = []
y_plot_data = []

# LG_G4_C60 data
young_LG_G4_C60_y, young_LG_G4_x = compare_trees(GTR_G4_index_tree, MIX_MF_index_tree,young_MIX_MF_dates, young_GTR_G4_dates)

x_plot_data.append(young_LG_G4_x)
y_plot_data.append(young_LG_G4_C60_y)

middle_LG_G4_C60_y, middle_LG_G4_x = compare_trees(GTR_G4_index_tree, MIX_MF_index_tree,middle_MIX_MF_dates, middle_GTR_G4_dates)

x_plot_data.append(middle_LG_G4_x)
y_plot_data.append(middle_LG_G4_C60_y)

root_LG_G4_C60_y, root_LG_G4_x = compare_trees(GTR_G4_index_tree, MIX_MF_index_tree,root_MIX_MF_dates, root_GTR_G4_dates)

x_plot_data.append(root_LG_G4_x)
y_plot_data.append(root_LG_G4_C60_y)

# PM_MF_Q data

young_PM_MF_Q_y, young_LG_G4_q_x = compare_trees(GTR_G4_index_tree, GTR_G4_index_tree, young_MF_Q_dates, young_GTR_G4_dates)

x_plot_data.append(young_LG_G4_q_x)
y_plot_data.append(young_PM_MF_Q_y)

middle_PM_MF_Q_y, middle_LG_G4_q_x = compare_trees(GTR_G4_index_tree, GTR_G4_index_tree,middle_MF_Q_dates, middle_GTR_G4_dates)

x_plot_data.append(middle_LG_G4_q_x)
y_plot_data.append(middle_PM_MF_Q_y)

root_PM_MF_Q_y, root_LG_G4_q_x = compare_trees(GTR_G4_index_tree, GTR_G4_index_tree,root_MF_Q_dates, root_GTR_G4_dates)

x_plot_data.append(root_LG_G4_q_x)
y_plot_data.append(root_PM_MF_Q_y)


# PM_MF_p data

young_PM_MF_p_y, young_LG_G4_p_x = compare_trees(GTR_G4_index_tree, GTR_G4_index_tree,young_MF_p_dates, young_GTR_G4_dates)

x_plot_data.append(young_LG_G4_p_x)
y_plot_data.append(young_PM_MF_p_y)

middle_PM_MF_p_y, middle_LG_G4_p_x = compare_trees(GTR_G4_index_tree, GTR_G4_index_tree,middle_MF_p_dates, middle_GTR_G4_dates)

x_plot_data.append(middle_LG_G4_p_x)
y_plot_data.append(middle_PM_MF_p_y)

root_PM_MF_p_y, root_LG_G4_p_x = compare_trees(GTR_G4_index_tree, GTR_G4_index_tree,root_MF_p_dates, root_GTR_G4_dates)

x_plot_data.append(root_LG_G4_p_x)
y_plot_data.append(root_PM_MF_p_y)
# Out:
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:12, Support Value LG_G4: 65.0, Support Value LG_G4_C60: 96.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:7, Support Value LG_G4: 66.0, Support Value LG_G4_C60: 97.0
# Clade: elephantulus_edwardii:elephantulus_myurus:elephantulus_sp_vb001:3, Support Value LG_G4: 67.0, Support Value LG_G4_C60: 98.0
# Clade: elephantulus_edwardii:1, Support Value LG_G4: 68.0, Support Value LG_G4_C60: 99.0
# Clade: elephantulus_myurus:elephantulus_sp_vb001:2, Support Value LG_G4: 68.0, Support Value LG_G4_C60: 99.0
# Clade: elephantulus_sp_vb001:1, Support Value LG_G4: 69.0, Support Value LG_G4_C60: 100.0
# Clade: elephantulus_myurus:1, Support Value LG_G4: 69.0, Support Value LG_G4_C60: 100.0
# Clade: elephantulus_brachyrhynchus:elephantulus_intufi:elephantulus_rufescens:elephantulus_rupestris:4, Support Value LG_G4: 67.0, Support Value LG_G4_C60: 98.0
# Clade: elephantulus_intufi:elephantulus_rupestris:2, Support Value LG_G4: 70.0, Support Value LG_G4_C60: 101.0
# Clade: elephantulus_intufi:1, Support Value LG_G4: 71.0, Support Value LG_G4_C60: 102.0
# Clade: elephantulus_rupestris:1, Support Value LG_G4: 71.0, Support Value LG_G4_C60: 102.0
# Clade: elephantulus_brachyrhynchus:elephantulus_rufescens:2, Support Value LG_G4: 70.0, Support Value LG_G4_C60: 101.0
# Clade: elephantulus_brachyrhynchus:1, Support Value LG_G4: 72.0, Support Value LG_G4_C60: 103.0
# Clade: elephantulus_rufescens:1, Support Value LG_G4: 72.0, Support Value LG_G4_C60: 103.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:5, Support Value LG_G4: 66.0, Support Value LG_G4_C60: 97.0
# Clade: petrodromus_tetradactylus:petrosaltator_rozeti:2, Support Value LG_G4: 73.0, Support Value LG_G4_C60: 104.0
# Clade: petrosaltator_rozeti:1, Support Value LG_G4: 74.0, Support Value LG_G4_C60: 105.0
# Clade: petrodromus_tetradactylus:1, Support Value LG_G4: 74.0, Support Value LG_G4_C60: 105.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:3, Support Value LG_G4: 73.0, Support Value LG_G4_C60: 104.0
# Clade: macroscelides_flavicaudatus:macroscelides_proboscideus:2, Support Value LG_G4: 75.0, Support Value LG_G4_C60: 106.0
# Clade: macroscelides_flavicaudatus:1, Support Value LG_G4: 76.0, Support Value LG_G4_C60: 107.0
# Clade: macroscelides_proboscideus:1, Support Value LG_G4: 76.0, Support Value LG_G4_C60: 107.0
# Clade: macroscelides_micus:1, Support Value LG_G4: 75.0, Support Value LG_G4_C60: 106.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:3, Support Value LG_G4: 65.0, Support Value LG_G4_C60: 96.0
# Clade: rhynchocyon_udzungwensis:1, Support Value LG_G4: 77.0, Support Value LG_G4_C60: 108.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:2, Support Value LG_G4: 77.0, Support Value LG_G4_C60: 108.0
# Clade: rhynchocyon_cirnei_reichardi:1, Support Value LG_G4: 78.0, Support Value LG_G4_C60: 109.0
# Clade: rhynchocyon_petersi:1, Support Value LG_G4: 78.0, Support Value LG_G4_C60: 109.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:oryzorictes:potamogale_velox:setifer_setosus:tenrec_ecaudatus:15, Support Value LG_G4: 79.0, Support Value LG_G4_C60: 65.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:setifer_setosus:tenrec_ecaudatus:13, Support Value LG_G4: 80.0, Support Value LG_G4_C60: 82.0
# Clade: echinops_telfairi:hemicentetes_semispinosus:setifer_setosus:tenrec_ecaudatus:4, Support Value LG_G4: 81.0, Support Value LG_G4_C60: 83.0
# Clade: echinops_telfairi:setifer_setosus:2, Support Value LG_G4: 82.0, Support Value LG_G4_C60: 84.0
# Clade: echinops_telfairi:1, Support Value LG_G4: 83.0, Support Value LG_G4_C60: 86.0
# Clade: setifer_setosus:1, Support Value LG_G4: 83.0, Support Value LG_G4_C60: 86.0
# Clade: hemicentetes_semispinosus:tenrec_ecaudatus:2, Support Value LG_G4: 82.0, Support Value LG_G4_C60: 84.0
# Clade: tenrec_ecaudatus:1, Support Value LG_G4: 84.0, Support Value LG_G4_C60: 85.0
# Clade: hemicentetes_semispinosus:1, Support Value LG_G4: 84.0, Support Value LG_G4_C60: 85.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:9, Support Value LG_G4: 81.0, Support Value LG_G4_C60: 83.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:8, Support Value LG_G4: 85.0, Support Value LG_G4_C60: 87.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:7, Support Value LG_G4: 86.0, Support Value LG_G4_C60: 88.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:4, Support Value LG_G4: 87.0, Support Value LG_G4_C60: 89.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:3, Support Value LG_G4: 88.0, Support Value LG_G4_C60: 90.0
# Clade: microgale_longicaudata:microgale_majori:2, Support Value LG_G4: 89.0, Support Value LG_G4_C60: 91.0
# Clade: microgale_longicaudata:1, Support Value LG_G4: 90.0, Support Value LG_G4_C60: 92.0
# Clade: microgale_majori:1, Support Value LG_G4: 90.0, Support Value LG_G4_C60: 92.0
# Clade: microgale_principula:1, Support Value LG_G4: 89.0, Support Value LG_G4_C60: 91.0
# Clade: microgale_pusilla:1, Support Value LG_G4: 88.0, Support Value LG_G4_C60: 90.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_talazaci:3, Support Value LG_G4: 87.0, Support Value LG_G4_C60: 89.0
# Clade: limnogale_mergulus:microgale_brevicaudata:2, Support Value LG_G4: 91.0, Support Value LG_G4_C60: 93.0
# Clade: microgale_brevicaudata:1, Support Value LG_G4: 92.0, Support Value LG_G4_C60: 94.0
# Clade: limnogale_mergulus:1, Support Value LG_G4: 92.0, Support Value LG_G4_C60: 94.0
# Clade: microgale_talazaci:1, Support Value LG_G4: 91.0, Support Value LG_G4_C60: 93.0
# Clade: geogale_aurita:1, Support Value LG_G4: 86.0, Support Value LG_G4_C60: 88.0
# Clade: oryzorictes:1, Support Value LG_G4: 85.0, Support Value LG_G4_C60: 87.0
# Clade: micropotamogale_lamottei:potamogale_velox:2, Support Value LG_G4: 80.0, Support Value LG_G4_C60: 82.0
# Clade: micropotamogale_lamottei:1, Support Value LG_G4: 93.0, Support Value LG_G4_C60: 95.0
# Clade: potamogale_velox:1, Support Value LG_G4: 93.0, Support Value LG_G4_C60: 95.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:17, Support Value LG_G4: 79.0, Support Value LG_G4_C60: 65.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:14, Support Value LG_G4: 94.0, Support Value LG_G4_C60: 66.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:neamblysomus_gunningi:neamblysomus_julianae:13, Support Value LG_G4: 95.0, Support Value LG_G4_C60: 67.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:8, Support Value LG_G4: 96.0, Support Value LG_G4_C60: 68.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:5, Support Value LG_G4: 97.0, Support Value LG_G4_C60: 73.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_septentrionalis:4, Support Value LG_G4: 98.0, Support Value LG_G4_C60: 74.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:3, Support Value LG_G4: 99.0, Support Value LG_G4_C60: 75.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:2, Support Value LG_G4: 100.0, Support Value LG_G4_C60: 76.0
# Clade: amblysomus_hottentotus:1, Support Value LG_G4: 101.0, Support Value LG_G4_C60: 77.0
# Clade: amblysomus_corriae:1, Support Value LG_G4: 101.0, Support Value LG_G4_C60: 77.0
# Clade: amblysomus_marleyi:1, Support Value LG_G4: 100.0, Support Value LG_G4_C60: 76.0
# Clade: amblysomus_septentrionalis:1, Support Value LG_G4: 99.0, Support Value LG_G4_C60: 75.0
# Clade: amblysomus_robustus:1, Support Value LG_G4: 98.0, Support Value LG_G4_C60: 74.0
# Clade: carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:3, Support Value LG_G4: 97.0, Support Value LG_G4_C60: 73.0
# Clade: neamblysomus_gunningi:neamblysomus_julianae:2, Support Value LG_G4: 102.0, Support Value LG_G4_C60: 78.0
# Clade: neamblysomus_julianae:1, Support Value LG_G4: 103.0, Support Value LG_G4_C60: 79.0
# Clade: neamblysomus_gunningi:1, Support Value LG_G4: 103.0, Support Value LG_G4_C60: 79.0
# Clade: carpitalpa_arendsi:1, Support Value LG_G4: 102.0, Support Value LG_G4_C60: 78.0
# Clade: calcochloris_obtusirostris:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:5, Support Value LG_G4: 96.0, Support Value LG_G4_C60: 68.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:chrysospalax_villosus:3, Support Value LG_G4: 104.0, Support Value LG_G4_C60: 69.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:2, Support Value LG_G4: 105.0, Support Value LG_G4_C60: 70.0
# Clade: chrysospalax_trevelyani:1, Support Value LG_G4: 106.0, Support Value LG_G4_C60: 71.0
# Clade: calcochloris_obtusirostris:1, Support Value LG_G4: 106.0, Support Value LG_G4_C60: 71.0
# Clade: chrysospalax_villosus:1, Support Value LG_G4: 105.0, Support Value LG_G4_C60: 70.0
# Clade: chlorotalpa_duthieae:chlorotalpa_sclateri:2, Support Value LG_G4: 104.0, Support Value LG_G4_C60: 69.0
# Clade: chlorotalpa_sclateri:1, Support Value LG_G4: 107.0, Support Value LG_G4_C60: 72.0
# Clade: chlorotalpa_duthieae:1, Support Value LG_G4: 107.0, Support Value LG_G4_C60: 72.0
# Clade: eremitalpa_granti:1, Support Value LG_G4: 95.0, Support Value LG_G4_C60: 67.0
# Clade: chrysochloris_asiatica:chrysochloris_stuhlmanni:cryptochloris_wintoni:3, Support Value LG_G4: 94.0, Support Value LG_G4_C60: 66.0
# Clade: chrysochloris_asiatica:cryptochloris_wintoni:2, Support Value LG_G4: 108.0, Support Value LG_G4_C60: 80.0
# Clade: chrysochloris_asiatica:1, Support Value LG_G4: 109.0, Support Value LG_G4_C60: 81.0
# Clade: cryptochloris_wintoni:1, Support Value LG_G4: 109.0, Support Value LG_G4_C60: 81.0
# Clade: chrysochloris_stuhlmanni:1, Support Value LG_G4: 108.0, Support Value LG_G4_C60: 80.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:12, Support Value LG_G4: 65.0, Support Value LG_G4_C60: 96.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:7, Support Value LG_G4: 66.0, Support Value LG_G4_C60: 97.0
# Clade: elephantulus_edwardii:elephantulus_myurus:elephantulus_sp_vb001:3, Support Value LG_G4: 67.0, Support Value LG_G4_C60: 98.0
# Clade: elephantulus_edwardii:1, Support Value LG_G4: 68.0, Support Value LG_G4_C60: 99.0
# Clade: elephantulus_myurus:elephantulus_sp_vb001:2, Support Value LG_G4: 68.0, Support Value LG_G4_C60: 99.0
# Clade: elephantulus_sp_vb001:1, Support Value LG_G4: 69.0, Support Value LG_G4_C60: 100.0
# Clade: elephantulus_myurus:1, Support Value LG_G4: 69.0, Support Value LG_G4_C60: 100.0
# Clade: elephantulus_brachyrhynchus:elephantulus_intufi:elephantulus_rufescens:elephantulus_rupestris:4, Support Value LG_G4: 67.0, Support Value LG_G4_C60: 98.0
# Clade: elephantulus_intufi:elephantulus_rupestris:2, Support Value LG_G4: 70.0, Support Value LG_G4_C60: 101.0
# Clade: elephantulus_intufi:1, Support Value LG_G4: 71.0, Support Value LG_G4_C60: 102.0
# Clade: elephantulus_rupestris:1, Support Value LG_G4: 71.0, Support Value LG_G4_C60: 102.0
# Clade: elephantulus_brachyrhynchus:elephantulus_rufescens:2, Support Value LG_G4: 70.0, Support Value LG_G4_C60: 101.0
# Clade: elephantulus_brachyrhynchus:1, Support Value LG_G4: 72.0, Support Value LG_G4_C60: 103.0
# Clade: elephantulus_rufescens:1, Support Value LG_G4: 72.0, Support Value LG_G4_C60: 103.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:5, Support Value LG_G4: 66.0, Support Value LG_G4_C60: 97.0
# Clade: petrodromus_tetradactylus:petrosaltator_rozeti:2, Support Value LG_G4: 73.0, Support Value LG_G4_C60: 104.0
# Clade: petrosaltator_rozeti:1, Support Value LG_G4: 74.0, Support Value LG_G4_C60: 105.0
# Clade: petrodromus_tetradactylus:1, Support Value LG_G4: 74.0, Support Value LG_G4_C60: 105.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:3, Support Value LG_G4: 73.0, Support Value LG_G4_C60: 104.0
# Clade: macroscelides_flavicaudatus:macroscelides_proboscideus:2, Support Value LG_G4: 75.0, Support Value LG_G4_C60: 106.0
# Clade: macroscelides_flavicaudatus:1, Support Value LG_G4: 76.0, Support Value LG_G4_C60: 107.0
# Clade: macroscelides_proboscideus:1, Support Value LG_G4: 76.0, Support Value LG_G4_C60: 107.0
# Clade: macroscelides_micus:1, Support Value LG_G4: 75.0, Support Value LG_G4_C60: 106.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:3, Support Value LG_G4: 65.0, Support Value LG_G4_C60: 96.0
# Clade: rhynchocyon_udzungwensis:1, Support Value LG_G4: 77.0, Support Value LG_G4_C60: 108.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:2, Support Value LG_G4: 77.0, Support Value LG_G4_C60: 108.0
# Clade: rhynchocyon_cirnei_reichardi:1, Support Value LG_G4: 78.0, Support Value LG_G4_C60: 109.0
# Clade: rhynchocyon_petersi:1, Support Value LG_G4: 78.0, Support Value LG_G4_C60: 109.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:oryzorictes:potamogale_velox:setifer_setosus:tenrec_ecaudatus:15, Support Value LG_G4: 79.0, Support Value LG_G4_C60: 65.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:setifer_setosus:tenrec_ecaudatus:13, Support Value LG_G4: 80.0, Support Value LG_G4_C60: 82.0
# Clade: echinops_telfairi:hemicentetes_semispinosus:setifer_setosus:tenrec_ecaudatus:4, Support Value LG_G4: 81.0, Support Value LG_G4_C60: 83.0
# Clade: echinops_telfairi:setifer_setosus:2, Support Value LG_G4: 82.0, Support Value LG_G4_C60: 84.0
# Clade: echinops_telfairi:1, Support Value LG_G4: 83.0, Support Value LG_G4_C60: 86.0
# Clade: setifer_setosus:1, Support Value LG_G4: 83.0, Support Value LG_G4_C60: 86.0
# Clade: hemicentetes_semispinosus:tenrec_ecaudatus:2, Support Value LG_G4: 82.0, Support Value LG_G4_C60: 84.0
# Clade: tenrec_ecaudatus:1, Support Value LG_G4: 84.0, Support Value LG_G4_C60: 85.0
# Clade: hemicentetes_semispinosus:1, Support Value LG_G4: 84.0, Support Value LG_G4_C60: 85.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:9, Support Value LG_G4: 81.0, Support Value LG_G4_C60: 83.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:8, Support Value LG_G4: 85.0, Support Value LG_G4_C60: 87.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:7, Support Value LG_G4: 86.0, Support Value LG_G4_C60: 88.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:4, Support Value LG_G4: 87.0, Support Value LG_G4_C60: 89.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:3, Support Value LG_G4: 88.0, Support Value LG_G4_C60: 90.0
# Clade: microgale_longicaudata:microgale_majori:2, Support Value LG_G4: 89.0, Support Value LG_G4_C60: 91.0
# Clade: microgale_longicaudata:1, Support Value LG_G4: 90.0, Support Value LG_G4_C60: 92.0
# Clade: microgale_majori:1, Support Value LG_G4: 90.0, Support Value LG_G4_C60: 92.0
# Clade: microgale_principula:1, Support Value LG_G4: 89.0, Support Value LG_G4_C60: 91.0
# Clade: microgale_pusilla:1, Support Value LG_G4: 88.0, Support Value LG_G4_C60: 90.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_talazaci:3, Support Value LG_G4: 87.0, Support Value LG_G4_C60: 89.0
# Clade: limnogale_mergulus:microgale_brevicaudata:2, Support Value LG_G4: 91.0, Support Value LG_G4_C60: 93.0
# Clade: microgale_brevicaudata:1, Support Value LG_G4: 92.0, Support Value LG_G4_C60: 94.0
# Clade: limnogale_mergulus:1, Support Value LG_G4: 92.0, Support Value LG_G4_C60: 94.0
# Clade: microgale_talazaci:1, Support Value LG_G4: 91.0, Support Value LG_G4_C60: 93.0
# Clade: geogale_aurita:1, Support Value LG_G4: 86.0, Support Value LG_G4_C60: 88.0
# Clade: oryzorictes:1, Support Value LG_G4: 85.0, Support Value LG_G4_C60: 87.0
# Clade: micropotamogale_lamottei:potamogale_velox:2, Support Value LG_G4: 80.0, Support Value LG_G4_C60: 82.0
# Clade: micropotamogale_lamottei:1, Support Value LG_G4: 93.0, Support Value LG_G4_C60: 95.0
# Clade: potamogale_velox:1, Support Value LG_G4: 93.0, Support Value LG_G4_C60: 95.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:17, Support Value LG_G4: 79.0, Support Value LG_G4_C60: 65.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:14, Support Value LG_G4: 94.0, Support Value LG_G4_C60: 66.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:neamblysomus_gunningi:neamblysomus_julianae:13, Support Value LG_G4: 95.0, Support Value LG_G4_C60: 67.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:8, Support Value LG_G4: 96.0, Support Value LG_G4_C60: 68.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:5, Support Value LG_G4: 97.0, Support Value LG_G4_C60: 73.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_septentrionalis:4, Support Value LG_G4: 98.0, Support Value LG_G4_C60: 74.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:3, Support Value LG_G4: 99.0, Support Value LG_G4_C60: 75.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:2, Support Value LG_G4: 100.0, Support Value LG_G4_C60: 76.0
# Clade: amblysomus_hottentotus:1, Support Value LG_G4: 101.0, Support Value LG_G4_C60: 77.0
# Clade: amblysomus_corriae:1, Support Value LG_G4: 101.0, Support Value LG_G4_C60: 77.0
# Clade: amblysomus_marleyi:1, Support Value LG_G4: 100.0, Support Value LG_G4_C60: 76.0
# Clade: amblysomus_septentrionalis:1, Support Value LG_G4: 99.0, Support Value LG_G4_C60: 75.0
# Clade: amblysomus_robustus:1, Support Value LG_G4: 98.0, Support Value LG_G4_C60: 74.0
# Clade: carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:3, Support Value LG_G4: 97.0, Support Value LG_G4_C60: 73.0
# Clade: neamblysomus_gunningi:neamblysomus_julianae:2, Support Value LG_G4: 102.0, Support Value LG_G4_C60: 78.0
# Clade: neamblysomus_julianae:1, Support Value LG_G4: 103.0, Support Value LG_G4_C60: 79.0
# Clade: neamblysomus_gunningi:1, Support Value LG_G4: 103.0, Support Value LG_G4_C60: 79.0
# Clade: carpitalpa_arendsi:1, Support Value LG_G4: 102.0, Support Value LG_G4_C60: 78.0
# Clade: calcochloris_obtusirostris:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:5, Support Value LG_G4: 96.0, Support Value LG_G4_C60: 68.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:chrysospalax_villosus:3, Support Value LG_G4: 104.0, Support Value LG_G4_C60: 69.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:2, Support Value LG_G4: 105.0, Support Value LG_G4_C60: 70.0
# Clade: chrysospalax_trevelyani:1, Support Value LG_G4: 106.0, Support Value LG_G4_C60: 71.0
# Clade: calcochloris_obtusirostris:1, Support Value LG_G4: 106.0, Support Value LG_G4_C60: 71.0
# Clade: chrysospalax_villosus:1, Support Value LG_G4: 105.0, Support Value LG_G4_C60: 70.0
# Clade: chlorotalpa_duthieae:chlorotalpa_sclateri:2, Support Value LG_G4: 104.0, Support Value LG_G4_C60: 69.0
# Clade: chlorotalpa_sclateri:1, Support Value LG_G4: 107.0, Support Value LG_G4_C60: 72.0
# Clade: chlorotalpa_duthieae:1, Support Value LG_G4: 107.0, Support Value LG_G4_C60: 72.0
# Clade: eremitalpa_granti:1, Support Value LG_G4: 95.0, Support Value LG_G4_C60: 67.0
# Clade: chrysochloris_asiatica:chrysochloris_stuhlmanni:cryptochloris_wintoni:3, Support Value LG_G4: 94.0, Support Value LG_G4_C60: 66.0
# Clade: chrysochloris_asiatica:cryptochloris_wintoni:2, Support Value LG_G4: 108.0, Support Value LG_G4_C60: 80.0
# Clade: chrysochloris_asiatica:1, Support Value LG_G4: 109.0, Support Value LG_G4_C60: 81.0
# Clade: cryptochloris_wintoni:1, Support Value LG_G4: 109.0, Support Value LG_G4_C60: 81.0
# Clade: chrysochloris_stuhlmanni:1, Support Value LG_G4: 108.0, Support Value LG_G4_C60: 80.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:12, Support Value LG_G4: 65.0, Support Value LG_G4_C60: 96.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:7, Support Value LG_G4: 66.0, Support Value LG_G4_C60: 97.0
# Clade: elephantulus_edwardii:elephantulus_myurus:elephantulus_sp_vb001:3, Support Value LG_G4: 67.0, Support Value LG_G4_C60: 98.0
# Clade: elephantulus_edwardii:1, Support Value LG_G4: 68.0, Support Value LG_G4_C60: 99.0
# Clade: elephantulus_myurus:elephantulus_sp_vb001:2, Support Value LG_G4: 68.0, Support Value LG_G4_C60: 99.0
# Clade: elephantulus_sp_vb001:1, Support Value LG_G4: 69.0, Support Value LG_G4_C60: 100.0
# Clade: elephantulus_myurus:1, Support Value LG_G4: 69.0, Support Value LG_G4_C60: 100.0
# Clade: elephantulus_brachyrhynchus:elephantulus_intufi:elephantulus_rufescens:elephantulus_rupestris:4, Support Value LG_G4: 67.0, Support Value LG_G4_C60: 98.0
# Clade: elephantulus_intufi:elephantulus_rupestris:2, Support Value LG_G4: 70.0, Support Value LG_G4_C60: 101.0
# Clade: elephantulus_intufi:1, Support Value LG_G4: 71.0, Support Value LG_G4_C60: 102.0
# Clade: elephantulus_rupestris:1, Support Value LG_G4: 71.0, Support Value LG_G4_C60: 102.0
# Clade: elephantulus_brachyrhynchus:elephantulus_rufescens:2, Support Value LG_G4: 70.0, Support Value LG_G4_C60: 101.0
# Clade: elephantulus_brachyrhynchus:1, Support Value LG_G4: 72.0, Support Value LG_G4_C60: 103.0
# Clade: elephantulus_rufescens:1, Support Value LG_G4: 72.0, Support Value LG_G4_C60: 103.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:5, Support Value LG_G4: 66.0, Support Value LG_G4_C60: 97.0
# Clade: petrodromus_tetradactylus:petrosaltator_rozeti:2, Support Value LG_G4: 73.0, Support Value LG_G4_C60: 104.0
# Clade: petrosaltator_rozeti:1, Support Value LG_G4: 74.0, Support Value LG_G4_C60: 105.0
# Clade: petrodromus_tetradactylus:1, Support Value LG_G4: 74.0, Support Value LG_G4_C60: 105.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:3, Support Value LG_G4: 73.0, Support Value LG_G4_C60: 104.0
# Clade: macroscelides_flavicaudatus:macroscelides_proboscideus:2, Support Value LG_G4: 75.0, Support Value LG_G4_C60: 106.0
# Clade: macroscelides_flavicaudatus:1, Support Value LG_G4: 76.0, Support Value LG_G4_C60: 107.0
# Clade: macroscelides_proboscideus:1, Support Value LG_G4: 76.0, Support Value LG_G4_C60: 107.0
# Clade: macroscelides_micus:1, Support Value LG_G4: 75.0, Support Value LG_G4_C60: 106.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:3, Support Value LG_G4: 65.0, Support Value LG_G4_C60: 96.0
# Clade: rhynchocyon_udzungwensis:1, Support Value LG_G4: 77.0, Support Value LG_G4_C60: 108.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:2, Support Value LG_G4: 77.0, Support Value LG_G4_C60: 108.0
# Clade: rhynchocyon_cirnei_reichardi:1, Support Value LG_G4: 78.0, Support Value LG_G4_C60: 109.0
# Clade: rhynchocyon_petersi:1, Support Value LG_G4: 78.0, Support Value LG_G4_C60: 109.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:oryzorictes:potamogale_velox:setifer_setosus:tenrec_ecaudatus:15, Support Value LG_G4: 79.0, Support Value LG_G4_C60: 65.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:setifer_setosus:tenrec_ecaudatus:13, Support Value LG_G4: 80.0, Support Value LG_G4_C60: 82.0
# Clade: echinops_telfairi:hemicentetes_semispinosus:setifer_setosus:tenrec_ecaudatus:4, Support Value LG_G4: 81.0, Support Value LG_G4_C60: 83.0
# Clade: echinops_telfairi:setifer_setosus:2, Support Value LG_G4: 82.0, Support Value LG_G4_C60: 84.0
# Clade: echinops_telfairi:1, Support Value LG_G4: 83.0, Support Value LG_G4_C60: 86.0
# Clade: setifer_setosus:1, Support Value LG_G4: 83.0, Support Value LG_G4_C60: 86.0
# Clade: hemicentetes_semispinosus:tenrec_ecaudatus:2, Support Value LG_G4: 82.0, Support Value LG_G4_C60: 84.0
# Clade: tenrec_ecaudatus:1, Support Value LG_G4: 84.0, Support Value LG_G4_C60: 85.0
# Clade: hemicentetes_semispinosus:1, Support Value LG_G4: 84.0, Support Value LG_G4_C60: 85.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:9, Support Value LG_G4: 81.0, Support Value LG_G4_C60: 83.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:8, Support Value LG_G4: 85.0, Support Value LG_G4_C60: 87.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:7, Support Value LG_G4: 86.0, Support Value LG_G4_C60: 88.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:4, Support Value LG_G4: 87.0, Support Value LG_G4_C60: 89.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:3, Support Value LG_G4: 88.0, Support Value LG_G4_C60: 90.0
# Clade: microgale_longicaudata:microgale_majori:2, Support Value LG_G4: 89.0, Support Value LG_G4_C60: 91.0
# Clade: microgale_longicaudata:1, Support Value LG_G4: 90.0, Support Value LG_G4_C60: 92.0
# Clade: microgale_majori:1, Support Value LG_G4: 90.0, Support Value LG_G4_C60: 92.0
# Clade: microgale_principula:1, Support Value LG_G4: 89.0, Support Value LG_G4_C60: 91.0
# Clade: microgale_pusilla:1, Support Value LG_G4: 88.0, Support Value LG_G4_C60: 90.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_talazaci:3, Support Value LG_G4: 87.0, Support Value LG_G4_C60: 89.0
# Clade: limnogale_mergulus:microgale_brevicaudata:2, Support Value LG_G4: 91.0, Support Value LG_G4_C60: 93.0
# Clade: microgale_brevicaudata:1, Support Value LG_G4: 92.0, Support Value LG_G4_C60: 94.0
# Clade: limnogale_mergulus:1, Support Value LG_G4: 92.0, Support Value LG_G4_C60: 94.0
# Clade: microgale_talazaci:1, Support Value LG_G4: 91.0, Support Value LG_G4_C60: 93.0
# Clade: geogale_aurita:1, Support Value LG_G4: 86.0, Support Value LG_G4_C60: 88.0
# Clade: oryzorictes:1, Support Value LG_G4: 85.0, Support Value LG_G4_C60: 87.0
# Clade: micropotamogale_lamottei:potamogale_velox:2, Support Value LG_G4: 80.0, Support Value LG_G4_C60: 82.0
# Clade: micropotamogale_lamottei:1, Support Value LG_G4: 93.0, Support Value LG_G4_C60: 95.0
# Clade: potamogale_velox:1, Support Value LG_G4: 93.0, Support Value LG_G4_C60: 95.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:17, Support Value LG_G4: 79.0, Support Value LG_G4_C60: 65.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:14, Support Value LG_G4: 94.0, Support Value LG_G4_C60: 66.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:neamblysomus_gunningi:neamblysomus_julianae:13, Support Value LG_G4: 95.0, Support Value LG_G4_C60: 67.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:8, Support Value LG_G4: 96.0, Support Value LG_G4_C60: 68.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:5, Support Value LG_G4: 97.0, Support Value LG_G4_C60: 73.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_septentrionalis:4, Support Value LG_G4: 98.0, Support Value LG_G4_C60: 74.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:3, Support Value LG_G4: 99.0, Support Value LG_G4_C60: 75.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:2, Support Value LG_G4: 100.0, Support Value LG_G4_C60: 76.0
# Clade: amblysomus_hottentotus:1, Support Value LG_G4: 101.0, Support Value LG_G4_C60: 77.0
# Clade: amblysomus_corriae:1, Support Value LG_G4: 101.0, Support Value LG_G4_C60: 77.0
# Clade: amblysomus_marleyi:1, Support Value LG_G4: 100.0, Support Value LG_G4_C60: 76.0
# Clade: amblysomus_septentrionalis:1, Support Value LG_G4: 99.0, Support Value LG_G4_C60: 75.0
# Clade: amblysomus_robustus:1, Support Value LG_G4: 98.0, Support Value LG_G4_C60: 74.0
# Clade: carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:3, Support Value LG_G4: 97.0, Support Value LG_G4_C60: 73.0
# Clade: neamblysomus_gunningi:neamblysomus_julianae:2, Support Value LG_G4: 102.0, Support Value LG_G4_C60: 78.0
# Clade: neamblysomus_julianae:1, Support Value LG_G4: 103.0, Support Value LG_G4_C60: 79.0
# Clade: neamblysomus_gunningi:1, Support Value LG_G4: 103.0, Support Value LG_G4_C60: 79.0
# Clade: carpitalpa_arendsi:1, Support Value LG_G4: 102.0, Support Value LG_G4_C60: 78.0
# Clade: calcochloris_obtusirostris:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:5, Support Value LG_G4: 96.0, Support Value LG_G4_C60: 68.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:chrysospalax_villosus:3, Support Value LG_G4: 104.0, Support Value LG_G4_C60: 69.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:2, Support Value LG_G4: 105.0, Support Value LG_G4_C60: 70.0
# Clade: chrysospalax_trevelyani:1, Support Value LG_G4: 106.0, Support Value LG_G4_C60: 71.0
# Clade: calcochloris_obtusirostris:1, Support Value LG_G4: 106.0, Support Value LG_G4_C60: 71.0
# Clade: chrysospalax_villosus:1, Support Value LG_G4: 105.0, Support Value LG_G4_C60: 70.0
# Clade: chlorotalpa_duthieae:chlorotalpa_sclateri:2, Support Value LG_G4: 104.0, Support Value LG_G4_C60: 69.0
# Clade: chlorotalpa_sclateri:1, Support Value LG_G4: 107.0, Support Value LG_G4_C60: 72.0
# Clade: chlorotalpa_duthieae:1, Support Value LG_G4: 107.0, Support Value LG_G4_C60: 72.0
# Clade: eremitalpa_granti:1, Support Value LG_G4: 95.0, Support Value LG_G4_C60: 67.0
# Clade: chrysochloris_asiatica:chrysochloris_stuhlmanni:cryptochloris_wintoni:3, Support Value LG_G4: 94.0, Support Value LG_G4_C60: 66.0
# Clade: chrysochloris_asiatica:cryptochloris_wintoni:2, Support Value LG_G4: 108.0, Support Value LG_G4_C60: 80.0
# Clade: chrysochloris_asiatica:1, Support Value LG_G4: 109.0, Support Value LG_G4_C60: 81.0
# Clade: cryptochloris_wintoni:1, Support Value LG_G4: 109.0, Support Value LG_G4_C60: 81.0
# Clade: chrysochloris_stuhlmanni:1, Support Value LG_G4: 108.0, Support Value LG_G4_C60: 80.0

# %%
x = x_plot_data
y = y_plot_data

# Coordinates of the points to be marked
points_to_mark = [(-7, -7), (4, 4), (0, 0)]
labels = ['Young calibration ~ B(0.0533,0.2304)', 'Middle calibration ~ B(0.2304,0.5600)', 'Root calibration ~ ST(1.6419,0.4248,12.6518,1714.5649)']
colors = ['red', 'lightgreen', 'blue']

# Creating a new 3x4 subplot grid with different y-axis titles for each plot
fig, axes = plt.subplots(3, 3, figsize=(20, 20), sharex=True, sharey=True)

# Adding scatter plots to each subplot
for i, ax in enumerate(axes.flat):
    ax.scatter(x[i], y[i], alpha=0.7)
    ax.plot([0, 3.3], [0, 3.3], 'k--', linewidth=1.5)  # Adding y=x line
    # ax.set_title(f'Plot {i+1}')

    # Adding different y-axis titles for each plot
    if(i==0):
        ax.set_title('Young calibration', fontsize=16)
        ax.set_ylabel('Posterior mean times (MixtureFinder)', fontsize=16)
    if(i==1):
        ax.set_title('Middle calibration', fontsize=16)
    if(i==2):
        ax.set_title('Root calibration', fontsize=16)
    if(i==3):
         ax.set_ylabel('Posterior mean times (ModelFinder [-Q])', fontsize=16)
    if(i==6):
         ax.set_ylabel('Posterior mean times (ModelFinder [-p])', fontsize=16)
    
    

    # Marking the given points in each subplot
    for (px, py), color in zip(points_to_mark, colors):
        ax.scatter(x[i][px], y[i][py], color=color, marker='o', s=100, zorder=3)

# Common labels
fig.text(0.5, 0.08, 'Posterior mean times (GTR+G4)', ha='center', fontsize=16)
# fig.text(0.04, 0.5, 'Common Y axis', va='center', rotation='vertical', fontsize=16)

# Adding a label below the x-axis title for all the subplots with colored dots
fig.text(0.5, 0.01, 'Highlighted Points: ', ha='center', fontsize=14, color='blue')
for label, color in zip(labels, colors):
    plt.scatter([], [], color=color, marker='o', s=100, label=label)
fig.legend(loc='lower center', ncol=3, fontsize=12)

plt.tight_layout(rect=[0.05, 0.1, 1, 1])
# plt.show()
plt.savefig('./afrotheria_posterior_all_plots.png')
