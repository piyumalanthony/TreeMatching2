# %%
# Code to get all the Posterior mean (95% Equal-tail CI) (95% HPD CI) HPD-CI-width from ./xenarthra_mcmc_out.txt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# Read the file
file = open("MIX_MF_root_out.txt", "r")
lines = file.readlines()
file.close()

# Extract the data
data = []
mu_data = []
var_data = []

read_flag = False
for line in lines:
    if line.startswith("Posterior"):
        read_flag = True
    if read_flag and line.startswith("t"):
        data.append(line)
    if read_flag and line.startswith("mu"):
        mu_data.append(line)
    if read_flag and line.startswith("sigma"):
        var_data.append(line)

# %%
data
# Out:
# ['t_n61          2.5200 ( 1.9012,  3.2031) ( 1.8700,  3.1673)  1.2973 (Jnode 118)\n',
#  't_n62          2.4438 ( 1.8446,  3.1105) ( 1.8009,  3.0633)  1.2625 (Jnode 117)\n',
#  't_n63          2.3210 ( 1.7428,  2.9607) ( 1.7097,  2.9172)  1.2075 (Jnode 116)\n',
#  't_n64          2.2897 ( 1.7196,  2.9241) ( 1.6984,  2.8945)  1.1961 (Jnode 115)\n',
#  't_n65          2.2087 ( 1.6567,  2.8215) ( 1.6215,  2.7809)  1.1594 (Jnode 114)\n',
#  't_n66          1.2710 ( 0.8540,  1.7544) ( 0.8324,  1.7264)  0.8939 (Jnode 113)\n',
#  't_n67          1.1501 ( 0.7596,  1.6136) ( 0.7312,  1.5784)  0.8472 (Jnode 112)\n',
#  't_n68          1.0473 ( 0.6817,  1.4897) ( 0.6741,  1.4774)  0.8033 (Jnode 111)\n',
#  't_n69          0.9324 ( 0.5670,  1.3671) ( 0.5501,  1.3425)  0.7924 (Jnode 110)\n',
#  't_n70          0.5833 ( 0.2527,  1.0178) ( 0.2249,  0.9776)  0.7527 (Jnode 109)\n',
#  't_n71          0.3456 ( 0.1158,  0.6998) ( 0.0890,  0.6433)  0.5544 (Jnode 108)\n',
#  't_n72          0.1449 ( 0.0085,  0.4610) ( 0.0000,  0.3872)  0.3872 (Jnode 107)\n',
#  't_n73          0.6964 ( 0.3829,  1.0937) ( 0.3554,  1.0567)  0.7013 (Jnode 106)\n',
#  't_n74          0.2567 ( 0.0754,  0.5463) ( 0.0472,  0.4904)  0.4432 (Jnode 105)\n',
#  't_n75          0.1821 ( 0.0440,  0.4184) ( 0.0301,  0.3775)  0.3474 (Jnode 104)\n',
#  't_n76          0.1297 ( 0.0232,  0.3296) ( 0.0090,  0.2882)  0.2791 (Jnode 103)\n',
#  't_n77          0.0714 ( 0.0033,  0.2320) ( 0.0000,  0.1910)  0.1910 (Jnode 102)\n',
#  't_n78          0.4349 ( 0.1778,  0.7899) ( 0.1544,  0.7533)  0.5990 (Jnode 101)\n',
#  't_n79          0.1324 ( 0.0229,  0.3435) ( 0.0076,  0.2991)  0.2915 (Jnode 100)\n',
#  't_n80          0.6306 ( 0.2783,  1.0800) ( 0.2448,  1.0378)  0.7930 (Jnode 99)\n',
#  't_n81          0.2925 ( 0.0466,  0.7279) ( 0.0208,  0.6473)  0.6265 (Jnode 98)\n',
#  't_n82          1.8130 ( 1.3227,  2.3652) ( 1.3002,  2.3325)  1.0323 (Jnode 97)\n',
#  't_n83          1.3036 ( 0.8911,  1.7873) ( 0.8751,  1.7635)  0.8884 (Jnode 96)\n',
#  't_n84          0.9667 ( 0.6143,  1.3976) ( 0.5917,  1.3636)  0.7719 (Jnode 95)\n',
#  't_n85          0.7772 ( 0.4569,  1.1817) ( 0.4307,  1.1432)  0.7125 (Jnode 94)\n',
#  't_n86          0.4056 ( 0.1818,  0.7303) ( 0.1578,  0.6897)  0.5319 (Jnode 93)\n',
#  't_n87          1.0652 ( 0.6964,  1.5119) ( 0.6733,  1.4777)  0.8044 (Jnode 92)\n',
#  't_n88          1.0128 ( 0.6548,  1.4480) ( 0.6196,  1.4044)  0.7848 (Jnode 91)\n',
#  't_n89          0.6220 ( 0.3623,  0.9675) ( 0.3439,  0.9343)  0.5905 (Jnode 90)\n',
#  't_n90          0.3140 ( 0.1575,  0.5480) ( 0.1440,  0.5205)  0.3765 (Jnode 89)\n',
#  't_n91          0.2243 ( 0.1093,  0.4019) ( 0.0974,  0.3762)  0.2789 (Jnode 88)\n',
#  't_n92          0.1074 ( 0.0490,  0.2059) ( 0.0407,  0.1872)  0.1465 (Jnode 87)\n',
#  't_n93          0.4976 ( 0.2516,  0.8258) ( 0.2288,  0.7920)  0.5632 (Jnode 86)\n',
#  't_n94          0.3676 ( 0.1763,  0.6434) ( 0.1522,  0.6062)  0.4540 (Jnode 85)\n',
#  't_n95          0.5962 ( 0.1940,  1.1705) ( 0.1480,  1.0924)  0.9444 (Jnode 84)\n',
#  't_n96          1.7763 ( 1.2687,  2.3448) ( 1.2389,  2.3077)  1.0688 (Jnode 83)\n',
#  't_n97          0.9978 ( 0.5922,  1.4825) ( 0.5620,  1.4457)  0.8838 (Jnode 82)\n',
#  't_n98          0.8701 ( 0.5060,  1.3183) ( 0.4776,  1.2778)  0.8002 (Jnode 81)\n',
#  't_n99          0.4865 ( 0.2447,  0.8306) ( 0.2104,  0.7789)  0.5685 (Jnode 80)\n',
#  't_n100         0.0297 ( 0.0094,  0.0756) ( 0.0063,  0.0642)  0.0579 (Jnode 79)\n',
#  't_n101         0.7585 ( 0.4334,  1.1659) ( 0.4234,  1.1463)  0.7229 (Jnode 78)\n',
#  't_n102         0.5737 ( 0.2939,  0.9469) ( 0.2685,  0.9032)  0.6348 (Jnode 77)\n',
#  't_n103         0.1903 ( 0.0759,  0.3906) ( 0.0600,  0.3537)  0.2936 (Jnode 76)\n',
#  't_n104         0.8330 ( 0.4805,  1.2701) ( 0.4530,  1.2302)  0.7772 (Jnode 75)\n',
#  't_n105         0.5416 ( 0.2870,  0.8946) ( 0.2580,  0.8509)  0.5929 (Jnode 74)\n',
#  't_n106         0.6489 ( 0.3611,  1.0298) ( 0.3350,  0.9885)  0.6535 (Jnode 73)\n',
#  't_n107         0.1910 ( 0.0826,  0.3769) ( 0.0677,  0.3450)  0.2774 (Jnode 72)\n',
#  't_n108         0.0673 ( 0.0122,  0.2139) ( 0.0050,  0.1737)  0.1687 (Jnode 71)\n',
#  't_n109         0.0177 ( 0.0019,  0.0671) ( 0.0003,  0.0518)  0.0515 (Jnode 70)\n',
#  't_n110         2.2118 ( 1.6377,  2.8456) ( 1.6058,  2.8043)  1.1985 (Jnode 69)\n',
#  't_n111         2.1596 ( 1.5865,  2.7869) ( 1.5621,  2.7557)  1.1936 (Jnode 68)\n',
#  't_n112         0.8105 ( 0.2602,  1.5354) ( 0.2071,  1.4535)  1.2464 (Jnode 67)\n',
#  't_n113         0.4822 ( 0.1653,  0.9699) ( 0.1250,  0.8917)  0.7667 (Jnode 66)\n',
#  't_n114         0.3815 ( 0.1288,  0.7971) ( 0.0961,  0.7246)  0.6285 (Jnode 65)\n',
#  't_n115         0.1783 ( 0.0505,  0.4278) ( 0.0344,  0.3794)  0.3450 (Jnode 64)\n',
#  't_n116         0.8067 ( 0.3956,  1.3398) ( 0.3559,  1.2850)  0.9291 (Jnode 63)\n',
#  't_n117         0.4524 ( 0.1742,  0.8787) ( 0.1377,  0.8160)  0.6783 (Jnode 62)\n',
#  't_n118         0.3384 ( 0.0960,  0.7567) ( 0.0618,  0.6744)  0.6126 (Jnode 61)\n',
#  't_n119         0.0901 ( 0.0202,  0.2414) ( 0.0114,  0.2054)  0.1940 (Jnode 60)\n']

# %%
node_name = []
posterior_mean_iqtree = []
posterior_mean_baseml = []

posterior_mean_mu_iqtree = []
posterior_mean_mu_baseml = []

posterior_mean_var_iqtree = []
posterior_mean_var_baseml = []

lower_ci_iqtree = []
upper_ci_iqtree = []

lower_ci_mu_iqtree = []
upper_ci_mu_iqtree = []

lower_ci_var_iqtree = []
upper_ci_var_iqtree = []

# Credible intervals for McmcDate
lower_ci_baseml = []
upper_ci_baseml = []

lower_ci_mu_baseml = []
upper_ci_mu_baseml = []

lower_ci_var_baseml = []
upper_ci_var_baseml = []

# %%
model1_mean_times = {}
for line in data:
    line = line.strip().split()
    node_name.append(line[0])
    posterior_mean_iqtree.append(float(line[1]))
    model1_mean_times[int(line[0][3:])] = float(line[1])
    model1_mean_times[int(line[0][3:])] = float(line[1])
#     if line[3].startswith('('):
#         lower_ci_iqtree.append(float(line[3][1:-1]))
#     else:
#         lower_ci_iqtree.append(float(line[3][1:-1]))
#     if line[4].startswith('('):
#         upper_ci_iqtree.append(float(line[4][1:-1]))
#     else:
#         upper_ci_iqtree.append(float(line[4][:-1]))
#     # posterior_mean_baseml.append(float(line[4]))
#     # lower_ci_baseml.append(float(line[5]))
#     # upper_ci_baseml.append(float(line[6]))
# 
# for line in mu_data:
#     line = line.strip().split()
#     # node_name.append(line[0])
#     posterior_mean_mu_iqtree.append(float(line[1]))
#     lower_ci_mu_iqtree.append(float(line[3][:-1]))
#     upper_ci_mu_iqtree.append(float(line[4][:-1]))
#
# for line in var_data:
#     line = line.strip().split()
#     # node_name.append(line[0])
#     posterior_mean_var_iqtree.append(float(line[1]))
#     lower_ci_var_iqtree.append(float(line[3][:-1]))
#     upper_ci_var_iqtree.append(float(line[4][:-1]))
for line in data:
    line = line.strip().split()
    node_name.append(line[0])
    posterior_mean_iqtree.append(float(line[1]))
#     if line[3].startswith('('):
#         lower_ci_iqtree.append(float(line[3][1:-1]))
#     else:
#         lower_ci_iqtree.append(float(line[3][1:-1]))
#     if line[4].startswith('('):
#         upper_ci_iqtree.append(float(line[4][1:-1]))
#     else:
#         upper_ci_iqtree.append(float(line[4][:-1]))
#     # posterior_mean_baseml.append(float(line[4]))
#     # lower_ci_baseml.append(float(line[5]))
#     # upper_ci_baseml.append(float(line[6]))
# 
# for line in mu_data:
#     line = line.strip().split()
#     # node_name.append(line[0])
#     posterior_mean_mu_iqtree.append(float(line[1]))
#     lower_ci_mu_iqtree.append(float(line[3][:-1]))
#     upper_ci_mu_iqtree.append(float(line[4][:-1]))
#
# for line in var_data:
#     line = line.strip().split()
#     # node_name.append(line[0])
#     posterior_mean_var_iqtree.append(float(line[1]))
#     lower_ci_var_iqtree.append(float(line[3][:-1]))
#     upper_ci_var_iqtree.append(float(line[4][:-1]))

# %%
node_name
# Out:
# ['t_n61',
#  't_n62',
#  't_n63',
#  't_n64',
#  't_n65',
#  't_n66',
#  't_n67',
#  't_n68',
#  't_n69',
#  't_n70',
#  't_n71',
#  't_n72',
#  't_n73',
#  't_n74',
#  't_n75',
#  't_n76',
#  't_n77',
#  't_n78',
#  't_n79',
#  't_n80',
#  't_n81',
#  't_n82',
#  't_n83',
#  't_n84',
#  't_n85',
#  't_n86',
#  't_n87',
#  't_n88',
#  't_n89',
#  't_n90',
#  't_n91',
#  't_n92',
#  't_n93',
#  't_n94',
#  't_n95',
#  't_n96',
#  't_n97',
#  't_n98',
#  't_n99',
#  't_n100',
#  't_n101',
#  't_n102',
#  't_n103',
#  't_n104',
#  't_n105',
#  't_n106',
#  't_n107',
#  't_n108',
#  't_n109',
#  't_n110',
#  't_n111',
#  't_n112',
#  't_n113',
#  't_n114',
#  't_n115',
#  't_n116',
#  't_n117',
#  't_n118',
#  't_n119',
#  't_n61',
#  't_n62',
#  't_n63',
#  't_n64',
#  't_n65',
#  't_n66',
#  't_n67',
#  't_n68',
#  't_n69',
#  't_n70',
#  't_n71',
#  't_n72',
#  't_n73',
#  't_n74',
#  't_n75',
#  't_n76',
#  't_n77',
#  't_n78',
#  't_n79',
#  't_n80',
#  't_n81',
#  't_n82',
#  't_n83',
#  't_n84',
#  't_n85',
#  't_n86',
#  't_n87',
#  't_n88',
#  't_n89',
#  't_n90',
#  't_n91',
#  't_n92',
#  't_n93',
#  't_n94',
#  't_n95',
#  't_n96',
#  't_n97',
#  't_n98',
#  't_n99',
#  't_n100',
#  't_n101',
#  't_n102',
#  't_n103',
#  't_n104',
#  't_n105',
#  't_n106',
#  't_n107',
#  't_n108',
#  't_n109',
#  't_n110',
#  't_n111',
#  't_n112',
#  't_n113',
#  't_n114',
#  't_n115',
#  't_n116',
#  't_n117',
#  't_n118',
#  't_n119']

# %%
posterior_mean_iqtree
# Out:
# [2.52,
#  2.4438,
#  2.321,
#  2.2897,
#  2.2087,
#  1.271,
#  1.1501,
#  1.0473,
#  0.9324,
#  0.5833,
#  0.3456,
#  0.1449,
#  0.6964,
#  0.2567,
#  0.1821,
#  0.1297,
#  0.0714,
#  0.4349,
#  0.1324,
#  0.6306,
#  0.2925,
#  1.813,
#  1.3036,
#  0.9667,
#  0.7772,
#  0.4056,
#  1.0652,
#  1.0128,
#  0.622,
#  0.314,
#  0.2243,
#  0.1074,
#  0.4976,
#  0.3676,
#  0.5962,
#  1.7763,
#  0.9978,
#  0.8701,
#  0.4865,
#  0.0297,
#  0.7585,
#  0.5737,
#  0.1903,
#  0.833,
#  0.5416,
#  0.6489,
#  0.191,
#  0.0673,
#  0.0177,
#  2.2118,
#  2.1596,
#  0.8105,
#  0.4822,
#  0.3815,
#  0.1783,
#  0.8067,
#  0.4524,
#  0.3384,
#  0.0901,
#  2.52,
#  2.4438,
#  2.321,
#  2.2897,
#  2.2087,
#  1.271,
#  1.1501,
#  1.0473,
#  0.9324,
#  0.5833,
#  0.3456,
#  0.1449,
#  0.6964,
#  0.2567,
#  0.1821,
#  0.1297,
#  0.0714,
#  0.4349,
#  0.1324,
#  0.6306,
#  0.2925,
#  1.813,
#  1.3036,
#  0.9667,
#  0.7772,
#  0.4056,
#  1.0652,
#  1.0128,
#  0.622,
#  0.314,
#  0.2243,
#  0.1074,
#  0.4976,
#  0.3676,
#  0.5962,
#  1.7763,
#  0.9978,
#  0.8701,
#  0.4865,
#  0.0297,
#  0.7585,
#  0.5737,
#  0.1903,
#  0.833,
#  0.5416,
#  0.6489,
#  0.191,
#  0.0673,
#  0.0177,
#  2.2118,
#  2.1596,
#  0.8105,
#  0.4822,
#  0.3815,
#  0.1783,
#  0.8067,
#  0.4524,
#  0.3384,
#  0.0901]

# %%
lower_ci_iqtree
# Out:
# []

# %%
upper_ci_iqtree
# Out:
# []

# %%
file_LG = open("GTR_G4_root_out.txt", "r")
lines1 = file_LG.readlines()
file_LG.close()

# Extract the data
data1 = []
mu_data1 = []
var_data1 = []

read_flag = False
for line in lines1:
    if line.startswith("Posterior"):
        read_flag = True
    if read_flag and line.startswith("t"):
        data1.append(line)
    if read_flag and line.startswith("mu"):
        mu_data1.append(line)
    if read_flag and line.startswith("sigma"):
        var_data1.append(line)

model2_mean_times = {}     
for line in data1:
    line = line.strip().split()
    # node_name.append(line[0])
    posterior_mean_baseml.append(float(line[1]))
    model2_mean_times[int(line[0][3:])] = float(line[1])
#     if line[3].startswith('('):
#         lower_ci_baseml.append(float(line[3][1:-1]))
#     else:
#          lower_ci_baseml.append(float(line[3][:-1]))
#     if line[4].startswith('('):
#         upper_ci_baseml.append(float(line[4][1:-1]))
#     else:
#          upper_ci_baseml.append(float(line[4][:-1]))
#         
#     
# for line in mu_data1:
#     line = line.strip().split()
#     # node_name.append(line[0])
#     posterior_mean_mu_baseml.append(float(line[1]))
#     lower_ci_mu_baseml.append(float(line[3][:-1]))
#     upper_ci_mu_baseml.append(float(line[4][:-1]))
    
# for line in var_data1:
#     line = line.strip().split()
#     # node_name.append(line[0])
#     posterior_mean_var_baseml.append(float(line[1]))
#     lower_ci_var_baseml.append(float(line[3][:-1]))
#     upper_ci_var_baseml.append(float(line[4][:-1]))

# %%
import matplotlib.pyplot as plt
import numpy as np

# # Example data
# # Posterior means for MCMCtree (x-axis) and McmcDate (y-axis)
# posterior_mean_mcmctree = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
# posterior_mean_mcmcdate = [110, 210, 310, 410, 510, 610, 710, 810, 910, 1010]
# 
# # Credible intervals for MCMCtree
# lower_ci_mcmctree = [90, 180, 270, 360, 450, 540, 630, 720, 810, 900]
# upper_ci_mcmctree = [110, 220, 330, 440, 550, 660, 770, 880, 990, 1100]
# 
# # Credible intervals for McmcDate
# lower_ci_mcmcdate = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
# upper_ci_mcmcdate = [120, 220, 320, 420, 520, 620, 720, 820, 920, 1020]

# Calculate error bars
# xerr = [np.array(lower_ci_baseml), 
#         np.array(upper_ci_baseml)]
# yerr = [np.array(lower_ci_iqtree), 
#         np.array(upper_ci_iqtree)]
# 
# # Plotting
# fig, ax = plt.subplots(figsize=(15, 15))
# ax.plot([-0.1,90], 
#         [-0.1, 90], 
#         'k--', label='y=x')
# ax.errorbar(posterior_mean_baseml, posterior_mean_iqtree, 
#             xerr=xerr, yerr=yerr, fmt='*', ecolor='r', capsize=3, label='95% HPD CI')
# 
# # Labels and title
# ax.set_xlabel('Posterior mean age LG [100 Mya]', fontsize=18)
# ax.set_ylabel('Posterior mean age LG+G4 [100 Mya]', fontsize=18)
# ax.set_title('Posterior mean age comparison between LG and LG+G4 models [t116 ~ B(1.25,2.482)]')
# ax.legend()
# 
# # Show plot
# # plt.show()
# plt.savefig('./animal_origin_posterior_mean_age_comparison_LG_G4_c11.png')

# %%
posterior_mean_baseml
# Out:
# [3.1263,
#  1.7379,
#  1.6833,
#  1.639,
#  1.2734,
#  0.6992,
#  0.5941,
#  0.3916,
#  0.0425,
#  0.4862,
#  0.3627,
#  0.1023,
#  0.6048,
#  0.4177,
#  0.4877,
#  0.1477,
#  0.0513,
#  0.0133,
#  1.533,
#  1.2387,
#  0.9032,
#  0.6941,
#  0.3581,
#  0.5715,
#  0.7453,
#  0.6981,
#  0.4698,
#  0.2744,
#  0.2046,
#  0.0848,
#  0.3936,
#  0.2932,
#  0.4409,
#  0.6722,
#  0.5382,
#  0.4203,
#  0.2792,
#  0.1098,
#  0.0806,
#  0.0599,
#  0.0379,
#  0.1961,
#  0.0666,
#  0.3905,
#  0.2701,
#  0.1802,
#  0.0513,
#  0.4247,
#  0.2702,
#  1.4401,
#  1.3458,
#  0.5548,
#  0.1385,
#  0.1091,
#  0.0359,
#  0.2995,
#  0.2299,
#  1.9709,
#  0.9138]

# %%
posterior_mean_iqtree
# Out:
# [2.52,
#  2.4438,
#  2.321,
#  2.2897,
#  2.2087,
#  1.271,
#  1.1501,
#  1.0473,
#  0.9324,
#  0.5833,
#  0.3456,
#  0.1449,
#  0.6964,
#  0.2567,
#  0.1821,
#  0.1297,
#  0.0714,
#  0.4349,
#  0.1324,
#  0.6306,
#  0.2925,
#  1.813,
#  1.3036,
#  0.9667,
#  0.7772,
#  0.4056,
#  1.0652,
#  1.0128,
#  0.622,
#  0.314,
#  0.2243,
#  0.1074,
#  0.4976,
#  0.3676,
#  0.5962,
#  1.7763,
#  0.9978,
#  0.8701,
#  0.4865,
#  0.0297,
#  0.7585,
#  0.5737,
#  0.1903,
#  0.833,
#  0.5416,
#  0.6489,
#  0.191,
#  0.0673,
#  0.0177,
#  2.2118,
#  2.1596,
#  0.8105,
#  0.4822,
#  0.3815,
#  0.1783,
#  0.8067,
#  0.4524,
#  0.3384,
#  0.0901,
#  2.52,
#  2.4438,
#  2.321,
#  2.2897,
#  2.2087,
#  1.271,
#  1.1501,
#  1.0473,
#  0.9324,
#  0.5833,
#  0.3456,
#  0.1449,
#  0.6964,
#  0.2567,
#  0.1821,
#  0.1297,
#  0.0714,
#  0.4349,
#  0.1324,
#  0.6306,
#  0.2925,
#  1.813,
#  1.3036,
#  0.9667,
#  0.7772,
#  0.4056,
#  1.0652,
#  1.0128,
#  0.622,
#  0.314,
#  0.2243,
#  0.1074,
#  0.4976,
#  0.3676,
#  0.5962,
#  1.7763,
#  0.9978,
#  0.8701,
#  0.4865,
#  0.0297,
#  0.7585,
#  0.5737,
#  0.1903,
#  0.833,
#  0.5416,
#  0.6489,
#  0.191,
#  0.0673,
#  0.0177,
#  2.2118,
#  2.1596,
#  0.8105,
#  0.4822,
#  0.3815,
#  0.1783,
#  0.8067,
#  0.4524,
#  0.3384,
#  0.0901]

# %%
# # Calculate error bars
# xerr = [np.array(lower_ci_baseml), 
#         np.array(upper_ci_baseml)]
# yerr = [np.array(lower_ci_iqtree), 
#         np.array(upper_ci_iqtree)]
# 
# # Plotting
# fig, ax = plt.subplots(figsize=(9 ,9))
# ax.plot([-0.1,3], 
#         [-0.1, 3], 
#         'k--', label='y=x')
# ax.plot(posterior_mean_baseml, posterior_mean_iqtree, 'o', label='Posterior mean age')
#  
# # Labels and title
# ax.set_xlabel('Posterior mean age GTR+G4 [100 Mya]', fontsize=18)
# ax.set_ylabel('Posterior mean age Partition MIX+MF [-Q] [100 Mya]', fontsize=18)
# # ax.set_title('Posterior mean age comparison between LG and Partition MF [-p] [t199 ~ B(10.3300,45.2000)]')
# ax.legend()
# 
# # point_x = posterior_mean_baseml[0]  # Example: first point in the list
# # point_y = posterior_mean_iqtree[0]  # Example: first point in the list
# # ax.annotate('Root age', xy=(point_x, point_y), xytext=(point_x - 0.1, point_y - 0.1), color='red')
# # Show plot
# # plt.show()
# plt.savefig('./afrotheria_posterior_mean_age_comparison_partition_MIX_MF_p_middle_scatter.png')

# %%
# fig, ax = plt.subplots(figsize=(9 ,9))
# ax.plot([0.01,0.04], 
#         [0.01, 0.04], 
#         'k--', label='y=x')
# ax.plot(posterior_mean_mu_baseml, posterior_mean_mu_iqtree, 'o', label='Posterior mean rates for partitions')
#  
# # Labels and title
# ax.set_xlabel('Posterior mean rate [LG]', fontsize=18)
# ax.set_ylabel('Posterior mean rate [LG+G4]', fontsize=18)
# ax.set_title('Posterior mean rate comparison between LG and LG+G4 [Cherry only calibration/IQ-TREE]')
# ax.legend()
# 
# # point_x = posterior_mean_baseml[0]  # Example: first point in the list
# # point_y = posterior_mean_iqtree[0]  # Example: first point in the list
# # ax.annotate('Root age', xy=(point_x, point_y), xytext=(point_x - 0.1, point_y - 0.1), color='red')
# # Show plot
# # plt.show()
# plt.savefig('./animal_origin__posterior_mean_rate_comparison_LG_G4_all_scatter.png')

# %%
import copy
from ete3 import Tree

iqtree_file = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/eucaryote-origin/complex-models-v3/LG_G4.tree"
mcmctree_file = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/eucaryote-origin/complex-models-v3/LG_G4_C60.tree"

tree_iqtree = Tree(iqtree_file)

iqtree_node_traversal = []
for node in tree_iqtree.traverse("preorder"):
    edge = node.get_edges()[0]
    clade_1 = list(edge[0])
    clade_2 = list(edge[1])
    node_name = clade_1 + clade_2
    node_name = [node.name for node in node_name]
    # node_name.sort()
    node_name = ':'.join(node_name)
    node.name = node_name
    iqtree_node_traversal.append(node.name)

tree_mcmctree = Tree(mcmctree_file)

mcmctree_node_traversal = []
for node in tree_mcmctree.traverse("preorder"):
    edge = node.get_edges()[0]
    clade_1 = list(edge[0])
    clade_2 = list(edge[1])
    node_name = clade_1 + clade_2
    node_name = [node.name for node in node_name]
    # node_name.sort()
    node_name = ':'.join(node_name)
    node.name = node_name
    mcmctree_node_traversal.append(node.name)

# %%
iqtree_node_traversal
# Out:
# ['Volvox:Staphylothermus_marinus:Chlorobium:Sulfolobus_solfataricus:Caldithrix:Bodo:Gemmatimonas:Caldivirga_maquilingensis:Latescibacteria:Pyrobaculum_aerophilum:Fibrobacter:Thermofilum_pendens:Trichomonas_vaginalis:Crenynpffa:Lentisphaera:Verrucomicrobium:Cenarchaeum_symbiosum:Chlamydia_trachomatis:Rhodopirellula_baltica:Nitrosopumilus_maritimus:Elusimicrobium:Nitrosoarchaeum_limnia:The09:Thalassiosira_pseudonana:Caldiarchaeum_subterraneum:Clostridium_acetobutylicum:Korarchaeum_cryptofilum:Treponema_pallidum:Chthonomonas:Archaeoglobus_fulgidus:Oscillochloris:Haloarcula_marismortui:Methanosarcina_mazei:Microgenomates:Parcubacteria:Thermoplasma_volcanium:Actinomadura:Elphidium:Methanomassiliicoccus_luminyensis:Methanothermobacter_thermautotro:Cylindrosperopsis:Methanopyrus_kandleri:Chlorogloeopsis:Physcomitrella:Synechocystis_sp._PCC6803:Methanococcus_jannaschii:Gloeobacter:Pyrococcus_furiosus:Candidatus:Jonquetella:Reticulomyxa:Hydra:Ar5:Dictyoglomus:Dictyostelium_discoideum:Caldisericum:Nanosalina:Arabidopsis_thaliana:Kosmotoga:Nanosalinarum:Homo_sapiens:Phytophthora_ramorum:Leishmania_major:DUSEL4:Ar15:Agaricus:Ar6:Ar13:Parvarchaeum_acidophilus:Nanoarchaeum:Cyanidioschyzon:Micrarchaeum_acidiphilum:Loki2:DUSEL3:Chondrus:Polysphondylium:Limulus:Chlamydomonas:Giardia_lamblia:Amphimedon:Oryza_sativa:Rhodopseudomonas_palustris:Rickettsia:Escherichia_coli:Campylobacter_jejuni:Cyanophora:Desulfurispirillum:Lokiarchaeum:Hyperthermus_butylicus:Acidobacterium:Paramecium:Aeropyrum_pernix:Thermodesulfatator:Tetrahymena:Ignicoccus_hospitalis:Thermodesulfovibrio:Loki3:Aquifex:Galdieria:Saccharomyces_cerevisiae:Ectocarpus:Batrachochytrium',
#  'Volvox:Staphylothermus_marinus:Sulfolobus_solfataricus:Bodo:Caldivirga_maquilingensis:Pyrobaculum_aerophilum:Thermofilum_pendens:Trichomonas_vaginalis:Crenynpffa:Cenarchaeum_symbiosum:Nitrosopumilus_maritimus:Nitrosoarchaeum_limnia:The09:Thalassiosira_pseudonana:Caldiarchaeum_subterraneum:Korarchaeum_cryptofilum:Archaeoglobus_fulgidus:Haloarcula_marismortui:Methanosarcina_mazei:Thermoplasma_volcanium:Elphidium:Methanomassiliicoccus_luminyensis:Methanothermobacter_thermautotro:Methanopyrus_kandleri:Physcomitrella:Methanococcus_jannaschii:Pyrococcus_furiosus:Reticulomyxa:Hydra:Ar5:Dictyostelium_discoideum:Nanosalina:Arabidopsis_thaliana:Nanosalinarum:Homo_sapiens:Phytophthora_ramorum:Leishmania_major:DUSEL4:Ar15:Agaricus:Ar6:Ar13:Parvarchaeum_acidophilus:Nanoarchaeum:Cyanidioschyzon:Micrarchaeum_acidiphilum:Loki2:DUSEL3:Chondrus:Polysphondylium:Limulus:Chlamydomonas:Giardia_lamblia:Amphimedon:Oryza_sativa:Cyanophora:Lokiarchaeum:Hyperthermus_butylicus:Paramecium:Aeropyrum_pernix:Tetrahymena:Ignicoccus_hospitalis:Loki3:Galdieria:Saccharomyces_cerevisiae:Ectocarpus:Batrachochytrium',
#  'Volvox:Staphylothermus_marinus:Phytophthora_ramorum:Leishmania_major:Sulfolobus_solfataricus:Bodo:Caldivirga_maquilingensis:Pyrobaculum_aerophilum:Agaricus:Thermofilum_pendens:Trichomonas_vaginalis:Crenynpffa:Cenarchaeum_symbiosum:Cyanidioschyzon:Loki2:Nitrosopumilus_maritimus:Chondrus:Nitrosoarchaeum_limnia:Polysphondylium:The09:Thalassiosira_pseudonana:Caldiarchaeum_subterraneum:Korarchaeum_cryptofilum:Archaeoglobus_fulgidus:Limulus:Chlamydomonas:Giardia_lamblia:Amphimedon:Haloarcula_marismortui:Methanosarcina_mazei:Oryza_sativa:Thermoplasma_volcanium:Elphidium:Methanomassiliicoccus_luminyensis:Cyanophora:Methanothermobacter_thermautotro:Lokiarchaeum:Methanopyrus_kandleri:Physcomitrella:Hyperthermus_butylicus:Methanococcus_jannaschii:Paramecium:Pyrococcus_furiosus:Aeropyrum_pernix:Tetrahymena:Ignicoccus_hospitalis:Loki3:Reticulomyxa:Galdieria:Saccharomyces_cerevisiae:Hydra:Ectocarpus:Dictyostelium_discoideum:Batrachochytrium:Arabidopsis_thaliana:Homo_sapiens',
#  'Volvox:Staphylothermus_marinus:Phytophthora_ramorum:Leishmania_major:Sulfolobus_solfataricus:Bodo:Caldivirga_maquilingensis:Pyrobaculum_aerophilum:Agaricus:Thermofilum_pendens:Trichomonas_vaginalis:Crenynpffa:Cenarchaeum_symbiosum:Cyanidioschyzon:Loki2:Nitrosopumilus_maritimus:Chondrus:Nitrosoarchaeum_limnia:Polysphondylium:The09:Thalassiosira_pseudonana:Caldiarchaeum_subterraneum:Korarchaeum_cryptofilum:Limulus:Chlamydomonas:Giardia_lamblia:Amphimedon:Oryza_sativa:Elphidium:Cyanophora:Lokiarchaeum:Physcomitrella:Hyperthermus_butylicus:Paramecium:Aeropyrum_pernix:Tetrahymena:Ignicoccus_hospitalis:Loki3:Reticulomyxa:Galdieria:Saccharomyces_cerevisiae:Hydra:Ectocarpus:Dictyostelium_discoideum:Batrachochytrium:Arabidopsis_thaliana:Homo_sapiens',
#  'Volvox:Staphylothermus_marinus:Phytophthora_ramorum:Leishmania_major:Sulfolobus_solfataricus:Bodo:Caldivirga_maquilingensis:Pyrobaculum_aerophilum:Agaricus:Thermofilum_pendens:Trichomonas_vaginalis:Crenynpffa:Cenarchaeum_symbiosum:Cyanidioschyzon:Loki2:Nitrosopumilus_maritimus:Chondrus:Nitrosoarchaeum_limnia:Polysphondylium:The09:Thalassiosira_pseudonana:Caldiarchaeum_subterraneum:Limulus:Chlamydomonas:Giardia_lamblia:Amphimedon:Oryza_sativa:Elphidium:Cyanophora:Lokiarchaeum:Physcomitrella:Hyperthermus_butylicus:Paramecium:Aeropyrum_pernix:Tetrahymena:Ignicoccus_hospitalis:Loki3:Reticulomyxa:Galdieria:Saccharomyces_cerevisiae:Hydra:Ectocarpus:Dictyostelium_discoideum:Batrachochytrium:Arabidopsis_thaliana:Homo_sapiens',
#  'Volvox:Phytophthora_ramorum:Leishmania_major:Bodo:Agaricus:Trichomonas_vaginalis:Cyanidioschyzon:Loki2:Chondrus:Polysphondylium:Thalassiosira_pseudonana:Limulus:Chlamydomonas:Giardia_lamblia:Amphimedon:Oryza_sativa:Elphidium:Cyanophora:Lokiarchaeum:Physcomitrella:Paramecium:Tetrahymena:Loki3:Reticulomyxa:Galdieria:Saccharomyces_cerevisiae:Hydra:Ectocarpus:Dictyostelium_discoideum:Batrachochytrium:Arabidopsis_thaliana:Homo_sapiens',
#  'Volvox:Limulus:Phytophthora_ramorum:Leishmania_major:Chlamydomonas:Giardia_lamblia:Amphimedon:Bodo:Oryza_sativa:Agaricus:Elphidium:Trichomonas_vaginalis:Cyanophora:Physcomitrella:Cyanidioschyzon:Paramecium:Chondrus:Tetrahymena:Polysphondylium:Reticulomyxa:Galdieria:Thalassiosira_pseudonana:Saccharomyces_cerevisiae:Ectocarpus:Hydra:Dictyostelium_discoideum:Batrachochytrium:Arabidopsis_thaliana:Homo_sapiens',
#  'Volvox:Phytophthora_ramorum:Leishmania_major:Chlamydomonas:Giardia_lamblia:Bodo:Oryza_sativa:Elphidium:Trichomonas_vaginalis:Cyanophora:Physcomitrella:Cyanidioschyzon:Paramecium:Chondrus:Tetrahymena:Reticulomyxa:Galdieria:Thalassiosira_pseudonana:Ectocarpus:Arabidopsis_thaliana',
#  'Volvox:Phytophthora_ramorum:Chlamydomonas:Oryza_sativa:Elphidium:Cyanophora:Physcomitrella:Cyanidioschyzon:Paramecium:Chondrus:Tetrahymena:Reticulomyxa:Galdieria:Thalassiosira_pseudonana:Ectocarpus:Arabidopsis_thaliana',
#  'Volvox:Physcomitrella:Cyanidioschyzon:Chlamydomonas:Chondrus:Oryza_sativa:Cyanophora:Galdieria:Arabidopsis_thaliana',
#  'Volvox:Physcomitrella:Cyanidioschyzon:Chlamydomonas:Chondrus:Oryza_sativa:Galdieria:Arabidopsis_thaliana',
#  'Volvox:Arabidopsis_thaliana:Physcomitrella:Oryza_sativa:Chlamydomonas',
#  'Volvox:Chlamydomonas',
#  'Volvox',
#  'Chlamydomonas',
#  'Oryza_sativa:Arabidopsis_thaliana:Physcomitrella',
#  'Oryza_sativa:Arabidopsis_thaliana',
#  'Oryza_sativa',
#  'Arabidopsis_thaliana',
#  'Physcomitrella',
#  'Galdieria:Chondrus:Cyanidioschyzon',
#  'Galdieria',
#  'Chondrus:Cyanidioschyzon',
#  'Chondrus',
#  'Cyanidioschyzon',
#  'Cyanophora',
#  'Paramecium:Phytophthora_ramorum:Tetrahymena:Reticulomyxa:Thalassiosira_pseudonana:Elphidium:Ectocarpus',
#  'Paramecium:Thalassiosira_pseudonana:Phytophthora_ramorum:Tetrahymena:Ectocarpus',
#  'Paramecium:Tetrahymena',
#  'Paramecium',
#  'Tetrahymena',
#  'Ectocarpus:Thalassiosira_pseudonana:Phytophthora_ramorum',
#  'Ectocarpus:Thalassiosira_pseudonana',
#  'Ectocarpus',
#  'Thalassiosira_pseudonana',
#  'Phytophthora_ramorum',
#  'Reticulomyxa:Elphidium',
#  'Reticulomyxa',
#  'Elphidium',
#  'Leishmania_major:Trichomonas_vaginalis:Bodo:Giardia_lamblia',
#  'Leishmania_major:Trichomonas_vaginalis:Bodo',
#  'Leishmania_major:Bodo',
#  'Leishmania_major',
#  'Bodo',
#  'Trichomonas_vaginalis',
#  'Giardia_lamblia',
#  'Limulus:Amphimedon:Polysphondylium:Agaricus:Saccharomyces_cerevisiae:Hydra:Dictyostelium_discoideum:Batrachochytrium:Homo_sapiens',
#  'Limulus:Amphimedon:Agaricus:Saccharomyces_cerevisiae:Hydra:Batrachochytrium:Homo_sapiens',
#  'Limulus:Homo_sapiens:Hydra:Amphimedon',
#  'Limulus:Hydra:Homo_sapiens',
#  'Limulus:Homo_sapiens',
#  'Limulus',
#  'Homo_sapiens',
#  'Hydra',
#  'Amphimedon',
#  'Agaricus:Batrachochytrium:Saccharomyces_cerevisiae',
#  'Agaricus:Saccharomyces_cerevisiae',
#  'Agaricus',
#  'Saccharomyces_cerevisiae',
#  'Batrachochytrium',
#  'Polysphondylium:Dictyostelium_discoideum',
#  'Polysphondylium',
#  'Dictyostelium_discoideum',
#  'Lokiarchaeum:Loki2:Loki3',
#  'Lokiarchaeum:Loki2',
#  'Lokiarchaeum',
#  'Loki2',
#  'Loki3',
#  'Hyperthermus_butylicus:Staphylothermus_marinus:Cenarchaeum_symbiosum:Sulfolobus_solfataricus:Aeropyrum_pernix:Nitrosopumilus_maritimus:Ignicoccus_hospitalis:Nitrosoarchaeum_limnia:Caldivirga_maquilingensis:The09:Pyrobaculum_aerophilum:Caldiarchaeum_subterraneum:Thermofilum_pendens:Crenynpffa',
#  'Hyperthermus_butylicus:Staphylothermus_marinus:Sulfolobus_solfataricus:Aeropyrum_pernix:Ignicoccus_hospitalis:Caldivirga_maquilingensis:Pyrobaculum_aerophilum:Thermofilum_pendens:Crenynpffa',
#  'Hyperthermus_butylicus:Staphylothermus_marinus:Sulfolobus_solfataricus:Aeropyrum_pernix:Ignicoccus_hospitalis:Caldivirga_maquilingensis:Pyrobaculum_aerophilum:Thermofilum_pendens',
#  'Hyperthermus_butylicus:Aeropyrum_pernix:Staphylothermus_marinus:Ignicoccus_hospitalis:Sulfolobus_solfataricus',
#  'Hyperthermus_butylicus:Aeropyrum_pernix:Staphylothermus_marinus:Ignicoccus_hospitalis',
#  'Hyperthermus_butylicus:Aeropyrum_pernix:Ignicoccus_hospitalis',
#  'Hyperthermus_butylicus:Aeropyrum_pernix',
#  'Hyperthermus_butylicus',
#  'Aeropyrum_pernix',
#  'Ignicoccus_hospitalis',
#  'Staphylothermus_marinus',
#  'Sulfolobus_solfataricus',
#  'Caldivirga_maquilingensis:Pyrobaculum_aerophilum:Thermofilum_pendens',
#  'Caldivirga_maquilingensis:Pyrobaculum_aerophilum',
#  'Caldivirga_maquilingensis',
#  'Pyrobaculum_aerophilum',
#  'Thermofilum_pendens',
#  'Crenynpffa',
#  'Cenarchaeum_symbiosum:The09:Nitrosopumilus_maritimus:Caldiarchaeum_subterraneum:Nitrosoarchaeum_limnia',
#  'Cenarchaeum_symbiosum:The09:Nitrosopumilus_maritimus:Nitrosoarchaeum_limnia',
#  'Cenarchaeum_symbiosum:Nitrosopumilus_maritimus:Nitrosoarchaeum_limnia',
#  'Cenarchaeum_symbiosum',
#  'Nitrosopumilus_maritimus:Nitrosoarchaeum_limnia',
#  'Nitrosopumilus_maritimus',
#  'Nitrosoarchaeum_limnia',
#  'The09',
#  'Caldiarchaeum_subterraneum',
#  'Korarchaeum_cryptofilum',
#  'Archaeoglobus_fulgidus:Methanopyrus_kandleri:Methanococcus_jannaschii:Haloarcula_marismortui:Pyrococcus_furiosus:Methanosarcina_mazei:Thermoplasma_volcanium:Methanomassiliicoccus_luminyensis:Methanothermobacter_thermautotro',
#  'Archaeoglobus_fulgidus:Haloarcula_marismortui:Thermoplasma_volcanium:Methanosarcina_mazei:Methanomassiliicoccus_luminyensis',
#  'Archaeoglobus_fulgidus:Haloarcula_marismortui:Methanosarcina_mazei',
#  'Archaeoglobus_fulgidus',
#  'Haloarcula_marismortui:Methanosarcina_mazei',
#  'Haloarcula_marismortui',
#  'Methanosarcina_mazei',
#  'Thermoplasma_volcanium:Methanomassiliicoccus_luminyensis',
#  'Thermoplasma_volcanium',
#  'Methanomassiliicoccus_luminyensis',
#  'Methanothermobacter_thermautotro:Methanopyrus_kandleri:Pyrococcus_furiosus:Methanococcus_jannaschii',
#  'Methanothermobacter_thermautotro:Methanopyrus_kandleri',
#  'Methanothermobacter_thermautotro',
#  'Methanopyrus_kandleri',
#  'Methanococcus_jannaschii:Pyrococcus_furiosus',
#  'Methanococcus_jannaschii',
#  'Pyrococcus_furiosus',
#  'Ar5:Nanoarchaeum:Micrarchaeum_acidiphilum:DUSEL3:DUSEL4:Ar15:Ar6:Ar13:Nanosalina:Parvarchaeum_acidophilus:Nanosalinarum',
#  'Ar5:Nanoarchaeum:DUSEL4:Ar15:Ar6:Ar13:Nanosalina:Parvarchaeum_acidophilus:Nanosalinarum',
#  'Ar5:Nanosalina:Nanosalinarum',
#  'Ar5',
#  'Nanosalina:Nanosalinarum',
#  'Nanosalina',
#  'Nanosalinarum',
#  'DUSEL4:Nanoarchaeum:Ar15:Ar6:Ar13:Parvarchaeum_acidophilus',
#  'DUSEL4:Ar15:Ar13:Parvarchaeum_acidophilus:Ar6',
#  'DUSEL4:Ar15:Ar13:Ar6',
#  'DUSEL4:Ar15',
#  'DUSEL4',
#  'Ar15',
#  'Ar6:Ar13',
#  'Ar6',
#  'Ar13',
#  'Parvarchaeum_acidophilus',
#  'Nanoarchaeum',
#  'Micrarchaeum_acidiphilum:DUSEL3',
#  'Micrarchaeum_acidiphilum',
#  'DUSEL3',
#  'Rhodopseudomonas_palustris:Chlorobium:Caldithrix:Gemmatimonas:Latescibacteria:Fibrobacter:Lentisphaera:Verrucomicrobium:Chlamydia_trachomatis:Rhodopirellula_baltica:Elusimicrobium:Clostridium_acetobutylicum:Treponema_pallidum:Chthonomonas:Oscillochloris:Microgenomates:Parcubacteria:Actinomadura:Rickettsia:Escherichia_coli:Campylobacter_jejuni:Desulfurispirillum:Cylindrosperopsis:Chlorogloeopsis:Synechocystis_sp._PCC6803:Acidobacterium:Gloeobacter:Candidatus:Thermodesulfatator:Jonquetella:Thermodesulfovibrio:Aquifex:Dictyoglomus:Caldisericum:Kosmotoga',
#  'Rhodopseudomonas_palustris:Chlorobium:Caldithrix:Gemmatimonas:Latescibacteria:Fibrobacter:Lentisphaera:Verrucomicrobium:Chlamydia_trachomatis:Rhodopirellula_baltica:Elusimicrobium:Clostridium_acetobutylicum:Treponema_pallidum:Chthonomonas:Oscillochloris:Microgenomates:Parcubacteria:Actinomadura:Rickettsia:Escherichia_coli:Campylobacter_jejuni:Desulfurispirillum:Cylindrosperopsis:Chlorogloeopsis:Synechocystis_sp._PCC6803:Acidobacterium:Gloeobacter:Candidatus:Thermodesulfatator:Jonquetella:Thermodesulfovibrio:Aquifex',
#  'Rhodopseudomonas_palustris:Chthonomonas:Chlorobium:Oscillochloris:Caldithrix:Microgenomates:Gemmatimonas:Parcubacteria:Latescibacteria:Actinomadura:Rickettsia:Fibrobacter:Escherichia_coli:Campylobacter_jejuni:Desulfurispirillum:Cylindrosperopsis:Lentisphaera:Chlorogloeopsis:Verrucomicrobium:Synechocystis_sp._PCC6803:Acidobacterium:Chlamydia_trachomatis:Gloeobacter:Rhodopirellula_baltica:Candidatus:Thermodesulfatator:Elusimicrobium:Thermodesulfovibrio:Aquifex:Clostridium_acetobutylicum:Treponema_pallidum',
#  'Rhodopseudomonas_palustris:Chthonomonas:Chlorobium:Oscillochloris:Caldithrix:Microgenomates:Gemmatimonas:Parcubacteria:Latescibacteria:Actinomadura:Rickettsia:Fibrobacter:Escherichia_coli:Campylobacter_jejuni:Desulfurispirillum:Cylindrosperopsis:Lentisphaera:Chlorogloeopsis:Verrucomicrobium:Synechocystis_sp._PCC6803:Acidobacterium:Chlamydia_trachomatis:Gloeobacter:Rhodopirellula_baltica:Thermodesulfatator:Elusimicrobium:Thermodesulfovibrio:Aquifex:Clostridium_acetobutylicum:Treponema_pallidum',
#  'Rhodopseudomonas_palustris:Chthonomonas:Chlorobium:Oscillochloris:Caldithrix:Microgenomates:Gemmatimonas:Parcubacteria:Latescibacteria:Actinomadura:Rickettsia:Fibrobacter:Escherichia_coli:Campylobacter_jejuni:Desulfurispirillum:Lentisphaera:Verrucomicrobium:Acidobacterium:Chlamydia_trachomatis:Rhodopirellula_baltica:Thermodesulfatator:Elusimicrobium:Thermodesulfovibrio:Aquifex:Clostridium_acetobutylicum:Treponema_pallidum',
#  'Rhodopseudomonas_palustris:Chlorobium:Caldithrix:Gemmatimonas:Latescibacteria:Rickettsia:Fibrobacter:Escherichia_coli:Campylobacter_jejuni:Desulfurispirillum:Lentisphaera:Verrucomicrobium:Acidobacterium:Chlamydia_trachomatis:Rhodopirellula_baltica:Thermodesulfatator:Elusimicrobium:Thermodesulfovibrio:Aquifex',
#  'Rhodopseudomonas_palustris:Chlorobium:Caldithrix:Gemmatimonas:Latescibacteria:Rickettsia:Fibrobacter:Escherichia_coli:Campylobacter_jejuni:Desulfurispirillum:Lentisphaera:Verrucomicrobium:Acidobacterium:Chlamydia_trachomatis:Rhodopirellula_baltica:Thermodesulfatator:Thermodesulfovibrio:Aquifex',
#  'Rhodopseudomonas_palustris:Acidobacterium:Thermodesulfatator:Thermodesulfovibrio:Aquifex:Rickettsia:Escherichia_coli:Campylobacter_jejuni:Desulfurispirillum',
#  'Rhodopseudomonas_palustris:Campylobacter_jejuni:Rickettsia:Desulfurispirillum:Escherichia_coli',
#  'Rhodopseudomonas_palustris:Campylobacter_jejuni:Rickettsia:Escherichia_coli',
#  'Rhodopseudomonas_palustris:Rickettsia:Escherichia_coli',
#  'Rhodopseudomonas_palustris:Rickettsia',
#  'Rhodopseudomonas_palustris',
#  'Rickettsia',
#  'Escherichia_coli',
#  'Campylobacter_jejuni',
#  'Desulfurispirillum',
#  'Acidobacterium:Aquifex:Thermodesulfatator:Thermodesulfovibrio',
#  'Acidobacterium:Thermodesulfatator:Thermodesulfovibrio',
#  'Acidobacterium',
#  'Thermodesulfatator:Thermodesulfovibrio',
#  'Thermodesulfatator',
#  'Thermodesulfovibrio',
#  'Aquifex',
#  'Chlorobium:Verrucomicrobium:Chlamydia_trachomatis:Caldithrix:Rhodopirellula_baltica:Gemmatimonas:Latescibacteria:Fibrobacter:Lentisphaera',
#  'Chlorobium:Latescibacteria:Fibrobacter:Gemmatimonas:Caldithrix',
#  'Chlorobium:Latescibacteria:Gemmatimonas:Caldithrix',
#  'Chlorobium:Caldithrix',
#  'Chlorobium',
#  'Caldithrix',
#  'Gemmatimonas:Latescibacteria',
#  'Gemmatimonas',
#  'Latescibacteria',
#  'Fibrobacter',
#  'Lentisphaera:Rhodopirellula_baltica:Verrucomicrobium:Chlamydia_trachomatis',
#  'Lentisphaera:Verrucomicrobium:Chlamydia_trachomatis',
#  'Lentisphaera:Verrucomicrobium',
#  'Lentisphaera',
#  'Verrucomicrobium',
#  'Chlamydia_trachomatis',
#  'Rhodopirellula_baltica',
#  'Elusimicrobium',
#  'Clostridium_acetobutylicum:Chthonomonas:Oscillochloris:Microgenomates:Parcubacteria:Actinomadura:Treponema_pallidum',
#  'Clostridium_acetobutylicum:Treponema_pallidum',
#  'Clostridium_acetobutylicum',
#  'Treponema_pallidum',
#  'Chthonomonas:Actinomadura:Microgenomates:Oscillochloris:Parcubacteria',
#  'Chthonomonas:Microgenomates:Oscillochloris:Parcubacteria',
#  'Chthonomonas',
#  'Oscillochloris:Microgenomates:Parcubacteria',
#  'Oscillochloris',
#  'Microgenomates:Parcubacteria',
#  'Microgenomates',
#  'Parcubacteria',
#  'Actinomadura',
#  'Cylindrosperopsis:Chlorogloeopsis:Synechocystis_sp._PCC6803:Gloeobacter',
#  'Cylindrosperopsis:Chlorogloeopsis:Synechocystis_sp._PCC6803',
#  'Cylindrosperopsis:Chlorogloeopsis',
#  'Cylindrosperopsis',
#  'Chlorogloeopsis',
#  'Synechocystis_sp._PCC6803',
#  'Gloeobacter',
#  'Candidatus',
#  'Jonquetella',
#  'Dictyoglomus:Caldisericum:Kosmotoga',
#  'Dictyoglomus:Caldisericum',
#  'Dictyoglomus',
#  'Caldisericum',
#  'Kosmotoga']

# %%
mcmctree_node_traversal
# Out:
# ['Volvox:Leishmania_major:Bodo:Ar6:Trichomonas_vaginalis:Ar13:Giardia_lamblia:Ar15:DUSEL4:Parvarchaeum_acidophilus:Nanoarchaeum:Limulus:Homo_sapiens:Hydra:Amphimedon:Agaricus:Saccharomyces_cerevisiae:Batrachochytrium:Polysphondylium:Dictyostelium_discoideum:Rhodopseudomonas_palustris:Rickettsia:Escherichia_coli:Lokiarchaeum:Campylobacter_jejuni:Loki2:Desulfurispirillum:Loki3:Acidobacterium:Thermodesulfatator:Thermodesulfovibrio:Aquifex:Hyperthermus_butylicus:Aeropyrum_pernix:Ignicoccus_hospitalis:Staphylothermus_marinus:Chlorobium:Sulfolobus_solfataricus:Caldithrix:Gemmatimonas:Caldivirga_maquilingensis:Latescibacteria:Pyrobaculum_aerophilum:Fibrobacter:Thermofilum_pendens:Crenynpffa:Lentisphaera:The09:Verrucomicrobium:Chlamydia_trachomatis:Cenarchaeum_symbiosum:Rhodopirellula_baltica:Elusimicrobium:Nitrosopumilus_maritimus:Nitrosoarchaeum_limnia:Caldiarchaeum_subterraneum:Clostridium_acetobutylicum:Korarchaeum_cryptofilum:Treponema_pallidum:Chlamydomonas:Chthonomonas:Archaeoglobus_fulgidus:Oryza_sativa:Haloarcula_marismortui:Parcubacteria:Arabidopsis_thaliana:Methanosarcina_mazei:Microgenomates:Physcomitrella:Oscillochloris:Thermoplasma_volcanium:Actinomadura:Methanomassiliicoccus_luminyensis:Chondrus:Cyanidioschyzon:Galdieria:Methanothermobacter_thermautotro:Cylindrosperopsis:Cyanophora:Methanopyrus_kandleri:Chlorogloeopsis:Synechocystis_sp._PCC6803:Methanococcus_jannaschii:Gloeobacter:Pyrococcus_furiosus:Candidatus:Paramecium:Jonquetella:Tetrahymena:DUSEL3:Micrarchaeum_acidiphilum:Dictyoglomus:Ectocarpus:Caldisericum:Thalassiosira_pseudonana:Kosmotoga:Phytophthora_ramorum:Ar5:Reticulomyxa:Nanosalina:Elphidium:Nanosalinarum',
#  'Volvox:Leishmania_major:Bodo:Ar6:Trichomonas_vaginalis:Ar13:Giardia_lamblia:Ar15:DUSEL4:Parvarchaeum_acidophilus:Nanoarchaeum:Limulus:Homo_sapiens:Hydra:Amphimedon:Agaricus:Saccharomyces_cerevisiae:Batrachochytrium:Polysphondylium:Dictyostelium_discoideum:Lokiarchaeum:Loki2:Loki3:Hyperthermus_butylicus:Aeropyrum_pernix:Ignicoccus_hospitalis:Staphylothermus_marinus:Sulfolobus_solfataricus:Caldivirga_maquilingensis:Pyrobaculum_aerophilum:Thermofilum_pendens:Crenynpffa:The09:Cenarchaeum_symbiosum:Nitrosopumilus_maritimus:Nitrosoarchaeum_limnia:Caldiarchaeum_subterraneum:Korarchaeum_cryptofilum:Chlamydomonas:Archaeoglobus_fulgidus:Oryza_sativa:Haloarcula_marismortui:Arabidopsis_thaliana:Methanosarcina_mazei:Physcomitrella:Thermoplasma_volcanium:Methanomassiliicoccus_luminyensis:Chondrus:Cyanidioschyzon:Galdieria:Methanothermobacter_thermautotro:Cyanophora:Methanopyrus_kandleri:Methanococcus_jannaschii:Pyrococcus_furiosus:Paramecium:Tetrahymena:DUSEL3:Micrarchaeum_acidiphilum:Ectocarpus:Thalassiosira_pseudonana:Phytophthora_ramorum:Ar5:Reticulomyxa:Nanosalina:Elphidium:Nanosalinarum',
#  'Volvox:Thermofilum_pendens:Leishmania_major:Crenynpffa:Bodo:Trichomonas_vaginalis:Giardia_lamblia:The09:Cenarchaeum_symbiosum:Nitrosopumilus_maritimus:Nitrosoarchaeum_limnia:Limulus:Caldiarchaeum_subterraneum:Homo_sapiens:Korarchaeum_cryptofilum:Hydra:Amphimedon:Chlamydomonas:Archaeoglobus_fulgidus:Agaricus:Saccharomyces_cerevisiae:Oryza_sativa:Haloarcula_marismortui:Batrachochytrium:Arabidopsis_thaliana:Methanosarcina_mazei:Physcomitrella:Polysphondylium:Thermoplasma_volcanium:Dictyostelium_discoideum:Methanomassiliicoccus_luminyensis:Chondrus:Cyanidioschyzon:Lokiarchaeum:Galdieria:Methanothermobacter_thermautotro:Loki2:Cyanophora:Methanopyrus_kandleri:Loki3:Methanococcus_jannaschii:Pyrococcus_furiosus:Paramecium:Tetrahymena:Ectocarpus:Hyperthermus_butylicus:Thalassiosira_pseudonana:Aeropyrum_pernix:Phytophthora_ramorum:Ignicoccus_hospitalis:Staphylothermus_marinus:Reticulomyxa:Sulfolobus_solfataricus:Elphidium:Caldivirga_maquilingensis:Pyrobaculum_aerophilum',
#  'Volvox:Thermofilum_pendens:Leishmania_major:Crenynpffa:Bodo:Trichomonas_vaginalis:Giardia_lamblia:The09:Cenarchaeum_symbiosum:Nitrosopumilus_maritimus:Nitrosoarchaeum_limnia:Limulus:Caldiarchaeum_subterraneum:Homo_sapiens:Korarchaeum_cryptofilum:Hydra:Amphimedon:Chlamydomonas:Agaricus:Saccharomyces_cerevisiae:Oryza_sativa:Batrachochytrium:Arabidopsis_thaliana:Physcomitrella:Polysphondylium:Dictyostelium_discoideum:Chondrus:Cyanidioschyzon:Lokiarchaeum:Galdieria:Loki2:Cyanophora:Loki3:Paramecium:Tetrahymena:Ectocarpus:Hyperthermus_butylicus:Thalassiosira_pseudonana:Aeropyrum_pernix:Phytophthora_ramorum:Ignicoccus_hospitalis:Staphylothermus_marinus:Reticulomyxa:Sulfolobus_solfataricus:Elphidium:Caldivirga_maquilingensis:Pyrobaculum_aerophilum',
#  'Volvox:Thermofilum_pendens:Leishmania_major:Crenynpffa:Bodo:Trichomonas_vaginalis:Giardia_lamblia:The09:Cenarchaeum_symbiosum:Nitrosopumilus_maritimus:Nitrosoarchaeum_limnia:Limulus:Caldiarchaeum_subterraneum:Homo_sapiens:Hydra:Amphimedon:Chlamydomonas:Agaricus:Saccharomyces_cerevisiae:Oryza_sativa:Batrachochytrium:Arabidopsis_thaliana:Physcomitrella:Polysphondylium:Dictyostelium_discoideum:Chondrus:Cyanidioschyzon:Lokiarchaeum:Galdieria:Loki2:Cyanophora:Loki3:Paramecium:Tetrahymena:Ectocarpus:Hyperthermus_butylicus:Thalassiosira_pseudonana:Aeropyrum_pernix:Phytophthora_ramorum:Ignicoccus_hospitalis:Staphylothermus_marinus:Reticulomyxa:Sulfolobus_solfataricus:Elphidium:Caldivirga_maquilingensis:Pyrobaculum_aerophilum',
#  'Volvox:Leishmania_major:Bodo:Trichomonas_vaginalis:Giardia_lamblia:Limulus:Homo_sapiens:Hydra:Amphimedon:Chlamydomonas:Agaricus:Saccharomyces_cerevisiae:Oryza_sativa:Batrachochytrium:Arabidopsis_thaliana:Physcomitrella:Polysphondylium:Dictyostelium_discoideum:Chondrus:Cyanidioschyzon:Lokiarchaeum:Galdieria:Loki2:Cyanophora:Loki3:Paramecium:Tetrahymena:Ectocarpus:Thalassiosira_pseudonana:Phytophthora_ramorum:Reticulomyxa:Elphidium',
#  'Volvox:Dictyostelium_discoideum:Chondrus:Leishmania_major:Cyanidioschyzon:Bodo:Galdieria:Trichomonas_vaginalis:Cyanophora:Giardia_lamblia:Paramecium:Tetrahymena:Limulus:Homo_sapiens:Ectocarpus:Hydra:Thalassiosira_pseudonana:Amphimedon:Phytophthora_ramorum:Chlamydomonas:Reticulomyxa:Agaricus:Elphidium:Oryza_sativa:Saccharomyces_cerevisiae:Batrachochytrium:Arabidopsis_thaliana:Physcomitrella:Polysphondylium',
#  'Volvox:Chondrus:Leishmania_major:Cyanidioschyzon:Bodo:Galdieria:Trichomonas_vaginalis:Cyanophora:Giardia_lamblia:Paramecium:Tetrahymena:Ectocarpus:Thalassiosira_pseudonana:Phytophthora_ramorum:Chlamydomonas:Reticulomyxa:Elphidium:Oryza_sativa:Arabidopsis_thaliana:Physcomitrella',
#  'Volvox:Chondrus:Cyanidioschyzon:Galdieria:Cyanophora:Paramecium:Tetrahymena:Ectocarpus:Thalassiosira_pseudonana:Phytophthora_ramorum:Chlamydomonas:Reticulomyxa:Elphidium:Oryza_sativa:Arabidopsis_thaliana:Physcomitrella',
#  'Volvox:Chondrus:Cyanidioschyzon:Galdieria:Chlamydomonas:Cyanophora:Oryza_sativa:Arabidopsis_thaliana:Physcomitrella',
#  'Volvox:Chondrus:Cyanidioschyzon:Galdieria:Chlamydomonas:Oryza_sativa:Arabidopsis_thaliana:Physcomitrella',
#  'Volvox:Arabidopsis_thaliana:Physcomitrella:Chlamydomonas:Oryza_sativa',
#  'Volvox:Chlamydomonas',
#  'Volvox',
#  'Chlamydomonas',
#  'Oryza_sativa:Arabidopsis_thaliana:Physcomitrella',
#  'Oryza_sativa:Arabidopsis_thaliana',
#  'Oryza_sativa',
#  'Arabidopsis_thaliana',
#  'Physcomitrella',
#  'Chondrus:Galdieria:Cyanidioschyzon',
#  'Chondrus:Cyanidioschyzon',
#  'Chondrus',
#  'Cyanidioschyzon',
#  'Galdieria',
#  'Cyanophora',
#  'Paramecium:Ectocarpus:Thalassiosira_pseudonana:Phytophthora_ramorum:Reticulomyxa:Elphidium:Tetrahymena',
#  'Paramecium:Thalassiosira_pseudonana:Phytophthora_ramorum:Tetrahymena:Ectocarpus',
#  'Paramecium:Tetrahymena',
#  'Paramecium',
#  'Tetrahymena',
#  'Ectocarpus:Thalassiosira_pseudonana:Phytophthora_ramorum',
#  'Ectocarpus:Thalassiosira_pseudonana',
#  'Ectocarpus',
#  'Thalassiosira_pseudonana',
#  'Phytophthora_ramorum',
#  'Reticulomyxa:Elphidium',
#  'Reticulomyxa',
#  'Elphidium',
#  'Leishmania_major:Trichomonas_vaginalis:Giardia_lamblia:Bodo',
#  'Leishmania_major:Trichomonas_vaginalis:Bodo',
#  'Leishmania_major:Bodo',
#  'Leishmania_major',
#  'Bodo',
#  'Trichomonas_vaginalis',
#  'Giardia_lamblia',
#  'Limulus:Dictyostelium_discoideum:Homo_sapiens:Hydra:Amphimedon:Agaricus:Saccharomyces_cerevisiae:Batrachochytrium:Polysphondylium',
#  'Limulus:Homo_sapiens:Hydra:Amphimedon:Agaricus:Saccharomyces_cerevisiae:Batrachochytrium',
#  'Limulus:Amphimedon:Homo_sapiens:Hydra',
#  'Limulus:Homo_sapiens:Hydra',
#  'Limulus:Homo_sapiens',
#  'Limulus',
#  'Homo_sapiens',
#  'Hydra',
#  'Amphimedon',
#  'Agaricus:Saccharomyces_cerevisiae:Batrachochytrium',
#  'Agaricus:Saccharomyces_cerevisiae',
#  'Agaricus',
#  'Saccharomyces_cerevisiae',
#  'Batrachochytrium',
#  'Polysphondylium:Dictyostelium_discoideum',
#  'Polysphondylium',
#  'Dictyostelium_discoideum',
#  'Lokiarchaeum:Loki2:Loki3',
#  'Lokiarchaeum:Loki2',
#  'Lokiarchaeum',
#  'Loki2',
#  'Loki3',
#  'Hyperthermus_butylicus:Caldiarchaeum_subterraneum:Thermofilum_pendens:Crenynpffa:Aeropyrum_pernix:Ignicoccus_hospitalis:The09:Staphylothermus_marinus:Sulfolobus_solfataricus:Cenarchaeum_symbiosum:Nitrosopumilus_maritimus:Caldivirga_maquilingensis:Nitrosoarchaeum_limnia:Pyrobaculum_aerophilum',
#  'Hyperthermus_butylicus:Thermofilum_pendens:Crenynpffa:Aeropyrum_pernix:Ignicoccus_hospitalis:Staphylothermus_marinus:Sulfolobus_solfataricus:Caldivirga_maquilingensis:Pyrobaculum_aerophilum',
#  'Hyperthermus_butylicus:Thermofilum_pendens:Aeropyrum_pernix:Ignicoccus_hospitalis:Staphylothermus_marinus:Sulfolobus_solfataricus:Caldivirga_maquilingensis:Pyrobaculum_aerophilum',
#  'Hyperthermus_butylicus:Staphylothermus_marinus:Aeropyrum_pernix:Sulfolobus_solfataricus:Ignicoccus_hospitalis',
#  'Hyperthermus_butylicus:Staphylothermus_marinus:Aeropyrum_pernix:Ignicoccus_hospitalis',
#  'Hyperthermus_butylicus:Aeropyrum_pernix:Ignicoccus_hospitalis',
#  'Hyperthermus_butylicus:Aeropyrum_pernix',
#  'Hyperthermus_butylicus',
#  'Aeropyrum_pernix',
#  'Ignicoccus_hospitalis',
#  'Staphylothermus_marinus',
#  'Sulfolobus_solfataricus',
#  'Caldivirga_maquilingensis:Thermofilum_pendens:Pyrobaculum_aerophilum',
#  'Caldivirga_maquilingensis:Pyrobaculum_aerophilum',
#  'Caldivirga_maquilingensis',
#  'Pyrobaculum_aerophilum',
#  'Thermofilum_pendens',
#  'Crenynpffa',
#  'The09:Caldiarchaeum_subterraneum:Nitrosopumilus_maritimus:Cenarchaeum_symbiosum:Nitrosoarchaeum_limnia',
#  'The09:Nitrosopumilus_maritimus:Cenarchaeum_symbiosum:Nitrosoarchaeum_limnia',
#  'The09',
#  'Cenarchaeum_symbiosum:Nitrosopumilus_maritimus:Nitrosoarchaeum_limnia',
#  'Cenarchaeum_symbiosum',
#  'Nitrosopumilus_maritimus:Nitrosoarchaeum_limnia',
#  'Nitrosopumilus_maritimus',
#  'Nitrosoarchaeum_limnia',
#  'Caldiarchaeum_subterraneum',
#  'Korarchaeum_cryptofilum',
#  'Archaeoglobus_fulgidus:Methanomassiliicoccus_luminyensis:Methanothermobacter_thermautotro:Methanopyrus_kandleri:Methanococcus_jannaschii:Haloarcula_marismortui:Pyrococcus_furiosus:Methanosarcina_mazei:Thermoplasma_volcanium',
#  'Archaeoglobus_fulgidus:Methanosarcina_mazei:Methanomassiliicoccus_luminyensis:Haloarcula_marismortui:Thermoplasma_volcanium',
#  'Archaeoglobus_fulgidus:Methanosarcina_mazei:Haloarcula_marismortui',
#  'Archaeoglobus_fulgidus',
#  'Haloarcula_marismortui:Methanosarcina_mazei',
#  'Haloarcula_marismortui',
#  'Methanosarcina_mazei',
#  'Thermoplasma_volcanium:Methanomassiliicoccus_luminyensis',
#  'Thermoplasma_volcanium',
#  'Methanomassiliicoccus_luminyensis',
#  'Methanothermobacter_thermautotro:Methanococcus_jannaschii:Methanopyrus_kandleri:Pyrococcus_furiosus',
#  'Methanothermobacter_thermautotro:Methanopyrus_kandleri',
#  'Methanothermobacter_thermautotro',
#  'Methanopyrus_kandleri',
#  'Methanococcus_jannaschii:Pyrococcus_furiosus',
#  'Methanococcus_jannaschii',
#  'Pyrococcus_furiosus',
#  'DUSEL3:Micrarchaeum_acidiphilum:Ar6:Ar13:Ar5:Ar15:Nanosalina:DUSEL4:Nanosalinarum:Parvarchaeum_acidophilus:Nanoarchaeum',
#  'DUSEL3:Micrarchaeum_acidiphilum',
#  'DUSEL3',
#  'Micrarchaeum_acidiphilum',
#  'Ar5:Ar6:Ar13:Ar15:Nanosalina:DUSEL4:Nanosalinarum:Parvarchaeum_acidophilus:Nanoarchaeum',
#  'Ar5:Nanosalina:Nanosalinarum',
#  'Ar5',
#  'Nanosalina:Nanosalinarum',
#  'Nanosalina',
#  'Nanosalinarum',
#  'Ar6:Ar13:Ar15:DUSEL4:Parvarchaeum_acidophilus:Nanoarchaeum',
#  'Ar6:Ar15:Ar13:DUSEL4:Parvarchaeum_acidophilus',
#  'Ar6:Ar15:Ar13:DUSEL4',
#  'Ar6:Ar13',
#  'Ar6',
#  'Ar13',
#  'Ar15:DUSEL4',
#  'Ar15',
#  'DUSEL4',
#  'Parvarchaeum_acidophilus',
#  'Nanoarchaeum',
#  'Rhodopseudomonas_palustris:Lentisphaera:Verrucomicrobium:Chlamydia_trachomatis:Rhodopirellula_baltica:Elusimicrobium:Clostridium_acetobutylicum:Treponema_pallidum:Chthonomonas:Parcubacteria:Microgenomates:Oscillochloris:Actinomadura:Rickettsia:Escherichia_coli:Campylobacter_jejuni:Cylindrosperopsis:Desulfurispirillum:Chlorogloeopsis:Synechocystis_sp._PCC6803:Gloeobacter:Acidobacterium:Candidatus:Jonquetella:Thermodesulfatator:Thermodesulfovibrio:Aquifex:Dictyoglomus:Caldisericum:Kosmotoga:Chlorobium:Caldithrix:Gemmatimonas:Latescibacteria:Fibrobacter',
#  'Rhodopseudomonas_palustris:Lentisphaera:Verrucomicrobium:Chlamydia_trachomatis:Rhodopirellula_baltica:Elusimicrobium:Clostridium_acetobutylicum:Treponema_pallidum:Chthonomonas:Parcubacteria:Microgenomates:Oscillochloris:Actinomadura:Rickettsia:Escherichia_coli:Campylobacter_jejuni:Cylindrosperopsis:Desulfurispirillum:Chlorogloeopsis:Synechocystis_sp._PCC6803:Gloeobacter:Acidobacterium:Candidatus:Jonquetella:Thermodesulfatator:Thermodesulfovibrio:Aquifex:Chlorobium:Caldithrix:Gemmatimonas:Latescibacteria:Fibrobacter',
#  'Rhodopseudomonas_palustris:Rickettsia:Escherichia_coli:Campylobacter_jejuni:Cylindrosperopsis:Lentisphaera:Desulfurispirillum:Chlorogloeopsis:Verrucomicrobium:Synechocystis_sp._PCC6803:Chlamydia_trachomatis:Gloeobacter:Rhodopirellula_baltica:Acidobacterium:Candidatus:Elusimicrobium:Thermodesulfatator:Thermodesulfovibrio:Clostridium_acetobutylicum:Aquifex:Treponema_pallidum:Chthonomonas:Chlorobium:Caldithrix:Parcubacteria:Microgenomates:Gemmatimonas:Oscillochloris:Latescibacteria:Actinomadura:Fibrobacter',
#  'Rhodopseudomonas_palustris:Rickettsia:Escherichia_coli:Campylobacter_jejuni:Cylindrosperopsis:Lentisphaera:Desulfurispirillum:Chlorogloeopsis:Verrucomicrobium:Synechocystis_sp._PCC6803:Chlamydia_trachomatis:Gloeobacter:Rhodopirellula_baltica:Acidobacterium:Elusimicrobium:Thermodesulfatator:Thermodesulfovibrio:Clostridium_acetobutylicum:Aquifex:Treponema_pallidum:Chthonomonas:Chlorobium:Caldithrix:Parcubacteria:Microgenomates:Gemmatimonas:Oscillochloris:Latescibacteria:Actinomadura:Fibrobacter',
#  'Rhodopseudomonas_palustris:Rickettsia:Escherichia_coli:Campylobacter_jejuni:Lentisphaera:Desulfurispirillum:Verrucomicrobium:Chlamydia_trachomatis:Rhodopirellula_baltica:Acidobacterium:Elusimicrobium:Thermodesulfatator:Thermodesulfovibrio:Clostridium_acetobutylicum:Aquifex:Treponema_pallidum:Chthonomonas:Chlorobium:Caldithrix:Parcubacteria:Microgenomates:Gemmatimonas:Oscillochloris:Latescibacteria:Actinomadura:Fibrobacter',
#  'Rhodopseudomonas_palustris:Rickettsia:Escherichia_coli:Campylobacter_jejuni:Lentisphaera:Desulfurispirillum:Verrucomicrobium:Chlamydia_trachomatis:Rhodopirellula_baltica:Acidobacterium:Elusimicrobium:Thermodesulfatator:Thermodesulfovibrio:Aquifex:Chlorobium:Caldithrix:Gemmatimonas:Latescibacteria:Fibrobacter',
#  'Rhodopseudomonas_palustris:Rickettsia:Escherichia_coli:Campylobacter_jejuni:Lentisphaera:Desulfurispirillum:Verrucomicrobium:Chlamydia_trachomatis:Rhodopirellula_baltica:Acidobacterium:Thermodesulfatator:Thermodesulfovibrio:Aquifex:Chlorobium:Caldithrix:Gemmatimonas:Latescibacteria:Fibrobacter',
#  'Rhodopseudomonas_palustris:Aquifex:Rickettsia:Escherichia_coli:Campylobacter_jejuni:Desulfurispirillum:Acidobacterium:Thermodesulfatator:Thermodesulfovibrio',
#  'Rhodopseudomonas_palustris:Campylobacter_jejuni:Rickettsia:Desulfurispirillum:Escherichia_coli',
#  'Rhodopseudomonas_palustris:Campylobacter_jejuni:Rickettsia:Escherichia_coli',
#  'Rhodopseudomonas_palustris:Rickettsia:Escherichia_coli',
#  'Rhodopseudomonas_palustris:Rickettsia',
#  'Rhodopseudomonas_palustris',
#  'Rickettsia',
#  'Escherichia_coli',
#  'Campylobacter_jejuni',
#  'Desulfurispirillum',
#  'Acidobacterium:Aquifex:Thermodesulfatator:Thermodesulfovibrio',
#  'Acidobacterium:Thermodesulfatator:Thermodesulfovibrio',
#  'Acidobacterium',
#  'Thermodesulfatator:Thermodesulfovibrio',
#  'Thermodesulfatator',
#  'Thermodesulfovibrio',
#  'Aquifex',
#  'Chlorobium:Lentisphaera:Verrucomicrobium:Chlamydia_trachomatis:Caldithrix:Rhodopirellula_baltica:Gemmatimonas:Latescibacteria:Fibrobacter',
#  'Chlorobium:Gemmatimonas:Caldithrix:Latescibacteria:Fibrobacter',
#  'Chlorobium:Gemmatimonas:Caldithrix:Latescibacteria',
#  'Chlorobium:Caldithrix',
#  'Chlorobium',
#  'Caldithrix',
#  'Gemmatimonas:Latescibacteria',
#  'Gemmatimonas',
#  'Latescibacteria',
#  'Fibrobacter',
#  'Lentisphaera:Chlamydia_trachomatis:Rhodopirellula_baltica:Verrucomicrobium',
#  'Lentisphaera:Chlamydia_trachomatis:Verrucomicrobium',
#  'Lentisphaera:Verrucomicrobium',
#  'Lentisphaera',
#  'Verrucomicrobium',
#  'Chlamydia_trachomatis',
#  'Rhodopirellula_baltica',
#  'Elusimicrobium',
#  'Clostridium_acetobutylicum:Treponema_pallidum:Chthonomonas:Parcubacteria:Microgenomates:Oscillochloris:Actinomadura',
#  'Clostridium_acetobutylicum:Treponema_pallidum',
#  'Clostridium_acetobutylicum',
#  'Treponema_pallidum',
#  'Chthonomonas:Microgenomates:Oscillochloris:Parcubacteria:Actinomadura',
#  'Chthonomonas:Microgenomates:Oscillochloris:Parcubacteria',
#  'Chthonomonas',
#  'Parcubacteria:Microgenomates:Oscillochloris',
#  'Parcubacteria:Microgenomates',
#  'Parcubacteria',
#  'Microgenomates',
#  'Oscillochloris',
#  'Actinomadura',
#  'Cylindrosperopsis:Synechocystis_sp._PCC6803:Gloeobacter:Chlorogloeopsis',
#  'Cylindrosperopsis:Synechocystis_sp._PCC6803:Chlorogloeopsis',
#  'Cylindrosperopsis:Chlorogloeopsis',
#  'Cylindrosperopsis',
#  'Chlorogloeopsis',
#  'Synechocystis_sp._PCC6803',
#  'Gloeobacter',
#  'Candidatus',
#  'Jonquetella',
#  'Dictyoglomus:Kosmotoga:Caldisericum',
#  'Dictyoglomus:Caldisericum',
#  'Dictyoglomus',
#  'Caldisericum',
#  'Kosmotoga']

# %%
LG_G4_index_tree = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/GTR_G4_index.tree"
LG_G4_C60_index_tree = "/home/piyumal/PHD/TimeTree/TreeMatching2/date_testing/Afrotheria/complex-model-analysis-v1/MIX_MF_index.tree"
# Load the tree using ETE3
tree1 = Tree(LG_G4_index_tree)
tree2 = Tree(LG_G4_C60_index_tree)


# Function to traverse the tree and populate the dictionary
def traverse_and_collect(node, clade_values):
    if not node.is_leaf():
        clade_name = node.name if node.name else "root"
        # Retrieve the support value (if exists)
        if clade_name == "root":
            clade_name = "root:1"
        support_value = node.support if node.support else None
        clade_values[clade_name] = support_value
        for child in node.get_children():
            # print(child)
            # print(child.get_leaf_names())
            child_names = child.get_leaf_names()
            cleaned_child_names = ["_".join(name.split('_')[1:]) for name in child_names]
            cleaned_child_names.sort()
            final_child_name = ":".join(cleaned_child_names)+":"+str(len(cleaned_child_names))
            support_value = node.support if node.support else None
            # print(support_value)
            clade_values[final_child_name] = support_value
            traverse_and_collect(child, clade_values)

# %%
# Start the traversal from the root
clade_values_tree1 = {}

traverse_and_collect(tree1, clade_values_tree1)

# Display the clade names with their associated values
for clade, value in clade_values_tree1.items():
    print(f"Clade: {clade}, Support Value: {value}")
# Out:
# Clade: root:1, Support Value: 119.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:dendrohyrax_dorsalis:dugong_dugon:echinops_telfairi:elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:elephas_maximus:elephas_maximus_indicus:eremitalpa_granti:geogale_aurita:hemicentetes_semispinosus:heterohyrax_brucei:limnogale_mergulus:loxodonta_africana:loxodonta_cyclotis:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:neamblysomus_gunningi:neamblysomus_julianae:orycteropus_afer:oryzorictes:petrodromus_tetradactylus:petrosaltator_rozeti:potamogale_velox:procavia_capensis:rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:setifer_setosus:tenrec_ecaudatus:trichechus_manatus:57, Support Value: 61.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:echinops_telfairi:elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:eremitalpa_granti:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:neamblysomus_gunningi:neamblysomus_julianae:orycteropus_afer:oryzorictes:petrodromus_tetradactylus:petrosaltator_rozeti:potamogale_velox:rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:setifer_setosus:tenrec_ecaudatus:48, Support Value: 62.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:echinops_telfairi:elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:eremitalpa_granti:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:neamblysomus_gunningi:neamblysomus_julianae:oryzorictes:petrodromus_tetradactylus:petrosaltator_rozeti:potamogale_velox:rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:setifer_setosus:tenrec_ecaudatus:47, Support Value: 63.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:15, Support Value: 64.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:12, Support Value: 65.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:7, Support Value: 66.0
# Clade: elephantulus_edwardii:elephantulus_myurus:elephantulus_sp_vb001:3, Support Value: 67.0
# Clade: elephantulus_edwardii:1, Support Value: 68.0
# Clade: elephantulus_myurus:elephantulus_sp_vb001:2, Support Value: 68.0
# Clade: elephantulus_sp_vb001:1, Support Value: 69.0
# Clade: elephantulus_myurus:1, Support Value: 69.0
# Clade: elephantulus_brachyrhynchus:elephantulus_intufi:elephantulus_rufescens:elephantulus_rupestris:4, Support Value: 67.0
# Clade: elephantulus_intufi:elephantulus_rupestris:2, Support Value: 70.0
# Clade: elephantulus_intufi:1, Support Value: 71.0
# Clade: elephantulus_rupestris:1, Support Value: 71.0
# Clade: elephantulus_brachyrhynchus:elephantulus_rufescens:2, Support Value: 70.0
# Clade: elephantulus_brachyrhynchus:1, Support Value: 72.0
# Clade: elephantulus_rufescens:1, Support Value: 72.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:5, Support Value: 66.0
# Clade: petrodromus_tetradactylus:petrosaltator_rozeti:2, Support Value: 73.0
# Clade: petrosaltator_rozeti:1, Support Value: 74.0
# Clade: petrodromus_tetradactylus:1, Support Value: 74.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:3, Support Value: 73.0
# Clade: macroscelides_flavicaudatus:macroscelides_proboscideus:2, Support Value: 75.0
# Clade: macroscelides_flavicaudatus:1, Support Value: 76.0
# Clade: macroscelides_proboscideus:1, Support Value: 76.0
# Clade: macroscelides_micus:1, Support Value: 75.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:3, Support Value: 65.0
# Clade: rhynchocyon_udzungwensis:1, Support Value: 77.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:2, Support Value: 77.0
# Clade: rhynchocyon_cirnei_reichardi:1, Support Value: 78.0
# Clade: rhynchocyon_petersi:1, Support Value: 78.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:echinops_telfairi:eremitalpa_granti:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:neamblysomus_gunningi:neamblysomus_julianae:oryzorictes:potamogale_velox:setifer_setosus:tenrec_ecaudatus:32, Support Value: 64.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:oryzorictes:potamogale_velox:setifer_setosus:tenrec_ecaudatus:15, Support Value: 79.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:setifer_setosus:tenrec_ecaudatus:13, Support Value: 80.0
# Clade: echinops_telfairi:hemicentetes_semispinosus:setifer_setosus:tenrec_ecaudatus:4, Support Value: 81.0
# Clade: echinops_telfairi:setifer_setosus:2, Support Value: 82.0
# Clade: echinops_telfairi:1, Support Value: 83.0
# Clade: setifer_setosus:1, Support Value: 83.0
# Clade: hemicentetes_semispinosus:tenrec_ecaudatus:2, Support Value: 82.0
# Clade: tenrec_ecaudatus:1, Support Value: 84.0
# Clade: hemicentetes_semispinosus:1, Support Value: 84.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:9, Support Value: 81.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:8, Support Value: 85.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:7, Support Value: 86.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:4, Support Value: 87.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:3, Support Value: 88.0
# Clade: microgale_longicaudata:microgale_majori:2, Support Value: 89.0
# Clade: microgale_longicaudata:1, Support Value: 90.0
# Clade: microgale_majori:1, Support Value: 90.0
# Clade: microgale_principula:1, Support Value: 89.0
# Clade: microgale_pusilla:1, Support Value: 88.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_talazaci:3, Support Value: 87.0
# Clade: limnogale_mergulus:microgale_brevicaudata:2, Support Value: 91.0
# Clade: microgale_brevicaudata:1, Support Value: 92.0
# Clade: limnogale_mergulus:1, Support Value: 92.0
# Clade: microgale_talazaci:1, Support Value: 91.0
# Clade: geogale_aurita:1, Support Value: 86.0
# Clade: oryzorictes:1, Support Value: 85.0
# Clade: micropotamogale_lamottei:potamogale_velox:2, Support Value: 80.0
# Clade: micropotamogale_lamottei:1, Support Value: 93.0
# Clade: potamogale_velox:1, Support Value: 93.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:17, Support Value: 79.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:14, Support Value: 94.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:neamblysomus_gunningi:neamblysomus_julianae:13, Support Value: 95.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:8, Support Value: 96.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:5, Support Value: 97.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_septentrionalis:4, Support Value: 98.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:3, Support Value: 99.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:2, Support Value: 100.0
# Clade: amblysomus_hottentotus:1, Support Value: 101.0
# Clade: amblysomus_corriae:1, Support Value: 101.0
# Clade: amblysomus_marleyi:1, Support Value: 100.0
# Clade: amblysomus_septentrionalis:1, Support Value: 99.0
# Clade: amblysomus_robustus:1, Support Value: 98.0
# Clade: carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:3, Support Value: 97.0
# Clade: neamblysomus_gunningi:neamblysomus_julianae:2, Support Value: 102.0
# Clade: neamblysomus_julianae:1, Support Value: 103.0
# Clade: neamblysomus_gunningi:1, Support Value: 103.0
# Clade: carpitalpa_arendsi:1, Support Value: 102.0
# Clade: calcochloris_obtusirostris:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:5, Support Value: 96.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:chrysospalax_villosus:3, Support Value: 104.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:2, Support Value: 105.0
# Clade: chrysospalax_trevelyani:1, Support Value: 106.0
# Clade: calcochloris_obtusirostris:1, Support Value: 106.0
# Clade: chrysospalax_villosus:1, Support Value: 105.0
# Clade: chlorotalpa_duthieae:chlorotalpa_sclateri:2, Support Value: 104.0
# Clade: chlorotalpa_sclateri:1, Support Value: 107.0
# Clade: chlorotalpa_duthieae:1, Support Value: 107.0
# Clade: eremitalpa_granti:1, Support Value: 95.0
# Clade: chrysochloris_asiatica:chrysochloris_stuhlmanni:cryptochloris_wintoni:3, Support Value: 94.0
# Clade: chrysochloris_asiatica:cryptochloris_wintoni:2, Support Value: 108.0
# Clade: chrysochloris_asiatica:1, Support Value: 109.0
# Clade: cryptochloris_wintoni:1, Support Value: 109.0
# Clade: chrysochloris_stuhlmanni:1, Support Value: 108.0
# Clade: orycteropus_afer:1, Support Value: 63.0
# Clade: dendrohyrax_dorsalis:dugong_dugon:elephas_maximus:elephas_maximus_indicus:heterohyrax_brucei:loxodonta_africana:loxodonta_cyclotis:procavia_capensis:trichechus_manatus:9, Support Value: 62.0
# Clade: dugong_dugon:elephas_maximus:elephas_maximus_indicus:loxodonta_africana:loxodonta_cyclotis:trichechus_manatus:6, Support Value: 110.0
# Clade: dugong_dugon:trichechus_manatus:2, Support Value: 111.0
# Clade: trichechus_manatus:1, Support Value: 112.0
# Clade: dugong_dugon:1, Support Value: 112.0
# Clade: elephas_maximus:elephas_maximus_indicus:loxodonta_africana:loxodonta_cyclotis:4, Support Value: 111.0
# Clade: loxodonta_africana:loxodonta_cyclotis:2, Support Value: 113.0
# Clade: loxodonta_cyclotis:1, Support Value: 114.0
# Clade: loxodonta_africana:1, Support Value: 114.0
# Clade: elephas_maximus:elephas_maximus_indicus:2, Support Value: 113.0
# Clade: elephas_maximus_indicus:1, Support Value: 115.0
# Clade: elephas_maximus:1, Support Value: 115.0
# Clade: dendrohyrax_dorsalis:heterohyrax_brucei:procavia_capensis:3, Support Value: 110.0
# Clade: dendrohyrax_dorsalis:1, Support Value: 116.0
# Clade: heterohyrax_brucei:procavia_capensis:2, Support Value: 116.0
# Clade: procavia_capensis:1, Support Value: 117.0
# Clade: heterohyrax_brucei:1, Support Value: 117.0
# Clade: ornithorhynchus_anatinus:tachyglossus_aculeatus:zaglossus_bruijni:3, Support Value: 61.0
# Clade: ornithorhynchus_anatinus:1, Support Value: 118.0
# Clade: tachyglossus_aculeatus:zaglossus_bruijni:2, Support Value: 118.0
# Clade: zaglossus_bruijni:1, Support Value: 119.0
# Clade: tachyglossus_aculeatus:1, Support Value: 119.0

# %%
# Start the traversal from the root
clade_values_tree2 = {}

traverse_and_collect(tree2, clade_values_tree2)

# Display the clade names with their associated values
for clade, value in clade_values_tree2.items():
    print(f"Clade: {clade}, Support Value: {value}")
# Out:
# Clade: root:1, Support Value: 119.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:dendrohyrax_dorsalis:dugong_dugon:echinops_telfairi:elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:elephas_maximus:elephas_maximus_indicus:eremitalpa_granti:geogale_aurita:hemicentetes_semispinosus:heterohyrax_brucei:limnogale_mergulus:loxodonta_africana:loxodonta_cyclotis:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:neamblysomus_gunningi:neamblysomus_julianae:orycteropus_afer:oryzorictes:petrodromus_tetradactylus:petrosaltator_rozeti:potamogale_velox:procavia_capensis:rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:setifer_setosus:tenrec_ecaudatus:trichechus_manatus:57, Support Value: 61.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:echinops_telfairi:elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:eremitalpa_granti:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:neamblysomus_gunningi:neamblysomus_julianae:orycteropus_afer:oryzorictes:petrodromus_tetradactylus:petrosaltator_rozeti:potamogale_velox:rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:setifer_setosus:tenrec_ecaudatus:48, Support Value: 62.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:echinops_telfairi:elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:eremitalpa_granti:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:neamblysomus_gunningi:neamblysomus_julianae:oryzorictes:petrodromus_tetradactylus:petrosaltator_rozeti:potamogale_velox:rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:setifer_setosus:tenrec_ecaudatus:47, Support Value: 63.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:echinops_telfairi:eremitalpa_granti:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:neamblysomus_gunningi:neamblysomus_julianae:oryzorictes:potamogale_velox:setifer_setosus:tenrec_ecaudatus:32, Support Value: 64.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:17, Support Value: 65.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:14, Support Value: 66.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:neamblysomus_gunningi:neamblysomus_julianae:13, Support Value: 67.0
# Clade: calcochloris_obtusirostris:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:5, Support Value: 68.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:chrysospalax_villosus:3, Support Value: 69.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:2, Support Value: 70.0
# Clade: calcochloris_obtusirostris:1, Support Value: 71.0
# Clade: chrysospalax_trevelyani:1, Support Value: 71.0
# Clade: chrysospalax_villosus:1, Support Value: 70.0
# Clade: chlorotalpa_duthieae:chlorotalpa_sclateri:2, Support Value: 69.0
# Clade: chlorotalpa_sclateri:1, Support Value: 72.0
# Clade: chlorotalpa_duthieae:1, Support Value: 72.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:8, Support Value: 68.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:5, Support Value: 73.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_septentrionalis:4, Support Value: 74.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:3, Support Value: 75.0
# Clade: amblysomus_marleyi:1, Support Value: 76.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:2, Support Value: 76.0
# Clade: amblysomus_hottentotus:1, Support Value: 77.0
# Clade: amblysomus_corriae:1, Support Value: 77.0
# Clade: amblysomus_septentrionalis:1, Support Value: 75.0
# Clade: amblysomus_robustus:1, Support Value: 74.0
# Clade: carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:3, Support Value: 73.0
# Clade: neamblysomus_gunningi:neamblysomus_julianae:2, Support Value: 78.0
# Clade: neamblysomus_julianae:1, Support Value: 79.0
# Clade: neamblysomus_gunningi:1, Support Value: 79.0
# Clade: carpitalpa_arendsi:1, Support Value: 78.0
# Clade: eremitalpa_granti:1, Support Value: 67.0
# Clade: chrysochloris_asiatica:chrysochloris_stuhlmanni:cryptochloris_wintoni:3, Support Value: 66.0
# Clade: chrysochloris_asiatica:cryptochloris_wintoni:2, Support Value: 80.0
# Clade: cryptochloris_wintoni:1, Support Value: 81.0
# Clade: chrysochloris_asiatica:1, Support Value: 81.0
# Clade: chrysochloris_stuhlmanni:1, Support Value: 80.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:oryzorictes:potamogale_velox:setifer_setosus:tenrec_ecaudatus:15, Support Value: 65.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:setifer_setosus:tenrec_ecaudatus:13, Support Value: 82.0
# Clade: echinops_telfairi:hemicentetes_semispinosus:setifer_setosus:tenrec_ecaudatus:4, Support Value: 83.0
# Clade: hemicentetes_semispinosus:tenrec_ecaudatus:2, Support Value: 84.0
# Clade: tenrec_ecaudatus:1, Support Value: 85.0
# Clade: hemicentetes_semispinosus:1, Support Value: 85.0
# Clade: echinops_telfairi:setifer_setosus:2, Support Value: 84.0
# Clade: echinops_telfairi:1, Support Value: 86.0
# Clade: setifer_setosus:1, Support Value: 86.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:9, Support Value: 83.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:8, Support Value: 87.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:7, Support Value: 88.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:4, Support Value: 89.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:3, Support Value: 90.0
# Clade: microgale_longicaudata:microgale_majori:2, Support Value: 91.0
# Clade: microgale_longicaudata:1, Support Value: 92.0
# Clade: microgale_majori:1, Support Value: 92.0
# Clade: microgale_principula:1, Support Value: 91.0
# Clade: microgale_pusilla:1, Support Value: 90.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_talazaci:3, Support Value: 89.0
# Clade: limnogale_mergulus:microgale_brevicaudata:2, Support Value: 93.0
# Clade: microgale_brevicaudata:1, Support Value: 94.0
# Clade: limnogale_mergulus:1, Support Value: 94.0
# Clade: microgale_talazaci:1, Support Value: 93.0
# Clade: geogale_aurita:1, Support Value: 88.0
# Clade: oryzorictes:1, Support Value: 87.0
# Clade: micropotamogale_lamottei:potamogale_velox:2, Support Value: 82.0
# Clade: potamogale_velox:1, Support Value: 95.0
# Clade: micropotamogale_lamottei:1, Support Value: 95.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:15, Support Value: 64.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:12, Support Value: 96.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:7, Support Value: 97.0
# Clade: elephantulus_edwardii:elephantulus_myurus:elephantulus_sp_vb001:3, Support Value: 98.0
# Clade: elephantulus_edwardii:1, Support Value: 99.0
# Clade: elephantulus_myurus:elephantulus_sp_vb001:2, Support Value: 99.0
# Clade: elephantulus_sp_vb001:1, Support Value: 100.0
# Clade: elephantulus_myurus:1, Support Value: 100.0
# Clade: elephantulus_brachyrhynchus:elephantulus_intufi:elephantulus_rufescens:elephantulus_rupestris:4, Support Value: 98.0
# Clade: elephantulus_intufi:elephantulus_rupestris:2, Support Value: 101.0
# Clade: elephantulus_intufi:1, Support Value: 102.0
# Clade: elephantulus_rupestris:1, Support Value: 102.0
# Clade: elephantulus_brachyrhynchus:elephantulus_rufescens:2, Support Value: 101.0
# Clade: elephantulus_brachyrhynchus:1, Support Value: 103.0
# Clade: elephantulus_rufescens:1, Support Value: 103.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:5, Support Value: 97.0
# Clade: petrodromus_tetradactylus:petrosaltator_rozeti:2, Support Value: 104.0
# Clade: petrosaltator_rozeti:1, Support Value: 105.0
# Clade: petrodromus_tetradactylus:1, Support Value: 105.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:3, Support Value: 104.0
# Clade: macroscelides_flavicaudatus:macroscelides_proboscideus:2, Support Value: 106.0
# Clade: macroscelides_flavicaudatus:1, Support Value: 107.0
# Clade: macroscelides_proboscideus:1, Support Value: 107.0
# Clade: macroscelides_micus:1, Support Value: 106.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:3, Support Value: 96.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:2, Support Value: 108.0
# Clade: rhynchocyon_cirnei_reichardi:1, Support Value: 109.0
# Clade: rhynchocyon_petersi:1, Support Value: 109.0
# Clade: rhynchocyon_udzungwensis:1, Support Value: 108.0
# Clade: orycteropus_afer:1, Support Value: 63.0
# Clade: dendrohyrax_dorsalis:dugong_dugon:elephas_maximus:elephas_maximus_indicus:heterohyrax_brucei:loxodonta_africana:loxodonta_cyclotis:procavia_capensis:trichechus_manatus:9, Support Value: 62.0
# Clade: dugong_dugon:elephas_maximus:elephas_maximus_indicus:loxodonta_africana:loxodonta_cyclotis:trichechus_manatus:6, Support Value: 110.0
# Clade: dugong_dugon:trichechus_manatus:2, Support Value: 111.0
# Clade: trichechus_manatus:1, Support Value: 112.0
# Clade: dugong_dugon:1, Support Value: 112.0
# Clade: elephas_maximus:elephas_maximus_indicus:loxodonta_africana:loxodonta_cyclotis:4, Support Value: 111.0
# Clade: loxodonta_africana:loxodonta_cyclotis:2, Support Value: 113.0
# Clade: loxodonta_cyclotis:1, Support Value: 114.0
# Clade: loxodonta_africana:1, Support Value: 114.0
# Clade: elephas_maximus:elephas_maximus_indicus:2, Support Value: 113.0
# Clade: elephas_maximus_indicus:1, Support Value: 115.0
# Clade: elephas_maximus:1, Support Value: 115.0
# Clade: dendrohyrax_dorsalis:heterohyrax_brucei:procavia_capensis:3, Support Value: 110.0
# Clade: dendrohyrax_dorsalis:1, Support Value: 116.0
# Clade: heterohyrax_brucei:procavia_capensis:2, Support Value: 116.0
# Clade: heterohyrax_brucei:1, Support Value: 117.0
# Clade: procavia_capensis:1, Support Value: 117.0
# Clade: ornithorhynchus_anatinus:tachyglossus_aculeatus:zaglossus_bruijni:3, Support Value: 61.0
# Clade: ornithorhynchus_anatinus:1, Support Value: 118.0
# Clade: tachyglossus_aculeatus:zaglossus_bruijni:2, Support Value: 118.0
# Clade: zaglossus_bruijni:1, Support Value: 119.0
# Clade: tachyglossus_aculeatus:1, Support Value: 119.0

# %%
diff_indexes = []
for clade, value in clade_values_tree1.items():
    names = clade.split(":")
    len_of_clade = int(names[-1])
    for clade2, value2 in clade_values_tree2.items():
        names2 = clade2.split(":")
        len_of_clade2 = int(names2[-1])
        if clade == clade2 and value != value2:
           print(f"Clade: {clade}, Support Value LG_G4: {value}, Support Value LG_G4_C60: {value2}")
           diff_indexes.append([int(value), int(value2)])
# Out:
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:12, Support Value LG_G4: 65.0, Support Value LG_G4_C60: 96.0
# Clade: elephantulus_brachyrhynchus:elephantulus_edwardii:elephantulus_intufi:elephantulus_myurus:elephantulus_rufescens:elephantulus_rupestris:elephantulus_sp_vb001:7, Support Value LG_G4: 66.0, Support Value LG_G4_C60: 97.0
# Clade: elephantulus_edwardii:elephantulus_myurus:elephantulus_sp_vb001:3, Support Value LG_G4: 67.0, Support Value LG_G4_C60: 98.0
# Clade: elephantulus_edwardii:1, Support Value LG_G4: 68.0, Support Value LG_G4_C60: 99.0
# Clade: elephantulus_myurus:elephantulus_sp_vb001:2, Support Value LG_G4: 68.0, Support Value LG_G4_C60: 99.0
# Clade: elephantulus_sp_vb001:1, Support Value LG_G4: 69.0, Support Value LG_G4_C60: 100.0
# Clade: elephantulus_myurus:1, Support Value LG_G4: 69.0, Support Value LG_G4_C60: 100.0
# Clade: elephantulus_brachyrhynchus:elephantulus_intufi:elephantulus_rufescens:elephantulus_rupestris:4, Support Value LG_G4: 67.0, Support Value LG_G4_C60: 98.0
# Clade: elephantulus_intufi:elephantulus_rupestris:2, Support Value LG_G4: 70.0, Support Value LG_G4_C60: 101.0
# Clade: elephantulus_intufi:1, Support Value LG_G4: 71.0, Support Value LG_G4_C60: 102.0
# Clade: elephantulus_rupestris:1, Support Value LG_G4: 71.0, Support Value LG_G4_C60: 102.0
# Clade: elephantulus_brachyrhynchus:elephantulus_rufescens:2, Support Value LG_G4: 70.0, Support Value LG_G4_C60: 101.0
# Clade: elephantulus_brachyrhynchus:1, Support Value LG_G4: 72.0, Support Value LG_G4_C60: 103.0
# Clade: elephantulus_rufescens:1, Support Value LG_G4: 72.0, Support Value LG_G4_C60: 103.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:petrodromus_tetradactylus:petrosaltator_rozeti:5, Support Value LG_G4: 66.0, Support Value LG_G4_C60: 97.0
# Clade: petrodromus_tetradactylus:petrosaltator_rozeti:2, Support Value LG_G4: 73.0, Support Value LG_G4_C60: 104.0
# Clade: petrosaltator_rozeti:1, Support Value LG_G4: 74.0, Support Value LG_G4_C60: 105.0
# Clade: petrodromus_tetradactylus:1, Support Value LG_G4: 74.0, Support Value LG_G4_C60: 105.0
# Clade: macroscelides_flavicaudatus:macroscelides_micus:macroscelides_proboscideus:3, Support Value LG_G4: 73.0, Support Value LG_G4_C60: 104.0
# Clade: macroscelides_flavicaudatus:macroscelides_proboscideus:2, Support Value LG_G4: 75.0, Support Value LG_G4_C60: 106.0
# Clade: macroscelides_flavicaudatus:1, Support Value LG_G4: 76.0, Support Value LG_G4_C60: 107.0
# Clade: macroscelides_proboscideus:1, Support Value LG_G4: 76.0, Support Value LG_G4_C60: 107.0
# Clade: macroscelides_micus:1, Support Value LG_G4: 75.0, Support Value LG_G4_C60: 106.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:rhynchocyon_udzungwensis:3, Support Value LG_G4: 65.0, Support Value LG_G4_C60: 96.0
# Clade: rhynchocyon_udzungwensis:1, Support Value LG_G4: 77.0, Support Value LG_G4_C60: 108.0
# Clade: rhynchocyon_cirnei_reichardi:rhynchocyon_petersi:2, Support Value LG_G4: 77.0, Support Value LG_G4_C60: 108.0
# Clade: rhynchocyon_cirnei_reichardi:1, Support Value LG_G4: 78.0, Support Value LG_G4_C60: 109.0
# Clade: rhynchocyon_petersi:1, Support Value LG_G4: 78.0, Support Value LG_G4_C60: 109.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:micropotamogale_lamottei:oryzorictes:potamogale_velox:setifer_setosus:tenrec_ecaudatus:15, Support Value LG_G4: 79.0, Support Value LG_G4_C60: 65.0
# Clade: echinops_telfairi:geogale_aurita:hemicentetes_semispinosus:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:setifer_setosus:tenrec_ecaudatus:13, Support Value LG_G4: 80.0, Support Value LG_G4_C60: 82.0
# Clade: echinops_telfairi:hemicentetes_semispinosus:setifer_setosus:tenrec_ecaudatus:4, Support Value LG_G4: 81.0, Support Value LG_G4_C60: 83.0
# Clade: echinops_telfairi:setifer_setosus:2, Support Value LG_G4: 82.0, Support Value LG_G4_C60: 84.0
# Clade: echinops_telfairi:1, Support Value LG_G4: 83.0, Support Value LG_G4_C60: 86.0
# Clade: setifer_setosus:1, Support Value LG_G4: 83.0, Support Value LG_G4_C60: 86.0
# Clade: hemicentetes_semispinosus:tenrec_ecaudatus:2, Support Value LG_G4: 82.0, Support Value LG_G4_C60: 84.0
# Clade: tenrec_ecaudatus:1, Support Value LG_G4: 84.0, Support Value LG_G4_C60: 85.0
# Clade: hemicentetes_semispinosus:1, Support Value LG_G4: 84.0, Support Value LG_G4_C60: 85.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:oryzorictes:9, Support Value LG_G4: 81.0, Support Value LG_G4_C60: 83.0
# Clade: geogale_aurita:limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:8, Support Value LG_G4: 85.0, Support Value LG_G4_C60: 87.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:microgale_talazaci:7, Support Value LG_G4: 86.0, Support Value LG_G4_C60: 88.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:microgale_pusilla:4, Support Value LG_G4: 87.0, Support Value LG_G4_C60: 89.0
# Clade: microgale_longicaudata:microgale_majori:microgale_principula:3, Support Value LG_G4: 88.0, Support Value LG_G4_C60: 90.0
# Clade: microgale_longicaudata:microgale_majori:2, Support Value LG_G4: 89.0, Support Value LG_G4_C60: 91.0
# Clade: microgale_longicaudata:1, Support Value LG_G4: 90.0, Support Value LG_G4_C60: 92.0
# Clade: microgale_majori:1, Support Value LG_G4: 90.0, Support Value LG_G4_C60: 92.0
# Clade: microgale_principula:1, Support Value LG_G4: 89.0, Support Value LG_G4_C60: 91.0
# Clade: microgale_pusilla:1, Support Value LG_G4: 88.0, Support Value LG_G4_C60: 90.0
# Clade: limnogale_mergulus:microgale_brevicaudata:microgale_talazaci:3, Support Value LG_G4: 87.0, Support Value LG_G4_C60: 89.0
# Clade: limnogale_mergulus:microgale_brevicaudata:2, Support Value LG_G4: 91.0, Support Value LG_G4_C60: 93.0
# Clade: microgale_brevicaudata:1, Support Value LG_G4: 92.0, Support Value LG_G4_C60: 94.0
# Clade: limnogale_mergulus:1, Support Value LG_G4: 92.0, Support Value LG_G4_C60: 94.0
# Clade: microgale_talazaci:1, Support Value LG_G4: 91.0, Support Value LG_G4_C60: 93.0
# Clade: geogale_aurita:1, Support Value LG_G4: 86.0, Support Value LG_G4_C60: 88.0
# Clade: oryzorictes:1, Support Value LG_G4: 85.0, Support Value LG_G4_C60: 87.0
# Clade: micropotamogale_lamottei:potamogale_velox:2, Support Value LG_G4: 80.0, Support Value LG_G4_C60: 82.0
# Clade: micropotamogale_lamottei:1, Support Value LG_G4: 93.0, Support Value LG_G4_C60: 95.0
# Clade: potamogale_velox:1, Support Value LG_G4: 93.0, Support Value LG_G4_C60: 95.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysochloris_asiatica:chrysochloris_stuhlmanni:chrysospalax_trevelyani:chrysospalax_villosus:cryptochloris_wintoni:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:17, Support Value LG_G4: 79.0, Support Value LG_G4_C60: 65.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:eremitalpa_granti:neamblysomus_gunningi:neamblysomus_julianae:14, Support Value LG_G4: 94.0, Support Value LG_G4_C60: 66.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:calcochloris_obtusirostris:carpitalpa_arendsi:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:neamblysomus_gunningi:neamblysomus_julianae:13, Support Value LG_G4: 95.0, Support Value LG_G4_C60: 67.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:8, Support Value LG_G4: 96.0, Support Value LG_G4_C60: 68.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_robustus:amblysomus_septentrionalis:5, Support Value LG_G4: 97.0, Support Value LG_G4_C60: 73.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:amblysomus_septentrionalis:4, Support Value LG_G4: 98.0, Support Value LG_G4_C60: 74.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:amblysomus_marleyi:3, Support Value LG_G4: 99.0, Support Value LG_G4_C60: 75.0
# Clade: amblysomus_corriae:amblysomus_hottentotus:2, Support Value LG_G4: 100.0, Support Value LG_G4_C60: 76.0
# Clade: amblysomus_hottentotus:1, Support Value LG_G4: 101.0, Support Value LG_G4_C60: 77.0
# Clade: amblysomus_corriae:1, Support Value LG_G4: 101.0, Support Value LG_G4_C60: 77.0
# Clade: amblysomus_marleyi:1, Support Value LG_G4: 100.0, Support Value LG_G4_C60: 76.0
# Clade: amblysomus_septentrionalis:1, Support Value LG_G4: 99.0, Support Value LG_G4_C60: 75.0
# Clade: amblysomus_robustus:1, Support Value LG_G4: 98.0, Support Value LG_G4_C60: 74.0
# Clade: carpitalpa_arendsi:neamblysomus_gunningi:neamblysomus_julianae:3, Support Value LG_G4: 97.0, Support Value LG_G4_C60: 73.0
# Clade: neamblysomus_gunningi:neamblysomus_julianae:2, Support Value LG_G4: 102.0, Support Value LG_G4_C60: 78.0
# Clade: neamblysomus_julianae:1, Support Value LG_G4: 103.0, Support Value LG_G4_C60: 79.0
# Clade: neamblysomus_gunningi:1, Support Value LG_G4: 103.0, Support Value LG_G4_C60: 79.0
# Clade: carpitalpa_arendsi:1, Support Value LG_G4: 102.0, Support Value LG_G4_C60: 78.0
# Clade: calcochloris_obtusirostris:chlorotalpa_duthieae:chlorotalpa_sclateri:chrysospalax_trevelyani:chrysospalax_villosus:5, Support Value LG_G4: 96.0, Support Value LG_G4_C60: 68.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:chrysospalax_villosus:3, Support Value LG_G4: 104.0, Support Value LG_G4_C60: 69.0
# Clade: calcochloris_obtusirostris:chrysospalax_trevelyani:2, Support Value LG_G4: 105.0, Support Value LG_G4_C60: 70.0
# Clade: chrysospalax_trevelyani:1, Support Value LG_G4: 106.0, Support Value LG_G4_C60: 71.0
# Clade: calcochloris_obtusirostris:1, Support Value LG_G4: 106.0, Support Value LG_G4_C60: 71.0
# Clade: chrysospalax_villosus:1, Support Value LG_G4: 105.0, Support Value LG_G4_C60: 70.0
# Clade: chlorotalpa_duthieae:chlorotalpa_sclateri:2, Support Value LG_G4: 104.0, Support Value LG_G4_C60: 69.0
# Clade: chlorotalpa_sclateri:1, Support Value LG_G4: 107.0, Support Value LG_G4_C60: 72.0
# Clade: chlorotalpa_duthieae:1, Support Value LG_G4: 107.0, Support Value LG_G4_C60: 72.0
# Clade: eremitalpa_granti:1, Support Value LG_G4: 95.0, Support Value LG_G4_C60: 67.0
# Clade: chrysochloris_asiatica:chrysochloris_stuhlmanni:cryptochloris_wintoni:3, Support Value LG_G4: 94.0, Support Value LG_G4_C60: 66.0
# Clade: chrysochloris_asiatica:cryptochloris_wintoni:2, Support Value LG_G4: 108.0, Support Value LG_G4_C60: 80.0
# Clade: chrysochloris_asiatica:1, Support Value LG_G4: 109.0, Support Value LG_G4_C60: 81.0
# Clade: cryptochloris_wintoni:1, Support Value LG_G4: 109.0, Support Value LG_G4_C60: 81.0
# Clade: chrysochloris_stuhlmanni:1, Support Value LG_G4: 108.0, Support Value LG_G4_C60: 80.0

# %%
diff_indexes
# Out:
# [[65, 96],
#  [66, 97],
#  [67, 98],
#  [68, 99],
#  [68, 99],
#  [69, 100],
#  [69, 100],
#  [67, 98],
#  [70, 101],
#  [71, 102],
#  [71, 102],
#  [70, 101],
#  [72, 103],
#  [72, 103],
#  [66, 97],
#  [73, 104],
#  [74, 105],
#  [74, 105],
#  [73, 104],
#  [75, 106],
#  [76, 107],
#  [76, 107],
#  [75, 106],
#  [65, 96],
#  [77, 108],
#  [77, 108],
#  [78, 109],
#  [78, 109],
#  [79, 65],
#  [80, 82],
#  [81, 83],
#  [82, 84],
#  [83, 86],
#  [83, 86],
#  [82, 84],
#  [84, 85],
#  [84, 85],
#  [81, 83],
#  [85, 87],
#  [86, 88],
#  [87, 89],
#  [88, 90],
#  [89, 91],
#  [90, 92],
#  [90, 92],
#  [89, 91],
#  [88, 90],
#  [87, 89],
#  [91, 93],
#  [92, 94],
#  [92, 94],
#  [91, 93],
#  [86, 88],
#  [85, 87],
#  [80, 82],
#  [93, 95],
#  [93, 95],
#  [79, 65],
#  [94, 66],
#  [95, 67],
#  [96, 68],
#  [97, 73],
#  [98, 74],
#  [99, 75],
#  [100, 76],
#  [101, 77],
#  [101, 77],
#  [100, 76],
#  [99, 75],
#  [98, 74],
#  [97, 73],
#  [102, 78],
#  [103, 79],
#  [103, 79],
#  [102, 78],
#  [96, 68],
#  [104, 69],
#  [105, 70],
#  [106, 71],
#  [106, 71],
#  [105, 70],
#  [104, 69],
#  [107, 72],
#  [107, 72],
#  [95, 67],
#  [94, 66],
#  [108, 80],
#  [109, 81],
#  [109, 81],
#  [108, 80]]

# %%
unique_data = [list(t) for t in set(tuple(inner) for inner in diff_indexes)]

# Print the result
print(unique_data)
# Out:
# [[82, 84], [66, 97], [75, 106], [76, 107], [87, 89], [105, 70], [71, 102], [72, 103], [92, 94], [99, 75], [67, 98], [77, 108], [93, 95], [88, 90], [106, 71], [68, 99], [94, 66], [100, 76], [80, 82], [89, 91], [107, 72], [73, 104], [79, 65], [108, 80], [85, 87], [101, 77], [95, 67], [69, 100], [78, 109], [65, 96], [74, 105], [81, 83], [90, 92], [97, 73], [84, 85], [109, 81], [86, 88], [102, 78], [96, 68], [91, 93], [98, 74], [70, 101], [83, 86], [104, 69], [103, 79]]

# %%
model2_keys = [i[0] for i in unique_data]
model1_keys = [i[1] for i in unique_data]

# %%
mapped_keys = {}
for i in range(len(model2_keys)):
    mapped_keys[model2_keys[i]] = model1_keys[i]

# %%
model1_revised_times = {}
for key, value in model1_mean_times.items():
    if key in model1_keys:
        model1_revised_times[key] = model1_mean_times[mapped_keys[key]]
    else:
        model1_revised_times[key] = value

# %%
model1_mean_posterior_times = np.array(list(model1_revised_times.values()))
model2_mean_posterior_times = np.array(list(model2_mean_times.values()))

# %%
fig, ax = plt.subplots(figsize=(9 ,9))
ax.plot([-0.1,3.3], 
        [-0.1, 3.3], 
        'k--', label='y=x')
points = ax.plot(model1_mean_posterior_times, model2_mean_posterior_times, 'o', label='Posterior mean age')
points[0].set_markerfacecolor('blue')
# points[23].set_markerfacecolor('blue')# Set default face color (for other points)

# Now plot the highlighted point with a different color
ax.scatter(posterior_mean_iqtree[0], posterior_mean_baseml[0], color='red', s=100)
# ax.scatter(posterior_mean_iqtree[4], posterior_mean_baseml[4], color='red', s=100)
# ax.scatter(posterior_mean_iqtree[0], posterior_mean_baseml[0], color='red', label='Root age')
ax.annotate('root calibration:\n ST(1.6419,0.4248,12.6518,1714.5649)', 
        xy=(posterior_mean_iqtree[0], posterior_mean_baseml[0]), 
        xytext=(posterior_mean_iqtree[0]-1.8,  posterior_mean_baseml[0]-0.2 ),  # Offset position for the label
        arrowprops=dict(arrowstyle='->', color='red'),  # Arrow style
        fontsize=12, color='red') 
# Labels and title
ax.set_xlabel('Posterior mean age MIX+MF [100 Mya]', fontsize=18)
ax.set_ylabel('Posterior mean age GTR+G4 [100 Mya]', fontsize=18)
# ax.set_title('Posterior mean age comparison between LG and LG+G4+C60 [t199 ~ B(10.3300,45.2000)]')
ax.legend()

plt.savefig('./afrotheria_mix_mf_root_scatter.png')
