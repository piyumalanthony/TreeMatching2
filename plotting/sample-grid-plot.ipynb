# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating some random data
np.random.seed(42)
x = np.linspace(0, 10, 100)
y_list = [np.sin(x + np.random.rand()) + np.random.rand(100) for _ in range(12)]

# Coordinates of the points to be marked
points_to_mark = [(2, 1.5), (5, -0.5), (8, 0.5)]
labels = ['Point A', 'Point B', 'Point C']
colors = ['red', 'green', 'blue']

# Creating a new 3x4 subplot grid with different y-axis titles for each plot
fig, axes = plt.subplots(3, 4, figsize=(20, 15), sharex=True, sharey=True)

# Adding scatter plots to each subplot
for i, ax in enumerate(axes.flat):
    ax.scatter(x, y_list[i], alpha=0.7)
    if i <3:
        ax.set_title(f'Plot {i+1}')

    # Adding different y-axis titles for each plot
    if(i % 4 == 0):
        ax.set_ylabel(f'Y-axis {i+1}', fontsize=12)

    # Marking the given points in each subplot
    for (px, py), color, label in zip(points_to_mark, colors, labels):
        ax.scatter(px, py, color=color, marker='o', s=100)
    
    # Ensuring no duplicate labels in the legend for each plot
    # if i == 0:
    #     ax.legend()

# Common labels
fig.text(0.5, 0.04, 'Common X axis', ha='center', fontsize=16)
# fig.text(0.04, 0.5, 'Common Y axis', va='center', rotation='vertical', fontsize=16)

# Adding a label below the x-axis title for all the subplots
fig.text(0.5, 0.01, 'Highlighted Points:', ha='center', fontsize=14, color='blue')
for label, color in zip(labels, colors):
    plt.scatter([], [], color=color, marker='o', s=100, label=label)
fig.legend(loc='lower center', ncol=3, fontsize=12)


plt.tight_layout(rect=[0.05, 0.08, 1, 1])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating some random data
np.random.seed(42)
x = np.linspace(0, 10, 100)
y_list = [np.sin(x + np.random.rand()) + np.random.rand(100) for _ in range(12)]

# Coordinates of the points to be marked
points_to_mark = [(2, 1.5), (5, -0.5), (8, 0.5)]
labels = ['Point A', 'Point B', 'Point C']
colors = ['red', 'green', 'blue']

# Creating a new 3x4 subplot grid with different y-axis titles for each plot
fig, axes = plt.subplots(3, 4, figsize=(20, 15), sharex=True, sharey=True)

# Adding scatter plots to each subplot
for i, ax in enumerate(axes.flat):
    ax.scatter(x, y_list[i], alpha=0.7)
    ax.set_title(f'Plot {i+1}')

    # Adding different y-axis titles for each plot
    ax.set_ylabel(f'Y-axis {i+1}', fontsize=12)

    # Marking the given points in each subplot
    for (px, py), color in zip(points_to_mark, colors):
        ax.scatter(px, py, color=color, marker='o', s=100)

# Common labels
fig.text(0.5, 0.04, 'Common X axis', ha='center', fontsize=16)
fig.text(0.04, 0.5, 'Common Y axis', va='center', rotation='vertical', fontsize=16)

# Adding a label below the x-axis title for all the subplots with colored dots
fig.text(0.5, 0.01, 'Highlighted Points: ', ha='center', fontsize=14, color='blue')
for label, color in zip(labels, colors):
    plt.scatter([], [], color=color, marker='o', s=100, label=label)
fig.legend(loc='lower center', ncol=3, fontsize=12)

plt.tight_layout(rect=[0.05, 0.1, 1, 1])
plt.show()
