# %%
import copy
import numpy as np
import matplotlib.pyplot as plt

# %%
iqtree_file_LG = 'LG_metazoa_in.BV'
codeml_file_LG = 'LG_mcmctree_metazoa_out.BV'

# %%
hessian_list = []

hessians_iqtree = []
treestrings_iqtree = []
branch_lengths_iqtree = []
gradient_vectors_iqtree = []
counter = 0
with open(iqtree_file_LG) as f:
    for k, line in enumerate(f.readlines()):
        if counter == 3:
            treestrings_iqtree.append(line)
            print('tree string',k)
        if counter == 5:
            branch_lengths_numerical = line.strip().split()
            branch_lengths_iqtree.append([float(i) for i in branch_lengths_numerical])
            print('branch lengths',k)
        if counter == 7:
            gradients_numerical = line.strip().split()
            gradient_vectors_iqtree.append([float(i) for i in gradients_numerical])
            print('gradients',k)
            
        if counter > 11 and line.strip() == '':
            hessians_iqtree.append(copy.deepcopy(hessian_list))
            hessian_list = []
            counter = 0 
            print('Hessian all string',k)
        elif counter > 11:
            # print(i, line)
            hessian_row_numerical = line.strip().split()
            hessian_list.append([float(i) for i in hessian_row_numerical])
            print('local hessian',k)
        counter += 1
    else:
        hessians_iqtree.append(copy.deepcopy(hessian_list))
# Out:
# tree string 3
# branch lengths 5
# gradients 7
# local hessian 12
# local hessian 13
# local hessian 14
# local hessian 15
# local hessian 16
# local hessian 17
# local hessian 18
# local hessian 19
# local hessian 20
# local hessian 21
# local hessian 22
# local hessian 23
# local hessian 24
# local hessian 25
# local hessian 26
# local hessian 27
# local hessian 28
# local hessian 29
# local hessian 30
# local hessian 31
# local hessian 32
# local hessian 33
# local hessian 34
# local hessian 35
# local hessian 36
# local hessian 37
# local hessian 38
# local hessian 39
# local hessian 40
# local hessian 41
# local hessian 42
# local hessian 43
# local hessian 44
# local hessian 45
# local hessian 46
# local hessian 47
# local hessian 48
# local hessian 49
# local hessian 50
# local hessian 51
# local hessian 52
# local hessian 53
# local hessian 54
# local hessian 55
# local hessian 56
# local hessian 57
# local hessian 58
# local hessian 59
# local hessian 60
# local hessian 61
# local hessian 62
# local hessian 63
# local hessian 64
# local hessian 65
# local hessian 66
# local hessian 67
# local hessian 68
# local hessian 69
# local hessian 70
# local hessian 71
# local hessian 72
# local hessian 73
# local hessian 74
# local hessian 75
# local hessian 76
# local hessian 77
# local hessian 78
# local hessian 79
# local hessian 80
# local hessian 81
# local hessian 82
# local hessian 83
# local hessian 84
# local hessian 85
# local hessian 86
# local hessian 87
# local hessian 88
# local hessian 89
# local hessian 90
# local hessian 91
# local hessian 92
# local hessian 93
# local hessian 94
# local hessian 95
# local hessian 96
# local hessian 97
# local hessian 98
# local hessian 99
# local hessian 100
# local hessian 101
# local hessian 102
# local hessian 103
# local hessian 104
# local hessian 105
# local hessian 106
# local hessian 107
# local hessian 108
# local hessian 109
# local hessian 110
# local hessian 111
# local hessian 112
# local hessian 113
# local hessian 114
# local hessian 115
# local hessian 116
# Hessian all string 117
# tree string 120
# branch lengths 122
# gradients 124
# local hessian 129
# local hessian 130
# local hessian 131
# local hessian 132
# local hessian 133
# local hessian 134
# local hessian 135
# local hessian 136
# local hessian 137
# local hessian 138
# local hessian 139
# local hessian 140
# local hessian 141
# local hessian 142
# local hessian 143
# local hessian 144
# local hessian 145
# local hessian 146
# local hessian 147
# local hessian 148
# local hessian 149
# local hessian 150
# local hessian 151
# local hessian 152
# local hessian 153
# local hessian 154
# local hessian 155
# local hessian 156
# local hessian 157
# local hessian 158
# local hessian 159
# local hessian 160
# local hessian 161
# local hessian 162
# local hessian 163
# local hessian 164
# local hessian 165
# local hessian 166
# local hessian 167
# local hessian 168
# local hessian 169
# local hessian 170
# local hessian 171
# local hessian 172
# local hessian 173
# local hessian 174
# local hessian 175
# local hessian 176
# local hessian 177
# local hessian 178
# local hessian 179
# local hessian 180
# local hessian 181
# local hessian 182
# local hessian 183
# local hessian 184
# local hessian 185
# local hessian 186
# local hessian 187
# local hessian 188
# local hessian 189
# local hessian 190
# local hessian 191
# local hessian 192
# local hessian 193
# local hessian 194
# local hessian 195
# local hessian 196
# local hessian 197
# local hessian 198
# local hessian 199
# local hessian 200
# local hessian 201
# local hessian 202
# local hessian 203
# local hessian 204
# local hessian 205
# local hessian 206
# local hessian 207
# local hessian 208
# local hessian 209
# local hessian 210
# local hessian 211
# local hessian 212
# local hessian 213
# local hessian 214
# local hessian 215
# local hessian 216
# local hessian 217
# local hessian 218
# local hessian 219
# local hessian 220
# local hessian 221
# local hessian 222
# local hessian 223
# local hessian 224
# local hessian 225
# local hessian 226
# local hessian 227
# local hessian 228
# local hessian 229
# local hessian 230
# local hessian 231
# local hessian 232
# local hessian 233
# Hessian all string 234
# tree string 237
# branch lengths 239
# gradients 241
# local hessian 246
# local hessian 247
# local hessian 248
# local hessian 249
# local hessian 250
# local hessian 251
# local hessian 252
# local hessian 253
# local hessian 254
# local hessian 255
# local hessian 256
# local hessian 257
# local hessian 258
# local hessian 259
# local hessian 260
# local hessian 261
# local hessian 262
# local hessian 263
# local hessian 264
# local hessian 265
# local hessian 266
# local hessian 267
# local hessian 268
# local hessian 269
# local hessian 270
# local hessian 271
# local hessian 272
# local hessian 273
# local hessian 274
# local hessian 275
# local hessian 276
# local hessian 277
# local hessian 278
# local hessian 279
# local hessian 280
# local hessian 281
# local hessian 282
# local hessian 283
# local hessian 284
# local hessian 285
# local hessian 286
# local hessian 287
# local hessian 288
# local hessian 289
# local hessian 290
# local hessian 291
# local hessian 292
# local hessian 293
# local hessian 294
# local hessian 295
# local hessian 296
# local hessian 297
# local hessian 298
# local hessian 299
# local hessian 300
# local hessian 301
# local hessian 302
# local hessian 303
# local hessian 304
# local hessian 305
# local hessian 306
# local hessian 307
# local hessian 308
# local hessian 309
# local hessian 310
# local hessian 311
# local hessian 312
# local hessian 313
# local hessian 314
# local hessian 315
# local hessian 316
# local hessian 317
# local hessian 318
# local hessian 319
# local hessian 320
# local hessian 321
# local hessian 322
# local hessian 323
# local hessian 324
# local hessian 325
# local hessian 326
# local hessian 327
# local hessian 328
# local hessian 329
# local hessian 330
# local hessian 331
# local hessian 332
# local hessian 333
# local hessian 334
# local hessian 335
# local hessian 336
# local hessian 337
# local hessian 338
# local hessian 339
# local hessian 340
# local hessian 341
# local hessian 342
# local hessian 343
# local hessian 344
# local hessian 345
# local hessian 346
# local hessian 347
# local hessian 348
# local hessian 349
# local hessian 350
# Hessian all string 351
# tree string 354
# branch lengths 356
# gradients 358
# local hessian 363
# local hessian 364
# local hessian 365
# local hessian 366
# local hessian 367
# local hessian 368
# local hessian 369
# local hessian 370
# local hessian 371
# local hessian 372
# local hessian 373
# local hessian 374
# local hessian 375
# local hessian 376
# local hessian 377
# local hessian 378
# local hessian 379
# local hessian 380
# local hessian 381
# local hessian 382
# local hessian 383
# local hessian 384
# local hessian 385
# local hessian 386
# local hessian 387
# local hessian 388
# local hessian 389
# local hessian 390
# local hessian 391
# local hessian 392
# local hessian 393
# local hessian 394
# local hessian 395
# local hessian 396
# local hessian 397
# local hessian 398
# local hessian 399
# local hessian 400
# local hessian 401
# local hessian 402
# local hessian 403
# local hessian 404
# local hessian 405
# local hessian 406
# local hessian 407
# local hessian 408
# local hessian 409
# local hessian 410
# local hessian 411
# local hessian 412
# local hessian 413
# local hessian 414
# local hessian 415
# local hessian 416
# local hessian 417
# local hessian 418
# local hessian 419
# local hessian 420
# local hessian 421
# local hessian 422
# local hessian 423
# local hessian 424
# local hessian 425
# local hessian 426
# local hessian 427
# local hessian 428
# local hessian 429
# local hessian 430
# local hessian 431
# local hessian 432
# local hessian 433
# local hessian 434
# local hessian 435
# local hessian 436
# local hessian 437
# local hessian 438
# local hessian 439
# local hessian 440
# local hessian 441
# local hessian 442
# local hessian 443
# local hessian 444
# local hessian 445
# local hessian 446
# local hessian 447
# local hessian 448
# local hessian 449
# local hessian 450
# local hessian 451
# local hessian 452
# local hessian 453
# local hessian 454
# local hessian 455
# local hessian 456
# local hessian 457
# local hessian 458
# local hessian 459
# local hessian 460
# local hessian 461
# local hessian 462
# local hessian 463
# local hessian 464
# local hessian 465
# local hessian 466
# local hessian 467
# Hessian all string 468
# tree string 471
# branch lengths 473
# gradients 475
# local hessian 480
# local hessian 481
# local hessian 482
# local hessian 483
# local hessian 484
# local hessian 485
# local hessian 486
# local hessian 487
# local hessian 488
# local hessian 489
# local hessian 490
# local hessian 491
# local hessian 492
# local hessian 493
# local hessian 494
# local hessian 495
# local hessian 496
# local hessian 497
# local hessian 498
# local hessian 499
# local hessian 500
# local hessian 501
# local hessian 502
# local hessian 503
# local hessian 504
# local hessian 505
# local hessian 506
# local hessian 507
# local hessian 508
# local hessian 509
# local hessian 510
# local hessian 511
# local hessian 512
# local hessian 513
# local hessian 514
# local hessian 515
# local hessian 516
# local hessian 517
# local hessian 518
# local hessian 519
# local hessian 520
# local hessian 521
# local hessian 522
# local hessian 523
# local hessian 524
# local hessian 525
# local hessian 526
# local hessian 527
# local hessian 528
# local hessian 529
# local hessian 530
# local hessian 531
# local hessian 532
# local hessian 533
# local hessian 534
# local hessian 535
# local hessian 536
# local hessian 537
# local hessian 538
# local hessian 539
# local hessian 540
# local hessian 541
# local hessian 542
# local hessian 543
# local hessian 544
# local hessian 545
# local hessian 546
# local hessian 547
# local hessian 548
# local hessian 549
# local hessian 550
# local hessian 551
# local hessian 552
# local hessian 553
# local hessian 554
# local hessian 555
# local hessian 556
# local hessian 557
# local hessian 558
# local hessian 559
# local hessian 560
# local hessian 561
# local hessian 562
# local hessian 563
# local hessian 564
# local hessian 565
# local hessian 566
# local hessian 567
# local hessian 568
# local hessian 569
# local hessian 570
# local hessian 571
# local hessian 572
# local hessian 573
# local hessian 574
# local hessian 575
# local hessian 576
# local hessian 577
# local hessian 578
# local hessian 579
# local hessian 580
# local hessian 581
# local hessian 582
# local hessian 583
# local hessian 584
# Hessian all string 585
# tree string 588
# branch lengths 590
# gradients 592
# local hessian 597
# local hessian 598
# local hessian 599
# local hessian 600
# local hessian 601
# local hessian 602
# local hessian 603
# local hessian 604
# local hessian 605
# local hessian 606
# local hessian 607
# local hessian 608
# local hessian 609
# local hessian 610
# local hessian 611
# local hessian 612
# local hessian 613
# local hessian 614
# local hessian 615
# local hessian 616
# local hessian 617
# local hessian 618
# local hessian 619
# local hessian 620
# local hessian 621
# local hessian 622
# local hessian 623
# local hessian 624
# local hessian 625
# local hessian 626
# local hessian 627
# local hessian 628
# local hessian 629
# local hessian 630
# local hessian 631
# local hessian 632
# local hessian 633
# local hessian 634
# local hessian 635
# local hessian 636
# local hessian 637
# local hessian 638
# local hessian 639
# local hessian 640
# local hessian 641
# local hessian 642
# local hessian 643
# local hessian 644
# local hessian 645
# local hessian 646
# local hessian 647
# local hessian 648
# local hessian 649
# local hessian 650
# local hessian 651
# local hessian 652
# local hessian 653
# local hessian 654
# local hessian 655
# local hessian 656
# local hessian 657
# local hessian 658
# local hessian 659
# local hessian 660
# local hessian 661
# local hessian 662
# local hessian 663
# local hessian 664
# local hessian 665
# local hessian 666
# local hessian 667
# local hessian 668
# local hessian 669
# local hessian 670
# local hessian 671
# local hessian 672
# local hessian 673
# local hessian 674
# local hessian 675
# local hessian 676
# local hessian 677
# local hessian 678
# local hessian 679
# local hessian 680
# local hessian 681
# local hessian 682
# local hessian 683
# local hessian 684
# local hessian 685
# local hessian 686
# local hessian 687
# local hessian 688
# local hessian 689
# local hessian 690
# local hessian 691
# local hessian 692
# local hessian 693
# local hessian 694
# local hessian 695
# local hessian 696
# local hessian 697
# local hessian 698
# local hessian 699
# local hessian 700
# local hessian 701
# Hessian all string 702
# tree string 705
# branch lengths 707
# gradients 709
# local hessian 714
# local hessian 715
# local hessian 716
# local hessian 717
# local hessian 718
# local hessian 719
# local hessian 720
# local hessian 721
# local hessian 722
# local hessian 723
# local hessian 724
# local hessian 725
# local hessian 726
# local hessian 727
# local hessian 728
# local hessian 729
# local hessian 730
# local hessian 731
# local hessian 732
# local hessian 733
# local hessian 734
# local hessian 735
# local hessian 736
# local hessian 737
# local hessian 738
# local hessian 739
# local hessian 740
# local hessian 741
# local hessian 742
# local hessian 743
# local hessian 744
# local hessian 745
# local hessian 746
# local hessian 747
# local hessian 748
# local hessian 749
# local hessian 750
# local hessian 751
# local hessian 752
# local hessian 753
# local hessian 754
# local hessian 755
# local hessian 756
# local hessian 757
# local hessian 758
# local hessian 759
# local hessian 760
# local hessian 761
# local hessian 762
# local hessian 763
# local hessian 764
# local hessian 765
# local hessian 766
# local hessian 767
# local hessian 768
# local hessian 769
# local hessian 770
# local hessian 771
# local hessian 772
# local hessian 773
# local hessian 774
# local hessian 775
# local hessian 776
# local hessian 777
# local hessian 778
# local hessian 779
# local hessian 780
# local hessian 781
# local hessian 782
# local hessian 783
# local hessian 784
# local hessian 785
# local hessian 786
# local hessian 787
# local hessian 788
# local hessian 789
# local hessian 790
# local hessian 791
# local hessian 792
# local hessian 793
# local hessian 794
# local hessian 795
# local hessian 796
# local hessian 797
# local hessian 798
# local hessian 799
# local hessian 800
# local hessian 801
# local hessian 802
# local hessian 803
# local hessian 804
# local hessian 805
# local hessian 806
# local hessian 807
# local hessian 808
# local hessian 809
# local hessian 810
# local hessian 811
# local hessian 812
# local hessian 813
# local hessian 814
# local hessian 815
# local hessian 816
# local hessian 817
# local hessian 818
# Hessian all string 819
# tree string 822
# branch lengths 824
# gradients 826
# local hessian 831
# local hessian 832
# local hessian 833
# local hessian 834
# local hessian 835
# local hessian 836
# local hessian 837
# local hessian 838
# local hessian 839
# local hessian 840
# local hessian 841
# local hessian 842
# local hessian 843
# local hessian 844
# local hessian 845
# local hessian 846
# local hessian 847
# local hessian 848
# local hessian 849
# local hessian 850
# local hessian 851
# local hessian 852
# local hessian 853
# local hessian 854
# local hessian 855
# local hessian 856
# local hessian 857
# local hessian 858
# local hessian 859
# local hessian 860
# local hessian 861
# local hessian 862
# local hessian 863
# local hessian 864
# local hessian 865
# local hessian 866
# local hessian 867
# local hessian 868
# local hessian 869
# local hessian 870
# local hessian 871
# local hessian 872
# local hessian 873
# local hessian 874
# local hessian 875
# local hessian 876
# local hessian 877
# local hessian 878
# local hessian 879
# local hessian 880
# local hessian 881
# local hessian 882
# local hessian 883
# local hessian 884
# local hessian 885
# local hessian 886
# local hessian 887
# local hessian 888
# local hessian 889
# local hessian 890
# local hessian 891
# local hessian 892
# local hessian 893
# local hessian 894
# local hessian 895
# local hessian 896
# local hessian 897
# local hessian 898
# local hessian 899
# local hessian 900
# local hessian 901
# local hessian 902
# local hessian 903
# local hessian 904
# local hessian 905
# local hessian 906
# local hessian 907
# local hessian 908
# local hessian 909
# local hessian 910
# local hessian 911
# local hessian 912
# local hessian 913
# local hessian 914
# local hessian 915
# local hessian 916
# local hessian 917
# local hessian 918
# local hessian 919
# local hessian 920
# local hessian 921
# local hessian 922
# local hessian 923
# local hessian 924
# local hessian 925
# local hessian 926
# local hessian 927
# local hessian 928
# local hessian 929
# local hessian 930
# local hessian 931
# local hessian 932
# local hessian 933
# local hessian 934
# local hessian 935
# Hessian all string 936
# tree string 939
# branch lengths 941
# gradients 943
# local hessian 948
# local hessian 949
# local hessian 950
# local hessian 951
# local hessian 952
# local hessian 953
# local hessian 954
# local hessian 955
# local hessian 956
# local hessian 957
# local hessian 958
# local hessian 959
# local hessian 960
# local hessian 961
# local hessian 962
# local hessian 963
# local hessian 964
# local hessian 965
# local hessian 966
# local hessian 967
# local hessian 968
# local hessian 969
# local hessian 970
# local hessian 971
# local hessian 972
# local hessian 973
# local hessian 974
# local hessian 975
# local hessian 976
# local hessian 977
# local hessian 978
# local hessian 979
# local hessian 980
# local hessian 981
# local hessian 982
# local hessian 983
# local hessian 984
# local hessian 985
# local hessian 986
# local hessian 987
# local hessian 988
# local hessian 989
# local hessian 990
# local hessian 991
# local hessian 992
# local hessian 993
# local hessian 994
# local hessian 995
# local hessian 996
# local hessian 997
# local hessian 998
# local hessian 999
# local hessian 1000
# local hessian 1001
# local hessian 1002
# local hessian 1003
# local hessian 1004
# local hessian 1005
# local hessian 1006
# local hessian 1007
# local hessian 1008
# local hessian 1009
# local hessian 1010
# local hessian 1011
# local hessian 1012
# local hessian 1013
# local hessian 1014
# local hessian 1015
# local hessian 1016
# local hessian 1017
# local hessian 1018
# local hessian 1019
# local hessian 1020
# local hessian 1021
# local hessian 1022
# local hessian 1023
# local hessian 1024
# local hessian 1025
# local hessian 1026
# local hessian 1027
# local hessian 1028
# local hessian 1029
# local hessian 1030
# local hessian 1031
# local hessian 1032
# local hessian 1033
# local hessian 1034
# local hessian 1035
# local hessian 1036
# local hessian 1037
# local hessian 1038
# local hessian 1039
# local hessian 1040
# local hessian 1041
# local hessian 1042
# local hessian 1043
# local hessian 1044
# local hessian 1045
# local hessian 1046
# local hessian 1047
# local hessian 1048
# local hessian 1049
# local hessian 1050
# local hessian 1051
# local hessian 1052
# Hessian all string 1053
# tree string 1056
# branch lengths 1058
# gradients 1060
# local hessian 1065
# local hessian 1066
# local hessian 1067
# local hessian 1068
# local hessian 1069
# local hessian 1070
# local hessian 1071
# local hessian 1072
# local hessian 1073
# local hessian 1074
# local hessian 1075
# local hessian 1076
# local hessian 1077
# local hessian 1078
# local hessian 1079
# local hessian 1080
# local hessian 1081
# local hessian 1082
# local hessian 1083
# local hessian 1084
# local hessian 1085
# local hessian 1086
# local hessian 1087
# local hessian 1088
# local hessian 1089
# local hessian 1090
# local hessian 1091
# local hessian 1092
# local hessian 1093
# local hessian 1094
# local hessian 1095
# local hessian 1096
# local hessian 1097
# local hessian 1098
# local hessian 1099
# local hessian 1100
# local hessian 1101
# local hessian 1102
# local hessian 1103
# local hessian 1104
# local hessian 1105
# local hessian 1106
# local hessian 1107
# local hessian 1108
# local hessian 1109
# local hessian 1110
# local hessian 1111
# local hessian 1112
# local hessian 1113
# local hessian 1114
# local hessian 1115
# local hessian 1116
# local hessian 1117
# local hessian 1118
# local hessian 1119
# local hessian 1120
# local hessian 1121
# local hessian 1122
# local hessian 1123
# local hessian 1124
# local hessian 1125
# local hessian 1126
# local hessian 1127
# local hessian 1128
# local hessian 1129
# local hessian 1130
# local hessian 1131
# local hessian 1132
# local hessian 1133
# local hessian 1134
# local hessian 1135
# local hessian 1136
# local hessian 1137
# local hessian 1138
# local hessian 1139
# local hessian 1140
# local hessian 1141
# local hessian 1142
# local hessian 1143
# local hessian 1144
# local hessian 1145
# local hessian 1146
# local hessian 1147
# local hessian 1148
# local hessian 1149
# local hessian 1150
# local hessian 1151
# local hessian 1152
# local hessian 1153
# local hessian 1154
# local hessian 1155
# local hessian 1156
# local hessian 1157
# local hessian 1158
# local hessian 1159
# local hessian 1160
# local hessian 1161
# local hessian 1162
# local hessian 1163
# local hessian 1164
# local hessian 1165
# local hessian 1166
# local hessian 1167
# local hessian 1168
# local hessian 1169

# %%
branch_lengths_iqtree = np.array(branch_lengths_iqtree)

# %%
branch_lengths_iqtree.shape
# Out:
# (10, 105)

# %%
branch_lengths_iqtree = branch_lengths_iqtree.reshape(-1,1)

# %%
branch_lengths_iqtree
# Out:
# array([[0.0354049 ],
#        [0.0220793 ],
#        [0.00624359],
#        ...,
#        [0.0982192 ],
#        [0.163294  ],
#        [0.192907  ]])

# %%
hessian_list_codeml = []

hessians_codeml= []
treestrings_codeml = []
branch_lengths_codeml = []
gradient_vectors_codeml = []
counter = 0
with open(codeml_file_LG) as f:
    for k, line in enumerate(f.readlines()):
        if counter == 3:
            treestrings_codeml.append(line)
            print('tree string',k)
        if counter == 5:
            branch_lengths_numerical = line.strip().split()
            branch_lengths_codeml.append([float(i) for i in branch_lengths_numerical])
            print('branch lengths',k)
        if counter == 7:
            gradients_numerical = line.strip().split()
            gradient_vectors_codeml.append([float(i) for i in gradients_numerical])
            print('gradients',k)
            
        if counter > 11 and line.strip() == '':
            hessians_codeml.append(copy.deepcopy(hessian_list_codeml))
            hessian_list_codeml = []
            counter = 0 
            print('Hessian all string',k)
        elif counter > 11:
            # print(i, line)
            hessian_row_numerical = line.strip().split()
            hessian_list_codeml.append([float(i) for i in hessian_row_numerical])
            print('local hessian',k)
        counter += 1
    else:
        hessians_codeml.append(copy.deepcopy(hessian_list_codeml))
# Out:
# tree string 3
# branch lengths 5
# gradients 7
# local hessian 12
# local hessian 13
# local hessian 14
# local hessian 15
# local hessian 16
# local hessian 17
# local hessian 18
# local hessian 19
# local hessian 20
# local hessian 21
# local hessian 22
# local hessian 23
# local hessian 24
# local hessian 25
# local hessian 26
# local hessian 27
# local hessian 28
# local hessian 29
# local hessian 30
# local hessian 31
# local hessian 32
# local hessian 33
# local hessian 34
# local hessian 35
# local hessian 36
# local hessian 37
# local hessian 38
# local hessian 39
# local hessian 40
# local hessian 41
# local hessian 42
# local hessian 43
# local hessian 44
# local hessian 45
# local hessian 46
# local hessian 47
# local hessian 48
# local hessian 49
# local hessian 50
# local hessian 51
# local hessian 52
# local hessian 53
# local hessian 54
# local hessian 55
# local hessian 56
# local hessian 57
# local hessian 58
# local hessian 59
# local hessian 60
# local hessian 61
# local hessian 62
# local hessian 63
# local hessian 64
# local hessian 65
# local hessian 66
# local hessian 67
# local hessian 68
# local hessian 69
# local hessian 70
# local hessian 71
# local hessian 72
# local hessian 73
# local hessian 74
# local hessian 75
# local hessian 76
# local hessian 77
# local hessian 78
# local hessian 79
# local hessian 80
# local hessian 81
# local hessian 82
# local hessian 83
# local hessian 84
# local hessian 85
# local hessian 86
# local hessian 87
# local hessian 88
# local hessian 89
# local hessian 90
# local hessian 91
# local hessian 92
# local hessian 93
# local hessian 94
# local hessian 95
# local hessian 96
# local hessian 97
# local hessian 98
# local hessian 99
# local hessian 100
# local hessian 101
# local hessian 102
# local hessian 103
# local hessian 104
# local hessian 105
# local hessian 106
# local hessian 107
# local hessian 108
# local hessian 109
# local hessian 110
# local hessian 111
# local hessian 112
# local hessian 113
# local hessian 114
# local hessian 115
# local hessian 116
# Hessian all string 117
# tree string 120
# branch lengths 122
# gradients 124
# local hessian 129
# local hessian 130
# local hessian 131
# local hessian 132
# local hessian 133
# local hessian 134
# local hessian 135
# local hessian 136
# local hessian 137
# local hessian 138
# local hessian 139
# local hessian 140
# local hessian 141
# local hessian 142
# local hessian 143
# local hessian 144
# local hessian 145
# local hessian 146
# local hessian 147
# local hessian 148
# local hessian 149
# local hessian 150
# local hessian 151
# local hessian 152
# local hessian 153
# local hessian 154
# local hessian 155
# local hessian 156
# local hessian 157
# local hessian 158
# local hessian 159
# local hessian 160
# local hessian 161
# local hessian 162
# local hessian 163
# local hessian 164
# local hessian 165
# local hessian 166
# local hessian 167
# local hessian 168
# local hessian 169
# local hessian 170
# local hessian 171
# local hessian 172
# local hessian 173
# local hessian 174
# local hessian 175
# local hessian 176
# local hessian 177
# local hessian 178
# local hessian 179
# local hessian 180
# local hessian 181
# local hessian 182
# local hessian 183
# local hessian 184
# local hessian 185
# local hessian 186
# local hessian 187
# local hessian 188
# local hessian 189
# local hessian 190
# local hessian 191
# local hessian 192
# local hessian 193
# local hessian 194
# local hessian 195
# local hessian 196
# local hessian 197
# local hessian 198
# local hessian 199
# local hessian 200
# local hessian 201
# local hessian 202
# local hessian 203
# local hessian 204
# local hessian 205
# local hessian 206
# local hessian 207
# local hessian 208
# local hessian 209
# local hessian 210
# local hessian 211
# local hessian 212
# local hessian 213
# local hessian 214
# local hessian 215
# local hessian 216
# local hessian 217
# local hessian 218
# local hessian 219
# local hessian 220
# local hessian 221
# local hessian 222
# local hessian 223
# local hessian 224
# local hessian 225
# local hessian 226
# local hessian 227
# local hessian 228
# local hessian 229
# local hessian 230
# local hessian 231
# local hessian 232
# local hessian 233
# Hessian all string 234
# tree string 237
# branch lengths 239
# gradients 241
# local hessian 246
# local hessian 247
# local hessian 248
# local hessian 249
# local hessian 250
# local hessian 251
# local hessian 252
# local hessian 253
# local hessian 254
# local hessian 255
# local hessian 256
# local hessian 257
# local hessian 258
# local hessian 259
# local hessian 260
# local hessian 261
# local hessian 262
# local hessian 263
# local hessian 264
# local hessian 265
# local hessian 266
# local hessian 267
# local hessian 268
# local hessian 269
# local hessian 270
# local hessian 271
# local hessian 272
# local hessian 273
# local hessian 274
# local hessian 275
# local hessian 276
# local hessian 277
# local hessian 278
# local hessian 279
# local hessian 280
# local hessian 281
# local hessian 282
# local hessian 283
# local hessian 284
# local hessian 285
# local hessian 286
# local hessian 287
# local hessian 288
# local hessian 289
# local hessian 290
# local hessian 291
# local hessian 292
# local hessian 293
# local hessian 294
# local hessian 295
# local hessian 296
# local hessian 297
# local hessian 298
# local hessian 299
# local hessian 300
# local hessian 301
# local hessian 302
# local hessian 303
# local hessian 304
# local hessian 305
# local hessian 306
# local hessian 307
# local hessian 308
# local hessian 309
# local hessian 310
# local hessian 311
# local hessian 312
# local hessian 313
# local hessian 314
# local hessian 315
# local hessian 316
# local hessian 317
# local hessian 318
# local hessian 319
# local hessian 320
# local hessian 321
# local hessian 322
# local hessian 323
# local hessian 324
# local hessian 325
# local hessian 326
# local hessian 327
# local hessian 328
# local hessian 329
# local hessian 330
# local hessian 331
# local hessian 332
# local hessian 333
# local hessian 334
# local hessian 335
# local hessian 336
# local hessian 337
# local hessian 338
# local hessian 339
# local hessian 340
# local hessian 341
# local hessian 342
# local hessian 343
# local hessian 344
# local hessian 345
# local hessian 346
# local hessian 347
# local hessian 348
# local hessian 349
# local hessian 350
# Hessian all string 351
# tree string 354
# branch lengths 356
# gradients 358
# local hessian 363
# local hessian 364
# local hessian 365
# local hessian 366
# local hessian 367
# local hessian 368
# local hessian 369
# local hessian 370
# local hessian 371
# local hessian 372
# local hessian 373
# local hessian 374
# local hessian 375
# local hessian 376
# local hessian 377
# local hessian 378
# local hessian 379
# local hessian 380
# local hessian 381
# local hessian 382
# local hessian 383
# local hessian 384
# local hessian 385
# local hessian 386
# local hessian 387
# local hessian 388
# local hessian 389
# local hessian 390
# local hessian 391
# local hessian 392
# local hessian 393
# local hessian 394
# local hessian 395
# local hessian 396
# local hessian 397
# local hessian 398
# local hessian 399
# local hessian 400
# local hessian 401
# local hessian 402
# local hessian 403
# local hessian 404
# local hessian 405
# local hessian 406
# local hessian 407
# local hessian 408
# local hessian 409
# local hessian 410
# local hessian 411
# local hessian 412
# local hessian 413
# local hessian 414
# local hessian 415
# local hessian 416
# local hessian 417
# local hessian 418
# local hessian 419
# local hessian 420
# local hessian 421
# local hessian 422
# local hessian 423
# local hessian 424
# local hessian 425
# local hessian 426
# local hessian 427
# local hessian 428
# local hessian 429
# local hessian 430
# local hessian 431
# local hessian 432
# local hessian 433
# local hessian 434
# local hessian 435
# local hessian 436
# local hessian 437
# local hessian 438
# local hessian 439
# local hessian 440
# local hessian 441
# local hessian 442
# local hessian 443
# local hessian 444
# local hessian 445
# local hessian 446
# local hessian 447
# local hessian 448
# local hessian 449
# local hessian 450
# local hessian 451
# local hessian 452
# local hessian 453
# local hessian 454
# local hessian 455
# local hessian 456
# local hessian 457
# local hessian 458
# local hessian 459
# local hessian 460
# local hessian 461
# local hessian 462
# local hessian 463
# local hessian 464
# local hessian 465
# local hessian 466
# local hessian 467
# Hessian all string 468
# tree string 471
# branch lengths 473
# gradients 475
# local hessian 480
# local hessian 481
# local hessian 482
# local hessian 483
# local hessian 484
# local hessian 485
# local hessian 486
# local hessian 487
# local hessian 488
# local hessian 489
# local hessian 490
# local hessian 491
# local hessian 492
# local hessian 493
# local hessian 494
# local hessian 495
# local hessian 496
# local hessian 497
# local hessian 498
# local hessian 499
# local hessian 500
# local hessian 501
# local hessian 502
# local hessian 503
# local hessian 504
# local hessian 505
# local hessian 506
# local hessian 507
# local hessian 508
# local hessian 509
# local hessian 510
# local hessian 511
# local hessian 512
# local hessian 513
# local hessian 514
# local hessian 515
# local hessian 516
# local hessian 517
# local hessian 518
# local hessian 519
# local hessian 520
# local hessian 521
# local hessian 522
# local hessian 523
# local hessian 524
# local hessian 525
# local hessian 526
# local hessian 527
# local hessian 528
# local hessian 529
# local hessian 530
# local hessian 531
# local hessian 532
# local hessian 533
# local hessian 534
# local hessian 535
# local hessian 536
# local hessian 537
# local hessian 538
# local hessian 539
# local hessian 540
# local hessian 541
# local hessian 542
# local hessian 543
# local hessian 544
# local hessian 545
# local hessian 546
# local hessian 547
# local hessian 548
# local hessian 549
# local hessian 550
# local hessian 551
# local hessian 552
# local hessian 553
# local hessian 554
# local hessian 555
# local hessian 556
# local hessian 557
# local hessian 558
# local hessian 559
# local hessian 560
# local hessian 561
# local hessian 562
# local hessian 563
# local hessian 564
# local hessian 565
# local hessian 566
# local hessian 567
# local hessian 568
# local hessian 569
# local hessian 570
# local hessian 571
# local hessian 572
# local hessian 573
# local hessian 574
# local hessian 575
# local hessian 576
# local hessian 577
# local hessian 578
# local hessian 579
# local hessian 580
# local hessian 581
# local hessian 582
# local hessian 583
# local hessian 584
# Hessian all string 585
# tree string 588
# branch lengths 590
# gradients 592
# local hessian 597
# local hessian 598
# local hessian 599
# local hessian 600
# local hessian 601
# local hessian 602
# local hessian 603
# local hessian 604
# local hessian 605
# local hessian 606
# local hessian 607
# local hessian 608
# local hessian 609
# local hessian 610
# local hessian 611
# local hessian 612
# local hessian 613
# local hessian 614
# local hessian 615
# local hessian 616
# local hessian 617
# local hessian 618
# local hessian 619
# local hessian 620
# local hessian 621
# local hessian 622
# local hessian 623
# local hessian 624
# local hessian 625
# local hessian 626
# local hessian 627
# local hessian 628
# local hessian 629
# local hessian 630
# local hessian 631
# local hessian 632
# local hessian 633
# local hessian 634
# local hessian 635
# local hessian 636
# local hessian 637
# local hessian 638
# local hessian 639
# local hessian 640
# local hessian 641
# local hessian 642
# local hessian 643
# local hessian 644
# local hessian 645
# local hessian 646
# local hessian 647
# local hessian 648
# local hessian 649
# local hessian 650
# local hessian 651
# local hessian 652
# local hessian 653
# local hessian 654
# local hessian 655
# local hessian 656
# local hessian 657
# local hessian 658
# local hessian 659
# local hessian 660
# local hessian 661
# local hessian 662
# local hessian 663
# local hessian 664
# local hessian 665
# local hessian 666
# local hessian 667
# local hessian 668
# local hessian 669
# local hessian 670
# local hessian 671
# local hessian 672
# local hessian 673
# local hessian 674
# local hessian 675
# local hessian 676
# local hessian 677
# local hessian 678
# local hessian 679
# local hessian 680
# local hessian 681
# local hessian 682
# local hessian 683
# local hessian 684
# local hessian 685
# local hessian 686
# local hessian 687
# local hessian 688
# local hessian 689
# local hessian 690
# local hessian 691
# local hessian 692
# local hessian 693
# local hessian 694
# local hessian 695
# local hessian 696
# local hessian 697
# local hessian 698
# local hessian 699
# local hessian 700
# local hessian 701
# Hessian all string 702
# tree string 705
# branch lengths 707
# gradients 709
# local hessian 714
# local hessian 715
# local hessian 716
# local hessian 717
# local hessian 718
# local hessian 719
# local hessian 720
# local hessian 721
# local hessian 722
# local hessian 723
# local hessian 724
# local hessian 725
# local hessian 726
# local hessian 727
# local hessian 728
# local hessian 729
# local hessian 730
# local hessian 731
# local hessian 732
# local hessian 733
# local hessian 734
# local hessian 735
# local hessian 736
# local hessian 737
# local hessian 738
# local hessian 739
# local hessian 740
# local hessian 741
# local hessian 742
# local hessian 743
# local hessian 744
# local hessian 745
# local hessian 746
# local hessian 747
# local hessian 748
# local hessian 749
# local hessian 750
# local hessian 751
# local hessian 752
# local hessian 753
# local hessian 754
# local hessian 755
# local hessian 756
# local hessian 757
# local hessian 758
# local hessian 759
# local hessian 760
# local hessian 761
# local hessian 762
# local hessian 763
# local hessian 764
# local hessian 765
# local hessian 766
# local hessian 767
# local hessian 768
# local hessian 769
# local hessian 770
# local hessian 771
# local hessian 772
# local hessian 773
# local hessian 774
# local hessian 775
# local hessian 776
# local hessian 777
# local hessian 778
# local hessian 779
# local hessian 780
# local hessian 781
# local hessian 782
# local hessian 783
# local hessian 784
# local hessian 785
# local hessian 786
# local hessian 787
# local hessian 788
# local hessian 789
# local hessian 790
# local hessian 791
# local hessian 792
# local hessian 793
# local hessian 794
# local hessian 795
# local hessian 796
# local hessian 797
# local hessian 798
# local hessian 799
# local hessian 800
# local hessian 801
# local hessian 802
# local hessian 803
# local hessian 804
# local hessian 805
# local hessian 806
# local hessian 807
# local hessian 808
# local hessian 809
# local hessian 810
# local hessian 811
# local hessian 812
# local hessian 813
# local hessian 814
# local hessian 815
# local hessian 816
# local hessian 817
# local hessian 818
# Hessian all string 819
# tree string 822
# branch lengths 824
# gradients 826
# local hessian 831
# local hessian 832
# local hessian 833
# local hessian 834
# local hessian 835
# local hessian 836
# local hessian 837
# local hessian 838
# local hessian 839
# local hessian 840
# local hessian 841
# local hessian 842
# local hessian 843
# local hessian 844
# local hessian 845
# local hessian 846
# local hessian 847
# local hessian 848
# local hessian 849
# local hessian 850
# local hessian 851
# local hessian 852
# local hessian 853
# local hessian 854
# local hessian 855
# local hessian 856
# local hessian 857
# local hessian 858
# local hessian 859
# local hessian 860
# local hessian 861
# local hessian 862
# local hessian 863
# local hessian 864
# local hessian 865
# local hessian 866
# local hessian 867
# local hessian 868
# local hessian 869
# local hessian 870
# local hessian 871
# local hessian 872
# local hessian 873
# local hessian 874
# local hessian 875
# local hessian 876
# local hessian 877
# local hessian 878
# local hessian 879
# local hessian 880
# local hessian 881
# local hessian 882
# local hessian 883
# local hessian 884
# local hessian 885
# local hessian 886
# local hessian 887
# local hessian 888
# local hessian 889
# local hessian 890
# local hessian 891
# local hessian 892
# local hessian 893
# local hessian 894
# local hessian 895
# local hessian 896
# local hessian 897
# local hessian 898
# local hessian 899
# local hessian 900
# local hessian 901
# local hessian 902
# local hessian 903
# local hessian 904
# local hessian 905
# local hessian 906
# local hessian 907
# local hessian 908
# local hessian 909
# local hessian 910
# local hessian 911
# local hessian 912
# local hessian 913
# local hessian 914
# local hessian 915
# local hessian 916
# local hessian 917
# local hessian 918
# local hessian 919
# local hessian 920
# local hessian 921
# local hessian 922
# local hessian 923
# local hessian 924
# local hessian 925
# local hessian 926
# local hessian 927
# local hessian 928
# local hessian 929
# local hessian 930
# local hessian 931
# local hessian 932
# local hessian 933
# local hessian 934
# local hessian 935
# Hessian all string 936
# tree string 939
# branch lengths 941
# gradients 943
# local hessian 948
# local hessian 949
# local hessian 950
# local hessian 951
# local hessian 952
# local hessian 953
# local hessian 954
# local hessian 955
# local hessian 956
# local hessian 957
# local hessian 958
# local hessian 959
# local hessian 960
# local hessian 961
# local hessian 962
# local hessian 963
# local hessian 964
# local hessian 965
# local hessian 966
# local hessian 967
# local hessian 968
# local hessian 969
# local hessian 970
# local hessian 971
# local hessian 972
# local hessian 973
# local hessian 974
# local hessian 975
# local hessian 976
# local hessian 977
# local hessian 978
# local hessian 979
# local hessian 980
# local hessian 981
# local hessian 982
# local hessian 983
# local hessian 984
# local hessian 985
# local hessian 986
# local hessian 987
# local hessian 988
# local hessian 989
# local hessian 990
# local hessian 991
# local hessian 992
# local hessian 993
# local hessian 994
# local hessian 995
# local hessian 996
# local hessian 997
# local hessian 998
# local hessian 999
# local hessian 1000
# local hessian 1001
# local hessian 1002
# local hessian 1003
# local hessian 1004
# local hessian 1005
# local hessian 1006
# local hessian 1007
# local hessian 1008
# local hessian 1009
# local hessian 1010
# local hessian 1011
# local hessian 1012
# local hessian 1013
# local hessian 1014
# local hessian 1015
# local hessian 1016
# local hessian 1017
# local hessian 1018
# local hessian 1019
# local hessian 1020
# local hessian 1021
# local hessian 1022
# local hessian 1023
# local hessian 1024
# local hessian 1025
# local hessian 1026
# local hessian 1027
# local hessian 1028
# local hessian 1029
# local hessian 1030
# local hessian 1031
# local hessian 1032
# local hessian 1033
# local hessian 1034
# local hessian 1035
# local hessian 1036
# local hessian 1037
# local hessian 1038
# local hessian 1039
# local hessian 1040
# local hessian 1041
# local hessian 1042
# local hessian 1043
# local hessian 1044
# local hessian 1045
# local hessian 1046
# local hessian 1047
# local hessian 1048
# local hessian 1049
# local hessian 1050
# local hessian 1051
# local hessian 1052
# Hessian all string 1053
# tree string 1056
# branch lengths 1058
# gradients 1060
# local hessian 1065
# local hessian 1066
# local hessian 1067
# local hessian 1068
# local hessian 1069
# local hessian 1070
# local hessian 1071
# local hessian 1072
# local hessian 1073
# local hessian 1074
# local hessian 1075
# local hessian 1076
# local hessian 1077
# local hessian 1078
# local hessian 1079
# local hessian 1080
# local hessian 1081
# local hessian 1082
# local hessian 1083
# local hessian 1084
# local hessian 1085
# local hessian 1086
# local hessian 1087
# local hessian 1088
# local hessian 1089
# local hessian 1090
# local hessian 1091
# local hessian 1092
# local hessian 1093
# local hessian 1094
# local hessian 1095
# local hessian 1096
# local hessian 1097
# local hessian 1098
# local hessian 1099
# local hessian 1100
# local hessian 1101
# local hessian 1102
# local hessian 1103
# local hessian 1104
# local hessian 1105
# local hessian 1106
# local hessian 1107
# local hessian 1108
# local hessian 1109
# local hessian 1110
# local hessian 1111
# local hessian 1112
# local hessian 1113
# local hessian 1114
# local hessian 1115
# local hessian 1116
# local hessian 1117
# local hessian 1118
# local hessian 1119
# local hessian 1120
# local hessian 1121
# local hessian 1122
# local hessian 1123
# local hessian 1124
# local hessian 1125
# local hessian 1126
# local hessian 1127
# local hessian 1128
# local hessian 1129
# local hessian 1130
# local hessian 1131
# local hessian 1132
# local hessian 1133
# local hessian 1134
# local hessian 1135
# local hessian 1136
# local hessian 1137
# local hessian 1138
# local hessian 1139
# local hessian 1140
# local hessian 1141
# local hessian 1142
# local hessian 1143
# local hessian 1144
# local hessian 1145
# local hessian 1146
# local hessian 1147
# local hessian 1148
# local hessian 1149
# local hessian 1150
# local hessian 1151
# local hessian 1152
# local hessian 1153
# local hessian 1154
# local hessian 1155
# local hessian 1156
# local hessian 1157
# local hessian 1158
# local hessian 1159
# local hessian 1160
# local hessian 1161
# local hessian 1162
# local hessian 1163
# local hessian 1164
# local hessian 1165
# local hessian 1166
# local hessian 1167
# local hessian 1168
# local hessian 1169

# %%
branch_lengths_codeml = np.array(branch_lengths_codeml)

# %%
branch_lengths_codeml.shape
# Out:
# (10, 105)

# %%
branch_lengths_codeml = branch_lengths_codeml.reshape(-1,1)

# %%
branch_lengths_codeml
# Out:
# array([[0.035406],
#        [0.022079],
#        [0.006244],
#        ...,
#        [0.09822 ],
#        [0.163293],
#        [0.192908]])

# %%
fig, ax = plt.subplots(figsize=(9 ,9))
ax.plot([-0.01,1], 
        [-0.01, 1], 
        'k--', label='y=x')
ax.plot(branch_lengths_codeml, branch_lengths_iqtree, 'o')
 
# Labels and title
ax.set_xlabel('Branch lengths-Codeml [LG]')
ax.set_ylabel('Branch lengths-IQ-TREE [LG] ')
ax.set_title('Branch lengths comparison between IQ-TREE and Codeml [LG]')
ax.legend()

# point_x = posterior_mean_baseml[0]  # Example: first point in the list
# point_y = posterior_mean_iqtree[0]  # Example: first point in the list
# ax.annotate('Root age', xy=(point_x, point_y), xytext=(point_x - 0.1, point_y - 0.1), color='red')
# Show plot
# plt.show()
plt.savefig('./metazoa_branch_lengths_codeml_iqtree_scatter_LG.png')

# %%
gradient_vectors_iqtree = np.array(gradient_vectors_iqtree)
gradient_vectors_codeml = np.array(gradient_vectors_codeml)
gradient_vectors_iqtree = gradient_vectors_iqtree.reshape(-1,1)
gradient_vectors_codeml = gradient_vectors_codeml.reshape(-1,1)

# %%
gradient_vectors_iqtree.shape
# Out:
# (1050, 1)

# %%
fig, ax = plt.subplots(figsize=(9 ,9))
ax.plot([-1,5], 
        [-1, 5], 
        'k--', label='y=x')
ax.plot(gradient_vectors_codeml, gradient_vectors_iqtree, 'o')
 
# Labels and title
ax.set_xlabel('Gradients-Codeml [LG]')
ax.set_ylabel('Gradients-IQ-TREE [LG] ')
ax.set_title('Gradients comparison between IQ-TREE and Codeml [LG]')
ax.legend()

# point_x = posterior_mean_baseml[0]  # Example: first point in the list
# point_y = posterior_mean_iqtree[0]  # Example: first point in the list
# ax.annotate('Root age', xy=(point_x, point_y), xytext=(point_x - 0.1, point_y - 0.1), color='red')
# Show plot
# plt.show()
plt.savefig('./metazoa_gradients_codeml_iqtree_scatter_LG.png')

# %%
hessians_iqtree = np.array(hessians_iqtree)
hessians_codeml= np.array(hessians_codeml)
hessians_iqtree = hessians_iqtree.reshape(-1,1)
hessians_codeml = hessians_codeml.reshape(-1,1)

# %%
fig, ax = plt.subplots(figsize=(9 ,9))
ax.plot([min(hessians_iqtree),max(hessians_iqtree)], 
        [min(hessians_iqtree),max(hessians_iqtree)], 
        'k--', label='y=x')
ax.plot(hessians_codeml, hessians_iqtree, 'o')
 
# Labels and title
ax.set_xlabel('Hessian elements-Codeml[LG]')
ax.set_ylabel('Hessian elements-IQ-TREE [LG] ')
ax.set_title('Hessian comparison between IQ-TREE and Codeml [LG]')
ax.legend()

# point_x = posterior_mean_baseml[0]  # Example: first point in the list
# point_y = posterior_mean_iqtree[0]  # Example: first point in the list
# ax.annotate('Root age', xy=(point_x, point_y), xytext=(point_x - 0.1, point_y - 0.1), color='red')
# Show plot
# plt.show()
plt.savefig('./metazoa_hessians_codeml_iqtree_scatter_LG.png')
